# %% [markdown]
# # 環境確認

# %%
import sys
import torch

print("Pythonのバージョン：",sys.version)
print("PyTorchのバージョン：", torch.__version__)
print("使用しているGPUの確認")
# !nvidia-smi
# Out:
# Pythonのバージョン： 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0]
# PyTorchのバージョン： 1.10.0+cu111
# 使用しているGPUの確認
# Fri Feb 18 02:09:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    25W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # データのダウンロード

# %%
# Fruits-360 dataset をダウンロードし、解凍する

# !wget https://md-datasets-cache-zipfiles-prod.s3.eu-west-1.amazonaws.com/rp73yg93n8-1.zip -nc -P ./data/
# !unzip -n ./data/rp73yg93n8-1.zip -d ./data/
# !unzip -n -q ./data/fruits-360_dataset.zip -d ./data/
# Out:
# File ‘./data/rp73yg93n8-1.zip’ already there; not retrieving.
#
# Archive:  ./data/rp73yg93n8-1.zip

# %% [markdown]
# # 事前準備

# %%
import os
import random
from glob import glob
from warnings import filterwarnings

import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.init as init
from natsort import natsorted
from PIL import Image
from skimage import io, transform
from torch import nn, optim
from torch.autograd import Variable
from torch.nn import functional as F
from torch.utils.data import Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
from torchvision.utils import make_grid, save_image

from torchsummary import summary

filterwarnings("ignore")  # warningをオフにする

# ランダムシードの設定
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
'''初期設定'''

COLAB_FLG = False  # COLABで実行する場合はTrue, それ以外で実行する場合はFalse

if COLAB_FLG:
    from google.colab import drive
    drive.mount('/content/gdrive') # マウント先
    ATTACH_PATH = "/content/gdrive/MyDrive/Colab Notebooks/EfficientGAN-RGB"  # 保存先のベースディレクトリ
else:
    ATTACH_PATH = "."  # ローカルならカレントディレクトリ
    
    
SAVE_MODEL_PATH = f"{ATTACH_PATH}/results/EfficientGAN/model/"  # モデルの保存先
SAVE_IMAGE_FROM_Z_PATH = f"{ATTACH_PATH}/results/EfficientGAN/image/image_from_z/"  # 乱数から生成した画像の保存先
SAVE_IMAGE_RECONSTRUCT = f"{ATTACH_PATH}/results/EfficientGAN/image/RECONSTRUCT/"  # 再構成した画像の保存先

# 保存先のディレクトリを作成する
os.makedirs(SAVE_MODEL_PATH, exist_ok=True)
os.makedirs(SAVE_IMAGE_FROM_Z_PATH, exist_ok=True)
os.makedirs(SAVE_IMAGE_RECONSTRUCT, exist_ok=True)

# %%
IMAGE_SIZE = 96  # 画像の読み込みサイズ
EMBED_SIZE = 128  # 潜在変数zの次元数
BATCH_SIZE = 16  # バッチサイズ
EPOCHS = 1000  # エポック数
LR = 0.0004  # 学習率

# %%
# デバイスの設定
device = "cuda" if torch.cuda.is_available() else "cpu"
kwargs = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {} # GPUが使える場合、DataLoaderでのミニバッチの取り出しを高速化

# %% [markdown]
# # DataLoader

# %%
train_root = './data/fruits-360/Training/Physalis/'  # train dataの保存してあるディレクトリ
val_root = './data/fruits-360/Test/Physalis/'  # val dataの保存してあるディレクトリ

# %%
# ディレクトリから画像を読み込んでDataLoaderに渡す用のクラス

class LoadFromFolder(Dataset):
    def __init__(self, main_dir, transform):
        self.main_dir = main_dir
        self.transform = transform
        all_imgs = natsorted(os.listdir(main_dir)) # ディレクトリ一覧を取得して自然ソート
        self.all_imgs_name = natsorted(all_imgs)
        self.imgs_loc = [os.path.join(self.main_dir, i) for i in self.all_imgs_name] # 画像のディレクトリ一覧

    def __len__(self):
        return len(self.all_imgs_name)
    
    def load_image(self, path):
        image = Image.open(path).convert("RGB")
        tensor_image = self.transform(image)
        return tensor_image
    
    def __getitem__(self, idx):
        
        # 後ほどsliceで画像を複数枚取得したいのでsliceでも取れるようにする
        if type(idx) == slice:
            paths = self.imgs_loc[idx]
            tensor_image = [self.load_image(path) for path in paths]
            tensor_image = torch.cat(tensor_image).reshape(len(tensor_image), *tensor_image[0].shape)
        elif type(idx) == int:
            path = self.imgs_loc[idx]
            tensor_image = self.load_image(path)
        return tensor_image

# %%
# 画像を読み込む際の前処理

transform_dict = {
    "train": transforms.Compose(
        [
            transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),  # IMAGE_SIZEにreshape
            transforms.RandomHorizontalFlip(), # ランダムに左右反転を行う
            transforms.ToTensor(),
        ]
    ),
    "test": transforms.Compose(
        [
            transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),  # IMAGE_SIZEにreshape
            transforms.ToTensor(),
        ]
    ),
}

# %%
# データを読み込む
train_dataset = LoadFromFolder(train_root, transform=transform_dict["train"])

test_dataset = LoadFromFolder(val_root, transform=transform_dict["test"])

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size = BATCH_SIZE, shuffle=True, **kwargs)

val_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size = BATCH_SIZE, shuffle=True, **kwargs)

# %% [markdown]
# # Encoder

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=4, stride=2, padding=1, bias=False), # 48x48
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1, bias=False), # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False), # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False), # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(256, 512, kernel_size=6, stride=1, bias=False), # 1x1
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(512, 512, kernel_size=1, stride=1, bias=False), # 1x1
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),  
        )

        self.last = nn.Sequential(nn.Conv2d(512, EMBED_SIZE, kernel_size=1, stride=1, bias=False))

    def forward(self, x):

        out = self.main(x)
        out = self.last(out)
        out = out.view(out.size()[0], -1, 1, 1)
        return out

# %%
# ネットワークを可視化する

summary(Encoder().to(device), (3, opt.image_size, opt.image_size))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 48, 48]           1,536
#        BatchNorm2d-2           [-1, 32, 48, 48]              64
#          LeakyReLU-3           [-1, 32, 48, 48]               0
#             Conv2d-4           [-1, 64, 24, 24]          32,768
#        BatchNorm2d-5           [-1, 64, 24, 24]             128
#          LeakyReLU-6           [-1, 64, 24, 24]               0
#             Conv2d-7          [-1, 128, 12, 12]         131,072
#        BatchNorm2d-8          [-1, 128, 12, 12]             256
#          LeakyReLU-9          [-1, 128, 12, 12]               0
#            Conv2d-10            [-1, 256, 6, 6]         524,288
#       BatchNorm2d-11            [-1, 256, 6, 6]             512
#         LeakyReLU-12            [-1, 256, 6, 6]               0
#            Conv2d-13            [-1, 512, 1, 1]       4,718,592
#       BatchNorm2d-14            [-1, 512, 1, 1]           1,024
#         LeakyReLU-15            [-1, 512, 1, 1]               0
#            Conv2d-16            [-1, 512, 1, 1]         262,144
#       BatchNorm2d-17            [-1, 512, 1, 1]           1,024
#         LeakyReLU-18            [-1, 512, 1, 1]               0
#            Conv2d-19            [-1, 128, 1, 1]          65,536
# ================================================================
# Total params: 5,738,944
# Trainable params: 5,738,944
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 3.19
# Params size (MB): 21.89
# Estimated Total Size (MB): 25.19
# ----------------------------------------------------------------

# %% [markdown]
# # Generator

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()

        self.main = nn.Sequential(
            nn.ConvTranspose2d(EMBED_SIZE, 256, kernel_size=6, stride=1, padding=0, bias=False),  # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),  # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),  # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1, bias=False),  # 48x48
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(32, 3, kernel_size=4, stride=2, padding=1, bias=False),  # 96x96
            nn.Tanh(),
        )

    def forward(self, z):
        out = self.main(z)
        return out

# %%
# ネットワークを可視化する

summary(Generator().to(device), tuple([EMBED_SIZE, 1, 1]))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1            [-1, 256, 6, 6]       1,179,648
#        BatchNorm2d-2            [-1, 256, 6, 6]             512
#          LeakyReLU-3            [-1, 256, 6, 6]               0
#    ConvTranspose2d-4          [-1, 128, 12, 12]         524,288
#        BatchNorm2d-5          [-1, 128, 12, 12]             256
#          LeakyReLU-6          [-1, 128, 12, 12]               0
#    ConvTranspose2d-7           [-1, 64, 24, 24]         131,072
#        BatchNorm2d-8           [-1, 64, 24, 24]             128
#          LeakyReLU-9           [-1, 64, 24, 24]               0
#   ConvTranspose2d-10           [-1, 32, 48, 48]          32,768
#       BatchNorm2d-11           [-1, 32, 48, 48]              64
#         LeakyReLU-12           [-1, 32, 48, 48]               0
#   ConvTranspose2d-13            [-1, 3, 96, 96]           1,536
#              Tanh-14            [-1, 3, 96, 96]               0
# ================================================================
# Total params: 1,870,272
# Trainable params: 1,870,272
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.59
# Params size (MB): 7.13
# Estimated Total Size (MB): 10.72
# ----------------------------------------------------------------

# %% [markdown]
# # Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()

        self.x_layer = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=4, stride=2, padding=1),  # 48x48
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.3),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1),  # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.3),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),  # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.3),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),  # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.3),
            nn.Conv2d(256, 256, kernel_size=6, stride=1),  # 1x1
        )
        self.z_layer = nn.Sequential(
            nn.Conv2d(EMBED_SIZE, 256, kernel_size=1, stride=1),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.2),
        )

        self.last1 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=1, stride=1),
            nn.LeakyReLU(0.1, inplace=False),
            nn.Dropout2d(p=0.2),
        )
        self.last2 = nn.Sequential(
            nn.Conv2d(512, 1, kernel_size=1, stride=1),
        )

    def forward(self, x, z):

        output_x = self.x_layer(x)
        output_z = self.z_layer(z)

        concat_x_z = torch.cat((output_x, output_z), 1)
        output = self.last1(concat_x_z)

        feature = output.view(output.size()[0], -1)

        output = self.last2(output)
        output = F.sigmoid(output)
        return output.squeeze(), feature

# %%
# ネットワークを可視化する

summary(Discriminator().to(device), [(3, IMAGE_SIZE, IMAGE_SIZE), (EMBED_SIZE, 1, 1)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 48, 48]           1,568
#          LeakyReLU-2           [-1, 32, 48, 48]               0
#          Dropout2d-3           [-1, 32, 48, 48]               0
#             Conv2d-4           [-1, 64, 24, 24]          32,832
#        BatchNorm2d-5           [-1, 64, 24, 24]             128
#          LeakyReLU-6           [-1, 64, 24, 24]               0
#          Dropout2d-7           [-1, 64, 24, 24]               0
#             Conv2d-8          [-1, 128, 12, 12]         131,200
#        BatchNorm2d-9          [-1, 128, 12, 12]             256
#         LeakyReLU-10          [-1, 128, 12, 12]               0
#         Dropout2d-11          [-1, 128, 12, 12]               0
#            Conv2d-12            [-1, 256, 6, 6]         524,544
#       BatchNorm2d-13            [-1, 256, 6, 6]             512
#         LeakyReLU-14            [-1, 256, 6, 6]               0
#         Dropout2d-15            [-1, 256, 6, 6]               0
#            Conv2d-16            [-1, 256, 1, 1]       2,359,552
#            Conv2d-17            [-1, 256, 1, 1]          33,024
#         LeakyReLU-18            [-1, 256, 1, 1]               0
#         Dropout2d-19            [-1, 256, 1, 1]               0
#            Conv2d-20            [-1, 512, 1, 1]         262,656
#         LeakyReLU-21            [-1, 512, 1, 1]               0
#         Dropout2d-22            [-1, 512, 1, 1]               0
#            Conv2d-23              [-1, 1, 1, 1]             513
# ================================================================
# Total params: 3,346,785
# Trainable params: 3,346,785
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 13.50
# Forward/backward pass size (MB): 3.68
# Params size (MB): 12.77
# Estimated Total Size (MB): 29.94
# ----------------------------------------------------------------

# %%
# 重みの初期化を行う関数

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
E = Encoder().to(device)
E.apply(weights_init)

G = Generator().to(device)
G.apply(weights_init)

D = Discriminator().to(device)
D.apply(weights_init)

criterion = nn.BCELoss()  # 評価関数
criterion_L1 = nn.L1Loss(reduction="sum") # 異常スコア計測用

# gとeは共通のoptimizer
optimizer_ge = torch.optim.Adam(list(G.parameters()) + list(E.parameters()), lr=LR, betas=(0.5,0.999))
optimizer_d = torch.optim.Adam(D.parameters(), lr=LR, betas=(0.5,0.999))

scheduler_ge = torch.optim.lr_scheduler.StepLR(optimizer_ge, step_size=50, gamma=0.9)
scheduler_d = torch.optim.lr_scheduler.StepLR(optimizer_d, step_size=50, gamma=0.9)

# %% [markdown]
# # 学習

# %%
def Anomaly_score(x, E_x, G_E_x, Lambda=0.1):
    
    _,x_feature = D(x, E_x)
    _,G_E_x_feature = D(G_E_x, E_x)
    
    residual_loss = criterion_L1(x, G_E_x)
    discrimination_loss = criterion_L1(x_feature, G_E_x_feature)
    
    total_loss = (1-Lambda)*residual_loss + Lambda*discrimination_loss
    total_loss = total_loss.item()

    return total_loss

# %%
loss_d_list = []
loss_ge_list = []
anomaly_score_list = []


for epoch in range(EPOCHS):
    loss_d_sum = 0
    loss_ge_sum = 0
    anomaly_score_sum = 0
    
    for i,(x, x_val) in enumerate(zip(train_loader, val_loader)):
        
        G.train()
        D.train()
        E.train()

        # 値の設定
        y_true = Variable(torch.ones(x.size()[0])).to(device)
        y_fake = Variable(torch.zeros(x.size()[0])).to(device)
        
        x = Variable(x).to(device)
        z = Variable(init.normal(torch.Tensor(x.size()[0],EMBED_SIZE, 1, 1),mean=0,std=0.1)).to(device)
        
        # Discriminatorに対するノイズ
        noise1 = Variable(torch.Tensor(x.size()).normal_(0, 0.1 * (EPOCHS - epoch) / EPOCHS),
                          requires_grad=False).to(device)
        noise2 = Variable(torch.Tensor(x.size()).normal_(0, 0.1 * (EPOCHS - epoch) / EPOCHS),
                          requires_grad=False).to(device)

        # Discriminator
        optimizer_d.zero_grad()
        
        E_x = E(x) 
        p_true, _ = D(x + noise1, E_x)
        
        G_z = G(z)
        p_fake, _ = D(G_z + noise2, z)
        
        loss_d = criterion(p_true, y_true) + criterion(p_fake, y_fake)
        loss_d.backward(retain_graph=True)
        optimizer_d.step()
        
        # Generator, Encoder
        optimizer_ge.zero_grad()
        
        p_true, _ = D(x + noise1, E_x)
        p_fake, _ = D(G_z + noise2, z)
        
        loss_ge = criterion(p_fake, y_true) + criterion(p_true, y_fake)
        loss_ge.backward(retain_graph=True)
        optimizer_ge.step()
        
        loss_d_sum += loss_d.item()
        loss_ge_sum += loss_ge.item()
        
        # anomaly scoreの記録
        
        G.eval()
        D.eval()
        E.eval()
        x_val = Variable(x_val).to(device)
        E_x_val = E(x_val)
        G_E_x_val = G(E_x_val)
        anomaly_score_sum += Anomaly_score(x_val, E_x_val, G_E_x_val)
            
        # 画像を保存
        if i == 0:
        
            save_image_size_for_z = min(BATCH_SIZE, 8)
            save_images = G(z)
            save_image(save_images[:save_image_size_for_z], f"{SAVE_IMAGE_FROM_Z_PATH}/epoch_{epoch}.png", nrow=4)

            save_image_size_for_recon = min(BATCH_SIZE, 8)
            images = x[:save_image_size_for_recon]
            G_E_x = G(E(images))
            diff_images = torch.abs(images - G_E_x)
            comparison = torch.cat([images , G_E_x, diff_images]).to("cpu")
            save_image(comparison, f"{SAVE_IMAGE_RECONSTRUCT}/epoch_{epoch}.png", nrow=save_image_size_for_recon)
            
    scheduler_ge.step()
    scheduler_d.step()
        
    # lossを記録
    loss_d_mean = loss_d_sum / len(train_loader)
    loss_ge_mean = loss_ge_sum / len(train_loader)
    anomaly_score_mean = anomaly_score_sum / len(train_loader)
    
    print(f"{epoch}/{EPOCHS} epoch ge_loss: {loss_ge_mean:.3f} d_loss: {loss_d_mean:.3f} anomaly_score: {anomaly_score_mean:.3f}")
    
    loss_d_list.append(loss_d_mean)
    loss_ge_list.append(loss_ge_mean)
    anomaly_score_list.append(anomaly_score_mean)
    
    # モデルを保存
    if (epoch + 1) % 10 == 0:
        torch.save(G.state_dict(),f'{SAVE_MODEL_PATH}/Generator_{epoch + 1}.pkl')
        torch.save(E.state_dict(),f'{SAVE_MODEL_PATH}/Encoder_{epoch + 1}.pkl')
        torch.save(D.state_dict(),f'{SAVE_MODEL_PATH}/Discriminator_{epoch + 1}.pkl')
# Out:
# 0/1000 epoch ge_loss: 2.627 d_loss: 0.200 anomaly_score: 86411.484
# 1/1000 epoch ge_loss: 5.696 d_loss: 0.062 anomaly_score: 83564.871
# 2/1000 epoch ge_loss: 6.512 d_loss: 0.029 anomaly_score: 77027.372
# 3/1000 epoch ge_loss: 6.464 d_loss: 0.090 anomaly_score: 64544.724
# 4/1000 epoch ge_loss: 6.065 d_loss: 0.049 anomaly_score: 48709.418
# 5/1000 epoch ge_loss: 3.542 d_loss: 0.559 anomaly_score: 40473.792
# 6/1000 epoch ge_loss: 2.590 d_loss: 0.182 anomaly_score: 33849.964
# 7/1000 epoch ge_loss: 2.742 d_loss: 0.188 anomaly_score: 37863.557
# 8/1000 epoch ge_loss: 2.497 d_loss: 0.196 anomaly_score: 28468.508
# 9/1000 epoch ge_loss: 1.754 d_loss: 0.272 anomaly_score: 21520.659
# 10/1000 epoch ge_loss: 1.469 d_loss: 0.337 anomaly_score: 19428.804
# 11/1000 epoch ge_loss: 1.428 d_loss: 0.357 anomaly_score: 18635.701
# 12/1000 epoch ge_loss: 1.222 d_loss: 0.325 anomaly_score: 16550.070
# 13/1000 epoch ge_loss: 1.088 d_loss: 0.371 anomaly_score: 16925.770
# 14/1000 epoch ge_loss: 0.991 d_loss: 0.397 anomaly_score: 17215.017
# 15/1000 epoch ge_loss: 1.094 d_loss: 0.407 anomaly_score: 17521.703
# 16/1000 epoch ge_loss: 1.083 d_loss: 0.392 anomaly_score: 17642.852
# 17/1000 epoch ge_loss: 1.152 d_loss: 0.361 anomaly_score: 16908.496
# 18/1000 epoch ge_loss: 1.085 d_loss: 0.371 anomaly_score: 15808.063
# 19/1000 epoch ge_loss: 1.075 d_loss: 0.345 anomaly_score: 16084.858
# 20/1000 epoch ge_loss: 1.339 d_loss: 0.372 anomaly_score: 20358.968
# 21/1000 epoch ge_loss: 1.153 d_loss: 0.361 anomaly_score: 17001.972
# 22/1000 epoch ge_loss: 1.355 d_loss: 0.340 anomaly_score: 18922.353
# 23/1000 epoch ge_loss: 1.296 d_loss: 0.344 anomaly_score: 15882.785
# 24/1000 epoch ge_loss: 1.420 d_loss: 0.391 anomaly_score: 16562.770
# 25/1000 epoch ge_loss: 1.341 d_loss: 0.310 anomaly_score: 15675.626
# 26/1000 epoch ge_loss: 1.260 d_loss: 0.340 anomaly_score: 15652.785
# 27/1000 epoch ge_loss: 1.458 d_loss: 0.338 anomaly_score: 16799.116
# 28/1000 epoch ge_loss: 1.473 d_loss: 0.360 anomaly_score: 15271.223
# 29/1000 epoch ge_loss: 1.220 d_loss: 0.342 anomaly_score: 15325.810
# 30/1000 epoch ge_loss: 1.263 d_loss: 0.321 anomaly_score: 15530.965
# 31/1000 epoch ge_loss: 1.563 d_loss: 0.296 anomaly_score: 14814.441
# 32/1000 epoch ge_loss: 1.399 d_loss: 0.343 anomaly_score: 16482.517
# 33/1000 epoch ge_loss: 1.439 d_loss: 0.352 anomaly_score: 16533.658
# 34/1000 epoch ge_loss: 1.332 d_loss: 0.340 anomaly_score: 13954.551
# 35/1000 epoch ge_loss: 1.134 d_loss: 0.399 anomaly_score: 14834.917
# 36/1000 epoch ge_loss: 1.126 d_loss: 0.387 anomaly_score: 16541.685
# 37/1000 epoch ge_loss: 1.208 d_loss: 0.326 anomaly_score: 12649.587
# 38/1000 epoch ge_loss: 1.236 d_loss: 0.297 anomaly_score: 13380.045
# 39/1000 epoch ge_loss: 1.311 d_loss: 0.351 anomaly_score: 15036.380
# 40/1000 epoch ge_loss: 1.244 d_loss: 0.359 anomaly_score: 13286.959
# 41/1000 epoch ge_loss: 1.152 d_loss: 0.349 anomaly_score: 15684.948
# 42/1000 epoch ge_loss: 1.270 d_loss: 0.344 anomaly_score: 11888.183
# 43/1000 epoch ge_loss: 1.393 d_loss: 0.350 anomaly_score: 13296.706
# 44/1000 epoch ge_loss: 1.250 d_loss: 0.323 anomaly_score: 13679.620
# 45/1000 epoch ge_loss: 1.350 d_loss: 0.383 anomaly_score: 12815.029
# 46/1000 epoch ge_loss: 1.229 d_loss: 0.327 anomaly_score: 10913.865
# 47/1000 epoch ge_loss: 1.358 d_loss: 0.360 anomaly_score: 12438.798
# 48/1000 epoch ge_loss: 1.273 d_loss: 0.296 anomaly_score: 13366.639
# 49/1000 epoch ge_loss: 1.247 d_loss: 0.291 anomaly_score: 15023.681
# 50/1000 epoch ge_loss: 1.449 d_loss: 0.310 anomaly_score: 10669.516
# 51/1000 epoch ge_loss: 1.370 d_loss: 0.318 anomaly_score: 11084.557
# 52/1000 epoch ge_loss: 1.395 d_loss: 0.318 anomaly_score: 11527.572
# 53/1000 epoch ge_loss: 1.150 d_loss: 0.381 anomaly_score: 14676.933
# 54/1000 epoch ge_loss: 1.400 d_loss: 0.299 anomaly_score: 11028.290
# 55/1000 epoch ge_loss: 1.524 d_loss: 0.267 anomaly_score: 11132.434
# 56/1000 epoch ge_loss: 1.464 d_loss: 0.293 anomaly_score: 11286.560
# 57/1000 epoch ge_loss: 1.444 d_loss: 0.377 anomaly_score: 11467.187
# 58/1000 epoch ge_loss: 1.315 d_loss: 0.317 anomaly_score: 14198.984
# 59/1000 epoch ge_loss: 1.406 d_loss: 0.338 anomaly_score: 11903.865
# 60/1000 epoch ge_loss: 1.293 d_loss: 0.359 anomaly_score: 12249.820
# 61/1000 epoch ge_loss: 1.230 d_loss: 0.320 anomaly_score: 11293.860
# 62/1000 epoch ge_loss: 1.414 d_loss: 0.316 anomaly_score: 10497.828
# 63/1000 epoch ge_loss: 1.425 d_loss: 0.325 anomaly_score: 10536.627
# 64/1000 epoch ge_loss: 1.294 d_loss: 0.321 anomaly_score: 10767.957
# 65/1000 epoch ge_loss: 1.401 d_loss: 0.315 anomaly_score: 9579.147
# 66/1000 epoch ge_loss: 1.516 d_loss: 0.325 anomaly_score: 10765.253
# 67/1000 epoch ge_loss: 1.444 d_loss: 0.350 anomaly_score: 12046.236
# 68/1000 epoch ge_loss: 1.248 d_loss: 0.343 anomaly_score: 10991.206
# 69/1000 epoch ge_loss: 1.395 d_loss: 0.282 anomaly_score: 10731.177
# 70/1000 epoch ge_loss: 1.445 d_loss: 0.285 anomaly_score: 11598.182
# 71/1000 epoch ge_loss: 1.529 d_loss: 0.319 anomaly_score: 11548.630
# 72/1000 epoch ge_loss: 1.341 d_loss: 0.345 anomaly_score: 11658.497
# 73/1000 epoch ge_loss: 1.633 d_loss: 0.208 anomaly_score: 11535.841
# 74/1000 epoch ge_loss: 1.640 d_loss: 0.273 anomaly_score: 9841.540
# 75/1000 epoch ge_loss: 1.574 d_loss: 0.340 anomaly_score: 13405.205
# 76/1000 epoch ge_loss: 1.472 d_loss: 0.309 anomaly_score: 12012.767
# 77/1000 epoch ge_loss: 1.559 d_loss: 0.269 anomaly_score: 10909.871
# 78/1000 epoch ge_loss: 1.605 d_loss: 0.260 anomaly_score: 10339.198
# 79/1000 epoch ge_loss: 1.578 d_loss: 0.310 anomaly_score: 9429.771
# 80/1000 epoch ge_loss: 1.541 d_loss: 0.299 anomaly_score: 10980.041
# 81/1000 epoch ge_loss: 1.440 d_loss: 0.377 anomaly_score: 10282.340
# 82/1000 epoch ge_loss: 1.476 d_loss: 0.296 anomaly_score: 10911.006
# 83/1000 epoch ge_loss: 1.530 d_loss: 0.284 anomaly_score: 10867.120
# 84/1000 epoch ge_loss: 1.490 d_loss: 0.271 anomaly_score: 9558.576
# 85/1000 epoch ge_loss: 1.561 d_loss: 0.327 anomaly_score: 11387.725
# 86/1000 epoch ge_loss: 1.630 d_loss: 0.283 anomaly_score: 12075.543
# 87/1000 epoch ge_loss: 1.691 d_loss: 0.305 anomaly_score: 10667.197
# 88/1000 epoch ge_loss: 1.573 d_loss: 0.343 anomaly_score: 9698.761
# 89/1000 epoch ge_loss: 1.476 d_loss: 0.248 anomaly_score: 8890.928
# 90/1000 epoch ge_loss: 1.729 d_loss: 0.251 anomaly_score: 9231.195
# 91/1000 epoch ge_loss: 1.708 d_loss: 0.345 anomaly_score: 10012.212
# 92/1000 epoch ge_loss: 1.672 d_loss: 0.279 anomaly_score: 10124.004
# 93/1000 epoch ge_loss: 1.716 d_loss: 0.258 anomaly_score: 10410.688
# 94/1000 epoch ge_loss: 1.766 d_loss: 0.253 anomaly_score: 10080.837
# 95/1000 epoch ge_loss: 1.716 d_loss: 0.311 anomaly_score: 11726.175
# 96/1000 epoch ge_loss: 1.561 d_loss: 0.271 anomaly_score: 10168.776
# 97/1000 epoch ge_loss: 1.751 d_loss: 0.282 anomaly_score: 10053.107
# 98/1000 epoch ge_loss: 1.601 d_loss: 0.244 anomaly_score: 11768.055
# 99/1000 epoch ge_loss: 1.866 d_loss: 0.238 anomaly_score: 9579.219
# 100/1000 epoch ge_loss: 1.945 d_loss: 0.259 anomaly_score: 10456.457
# 101/1000 epoch ge_loss: 1.861 d_loss: 0.297 anomaly_score: 10128.144
# 102/1000 epoch ge_loss: 1.650 d_loss: 0.295 anomaly_score: 9681.686
# 103/1000 epoch ge_loss: 1.764 d_loss: 0.260 anomaly_score: 10141.527
# 104/1000 epoch ge_loss: 1.838 d_loss: 0.216 anomaly_score: 11144.745
# 105/1000 epoch ge_loss: 1.731 d_loss: 0.267 anomaly_score: 10677.861
# 106/1000 epoch ge_loss: 1.883 d_loss: 0.244 anomaly_score: 11256.877
# 107/1000 epoch ge_loss: 1.932 d_loss: 0.267 anomaly_score: 8967.860
# 108/1000 epoch ge_loss: 1.848 d_loss: 0.206 anomaly_score: 10959.757
# 109/1000 epoch ge_loss: 1.957 d_loss: 0.300 anomaly_score: 10971.518
# 110/1000 epoch ge_loss: 1.803 d_loss: 0.286 anomaly_score: 10002.356
# 111/1000 epoch ge_loss: 1.874 d_loss: 0.282 anomaly_score: 10938.174
# 112/1000 epoch ge_loss: 1.802 d_loss: 0.256 anomaly_score: 9780.010
# 113/1000 epoch ge_loss: 1.737 d_loss: 0.272 anomaly_score: 10801.483
# 114/1000 epoch ge_loss: 1.715 d_loss: 0.252 anomaly_score: 10511.384
# 115/1000 epoch ge_loss: 1.830 d_loss: 0.252 anomaly_score: 8914.456
# 116/1000 epoch ge_loss: 1.973 d_loss: 0.264 anomaly_score: 8613.902
# 117/1000 epoch ge_loss: 1.901 d_loss: 0.281 anomaly_score: 9099.866
# 118/1000 epoch ge_loss: 1.877 d_loss: 0.227 anomaly_score: 8795.718
# 119/1000 epoch ge_loss: 2.009 d_loss: 0.184 anomaly_score: 8526.445
# 120/1000 epoch ge_loss: 2.134 d_loss: 0.251 anomaly_score: 8848.881
# 121/1000 epoch ge_loss: 1.871 d_loss: 0.231 anomaly_score: 9822.615
# 122/1000 epoch ge_loss: 1.984 d_loss: 0.250 anomaly_score: 10458.826
# 123/1000 epoch ge_loss: 2.138 d_loss: 0.219 anomaly_score: 9598.949
# 124/1000 epoch ge_loss: 2.192 d_loss: 0.233 anomaly_score: 8842.572
# 125/1000 epoch ge_loss: 1.815 d_loss: 0.270 anomaly_score: 8921.549
# 126/1000 epoch ge_loss: 2.110 d_loss: 0.192 anomaly_score: 8515.237
# 127/1000 epoch ge_loss: 2.140 d_loss: 0.245 anomaly_score: 10879.569
# 128/1000 epoch ge_loss: 1.926 d_loss: 0.267 anomaly_score: 10458.625
# 129/1000 epoch ge_loss: 1.857 d_loss: 0.301 anomaly_score: 8363.694
# 130/1000 epoch ge_loss: 1.927 d_loss: 0.200 anomaly_score: 10642.438
# 131/1000 epoch ge_loss: 2.067 d_loss: 0.247 anomaly_score: 13113.753
# 132/1000 epoch ge_loss: 1.884 d_loss: 0.260 anomaly_score: 9173.422
# 133/1000 epoch ge_loss: 1.959 d_loss: 0.205 anomaly_score: 11017.614
# 134/1000 epoch ge_loss: 2.040 d_loss: 0.290 anomaly_score: 13340.596
# 135/1000 epoch ge_loss: 1.913 d_loss: 0.238 anomaly_score: 10818.849
# 136/1000 epoch ge_loss: 2.022 d_loss: 0.211 anomaly_score: 9926.714
# 137/1000 epoch ge_loss: 2.043 d_loss: 0.212 anomaly_score: 12498.919
# 138/1000 epoch ge_loss: 2.106 d_loss: 0.192 anomaly_score: 11565.870
# 139/1000 epoch ge_loss: 2.126 d_loss: 0.250 anomaly_score: 9189.123
# 140/1000 epoch ge_loss: 2.086 d_loss: 0.206 anomaly_score: 10779.850
# 141/1000 epoch ge_loss: 2.151 d_loss: 0.211 anomaly_score: 11922.546
# 142/1000 epoch ge_loss: 2.151 d_loss: 0.255 anomaly_score: 9934.189
# 143/1000 epoch ge_loss: 2.035 d_loss: 0.206 anomaly_score: 9866.914
# 144/1000 epoch ge_loss: 2.272 d_loss: 0.248 anomaly_score: 9254.331
# 145/1000 epoch ge_loss: 2.222 d_loss: 0.241 anomaly_score: 13635.283
# 146/1000 epoch ge_loss: 2.119 d_loss: 0.253 anomaly_score: 9143.887
# 147/1000 epoch ge_loss: 1.877 d_loss: 0.277 anomaly_score: 9817.581
# 148/1000 epoch ge_loss: 2.016 d_loss: 0.222 anomaly_score: 10568.480
# 149/1000 epoch ge_loss: 2.125 d_loss: 0.202 anomaly_score: 8880.408
# 150/1000 epoch ge_loss: 2.200 d_loss: 0.187 anomaly_score: 10965.351
# 151/1000 epoch ge_loss: 2.147 d_loss: 0.235 anomaly_score: 9389.491
# 152/1000 epoch ge_loss: 2.302 d_loss: 0.171 anomaly_score: 9033.743
# 153/1000 epoch ge_loss: 2.140 d_loss: 0.213 anomaly_score: 9666.523
# 154/1000 epoch ge_loss: 2.207 d_loss: 0.176 anomaly_score: 10700.348
# 155/1000 epoch ge_loss: 2.232 d_loss: 0.180 anomaly_score: 8218.364
# 156/1000 epoch ge_loss: 2.347 d_loss: 0.216 anomaly_score: 8131.154
# 157/1000 epoch ge_loss: 2.332 d_loss: 0.159 anomaly_score: 9436.215
# 158/1000 epoch ge_loss: 2.451 d_loss: 0.202 anomaly_score: 9769.512
# 159/1000 epoch ge_loss: 2.243 d_loss: 0.212 anomaly_score: 9387.487
# 160/1000 epoch ge_loss: 2.169 d_loss: 0.291 anomaly_score: 9339.277
# 161/1000 epoch ge_loss: 2.150 d_loss: 0.152 anomaly_score: 7652.589
# 162/1000 epoch ge_loss: 2.348 d_loss: 0.175 anomaly_score: 7961.943
# 163/1000 epoch ge_loss: 2.321 d_loss: 0.249 anomaly_score: 8611.692
# 164/1000 epoch ge_loss: 2.139 d_loss: 0.219 anomaly_score: 9039.794
# 165/1000 epoch ge_loss: 2.268 d_loss: 0.295 anomaly_score: 8723.803
# 166/1000 epoch ge_loss: 2.174 d_loss: 0.185 anomaly_score: 9626.159
# 167/1000 epoch ge_loss: 2.238 d_loss: 0.187 anomaly_score: 8738.294
# 168/1000 epoch ge_loss: 2.180 d_loss: 0.194 anomaly_score: 9645.216
# 169/1000 epoch ge_loss: 2.291 d_loss: 0.198 anomaly_score: 10690.808
# 170/1000 epoch ge_loss: 2.292 d_loss: 0.188 anomaly_score: 8907.385
# 171/1000 epoch ge_loss: 2.312 d_loss: 0.228 anomaly_score: 7781.420
# 172/1000 epoch ge_loss: 2.189 d_loss: 0.228 anomaly_score: 9411.933
# 173/1000 epoch ge_loss: 2.400 d_loss: 0.204 anomaly_score: 10448.353
# 174/1000 epoch ge_loss: 2.473 d_loss: 0.167 anomaly_score: 9829.342
# 175/1000 epoch ge_loss: 2.632 d_loss: 0.224 anomaly_score: 10846.872
# 176/1000 epoch ge_loss: 2.242 d_loss: 0.233 anomaly_score: 9228.217
# 177/1000 epoch ge_loss: 2.266 d_loss: 0.260 anomaly_score: 11247.853
# 178/1000 epoch ge_loss: 2.197 d_loss: 0.206 anomaly_score: 10698.631
# 179/1000 epoch ge_loss: 2.298 d_loss: 0.236 anomaly_score: 9270.014
# 180/1000 epoch ge_loss: 2.220 d_loss: 0.216 anomaly_score: 7446.184
# 181/1000 epoch ge_loss: 2.107 d_loss: 0.170 anomaly_score: 9116.507
# 182/1000 epoch ge_loss: 2.125 d_loss: 0.233 anomaly_score: 10339.733
# 183/1000 epoch ge_loss: 2.205 d_loss: 0.211 anomaly_score: 11247.141
# 184/1000 epoch ge_loss: 2.239 d_loss: 0.215 anomaly_score: 8872.609
# 185/1000 epoch ge_loss: 2.282 d_loss: 0.234 anomaly_score: 8344.199
# 186/1000 epoch ge_loss: 2.200 d_loss: 0.214 anomaly_score: 10312.451
# 187/1000 epoch ge_loss: 2.146 d_loss: 0.244 anomaly_score: 10166.274
# 188/1000 epoch ge_loss: 2.237 d_loss: 0.186 anomaly_score: 10529.334
# 189/1000 epoch ge_loss: 2.334 d_loss: 0.195 anomaly_score: 9702.067
# 190/1000 epoch ge_loss: 2.301 d_loss: 0.249 anomaly_score: 10947.841
# 191/1000 epoch ge_loss: 2.152 d_loss: 0.220 anomaly_score: 11003.265
# 192/1000 epoch ge_loss: 2.254 d_loss: 0.156 anomaly_score: 9988.865
# 193/1000 epoch ge_loss: 2.199 d_loss: 0.201 anomaly_score: 9398.103
# 194/1000 epoch ge_loss: 2.267 d_loss: 0.214 anomaly_score: 9335.570
# 195/1000 epoch ge_loss: 2.367 d_loss: 0.226 anomaly_score: 8849.973
# 196/1000 epoch ge_loss: 2.296 d_loss: 0.192 anomaly_score: 7840.768
# 197/1000 epoch ge_loss: 2.286 d_loss: 0.216 anomaly_score: 8821.247
# 198/1000 epoch ge_loss: 2.172 d_loss: 0.145 anomaly_score: 10768.343
# 199/1000 epoch ge_loss: 2.378 d_loss: 0.252 anomaly_score: 8473.373
# 200/1000 epoch ge_loss: 2.333 d_loss: 0.213 anomaly_score: 8523.180
# 201/1000 epoch ge_loss: 2.185 d_loss: 0.240 anomaly_score: 9598.872
# 202/1000 epoch ge_loss: 2.296 d_loss: 0.204 anomaly_score: 10721.283
# 203/1000 epoch ge_loss: 2.252 d_loss: 0.178 anomaly_score: 11373.269
# 204/1000 epoch ge_loss: 2.326 d_loss: 0.175 anomaly_score: 11615.831
# 205/1000 epoch ge_loss: 2.208 d_loss: 0.249 anomaly_score: 9315.113
# 206/1000 epoch ge_loss: 2.366 d_loss: 0.169 anomaly_score: 8377.507
# 207/1000 epoch ge_loss: 2.252 d_loss: 0.180 anomaly_score: 11236.977
# 208/1000 epoch ge_loss: 2.404 d_loss: 0.172 anomaly_score: 8627.166
# 209/1000 epoch ge_loss: 2.450 d_loss: 0.201 anomaly_score: 8170.591
# 210/1000 epoch ge_loss: 2.516 d_loss: 0.178 anomaly_score: 8957.890
# 211/1000 epoch ge_loss: 2.458 d_loss: 0.155 anomaly_score: 9463.303
# 212/1000 epoch ge_loss: 2.451 d_loss: 0.203 anomaly_score: 10374.672
# 213/1000 epoch ge_loss: 2.580 d_loss: 0.181 anomaly_score: 9237.310
# 214/1000 epoch ge_loss: 2.366 d_loss: 0.209 anomaly_score: 9945.787
# 215/1000 epoch ge_loss: 2.228 d_loss: 0.197 anomaly_score: 9090.447
# 216/1000 epoch ge_loss: 2.423 d_loss: 0.152 anomaly_score: 9559.963
# 217/1000 epoch ge_loss: 2.544 d_loss: 0.225 anomaly_score: 8943.944
# 218/1000 epoch ge_loss: 2.423 d_loss: 0.162 anomaly_score: 10917.378
# 219/1000 epoch ge_loss: 2.766 d_loss: 0.168 anomaly_score: 11951.783
# 220/1000 epoch ge_loss: 2.598 d_loss: 0.135 anomaly_score: 8706.897
# 221/1000 epoch ge_loss: 2.580 d_loss: 0.213 anomaly_score: 9430.181
# 222/1000 epoch ge_loss: 2.490 d_loss: 0.196 anomaly_score: 10167.845
# 223/1000 epoch ge_loss: 2.359 d_loss: 0.237 anomaly_score: 7698.201
# 224/1000 epoch ge_loss: 2.432 d_loss: 0.212 anomaly_score: 9947.930
# 225/1000 epoch ge_loss: 2.378 d_loss: 0.286 anomaly_score: 9032.576
# 226/1000 epoch ge_loss: 2.207 d_loss: 0.215 anomaly_score: 12230.476
# 227/1000 epoch ge_loss: 2.328 d_loss: 0.165 anomaly_score: 10001.907
# 228/1000 epoch ge_loss: 2.176 d_loss: 0.277 anomaly_score: 7467.267
# 229/1000 epoch ge_loss: 2.165 d_loss: 0.181 anomaly_score: 7981.649
# 230/1000 epoch ge_loss: 2.184 d_loss: 0.195 anomaly_score: 8299.070
# 231/1000 epoch ge_loss: 2.292 d_loss: 0.157 anomaly_score: 8674.971
# 232/1000 epoch ge_loss: 2.371 d_loss: 0.174 anomaly_score: 8199.992
# 233/1000 epoch ge_loss: 2.461 d_loss: 0.160 anomaly_score: 6936.288
# 234/1000 epoch ge_loss: 2.549 d_loss: 0.182 anomaly_score: 7422.134
# 235/1000 epoch ge_loss: 2.424 d_loss: 0.224 anomaly_score: 8704.685
# 236/1000 epoch ge_loss: 2.487 d_loss: 0.175 anomaly_score: 8935.740
# 237/1000 epoch ge_loss: 2.395 d_loss: 0.195 anomaly_score: 10327.923
# 238/1000 epoch ge_loss: 2.483 d_loss: 0.139 anomaly_score: 11508.365
# 239/1000 epoch ge_loss: 2.496 d_loss: 0.247 anomaly_score: 8269.181
# 240/1000 epoch ge_loss: 2.309 d_loss: 0.194 anomaly_score: 8109.740
# 241/1000 epoch ge_loss: 2.341 d_loss: 0.199 anomaly_score: 8327.548
# 242/1000 epoch ge_loss: 2.399 d_loss: 0.161 anomaly_score: 9982.498
# 243/1000 epoch ge_loss: 2.532 d_loss: 0.166 anomaly_score: 12930.539
# 244/1000 epoch ge_loss: 2.483 d_loss: 0.197 anomaly_score: 10438.315
# 245/1000 epoch ge_loss: 2.535 d_loss: 0.166 anomaly_score: 10474.616
# 246/1000 epoch ge_loss: 2.635 d_loss: 0.202 anomaly_score: 8477.101
# 247/1000 epoch ge_loss: 2.472 d_loss: 0.220 anomaly_score: 7795.867
# 248/1000 epoch ge_loss: 2.452 d_loss: 0.222 anomaly_score: 7563.340
# 249/1000 epoch ge_loss: 2.431 d_loss: 0.200 anomaly_score: 8503.145
# 250/1000 epoch ge_loss: 2.419 d_loss: 0.155 anomaly_score: 9709.635
# 251/1000 epoch ge_loss: 2.559 d_loss: 0.134 anomaly_score: 8866.314
# 252/1000 epoch ge_loss: 2.569 d_loss: 0.185 anomaly_score: 8414.326
# 253/1000 epoch ge_loss: 2.510 d_loss: 0.183 anomaly_score: 7272.770
# 254/1000 epoch ge_loss: 2.618 d_loss: 0.186 anomaly_score: 8624.868
# 255/1000 epoch ge_loss: 2.551 d_loss: 0.175 anomaly_score: 7921.441
# 256/1000 epoch ge_loss: 2.520 d_loss: 0.177 anomaly_score: 8142.138
# 257/1000 epoch ge_loss: 2.577 d_loss: 0.214 anomaly_score: 8141.162
# 258/1000 epoch ge_loss: 2.273 d_loss: 0.208 anomaly_score: 8165.631
# 259/1000 epoch ge_loss: 2.400 d_loss: 0.157 anomaly_score: 7856.848
# 260/1000 epoch ge_loss: 2.490 d_loss: 0.158 anomaly_score: 9186.418
# 261/1000 epoch ge_loss: 2.626 d_loss: 0.167 anomaly_score: 8493.904
# 262/1000 epoch ge_loss: 2.555 d_loss: 0.183 anomaly_score: 10661.630
# 263/1000 epoch ge_loss: 2.491 d_loss: 0.187 anomaly_score: 11080.891
# 264/1000 epoch ge_loss: 2.616 d_loss: 0.184 anomaly_score: 9237.857
# 265/1000 epoch ge_loss: 2.657 d_loss: 0.125 anomaly_score: 7396.794
# 266/1000 epoch ge_loss: 2.750 d_loss: 0.181 anomaly_score: 8992.593
# 267/1000 epoch ge_loss: 2.538 d_loss: 0.186 anomaly_score: 8644.138
# 268/1000 epoch ge_loss: 2.708 d_loss: 0.167 anomaly_score: 10125.473
# 269/1000 epoch ge_loss: 2.771 d_loss: 0.200 anomaly_score: 13090.828
# 270/1000 epoch ge_loss: 2.493 d_loss: 0.191 anomaly_score: 13193.956
# 271/1000 epoch ge_loss: 2.526 d_loss: 0.203 anomaly_score: 7489.461
# 272/1000 epoch ge_loss: 2.496 d_loss: 0.210 anomaly_score: 8633.095
# 273/1000 epoch ge_loss: 2.557 d_loss: 0.130 anomaly_score: 10512.884
# 274/1000 epoch ge_loss: 2.694 d_loss: 0.124 anomaly_score: 13062.588
# 275/1000 epoch ge_loss: 2.803 d_loss: 0.175 anomaly_score: 11747.188
# 276/1000 epoch ge_loss: 2.489 d_loss: 0.179 anomaly_score: 7243.489
# 277/1000 epoch ge_loss: 2.671 d_loss: 0.183 anomaly_score: 8018.597
# 278/1000 epoch ge_loss: 2.414 d_loss: 0.177 anomaly_score: 6964.255
# 279/1000 epoch ge_loss: 2.535 d_loss: 0.214 anomaly_score: 10264.900
# 280/1000 epoch ge_loss: 2.555 d_loss: 0.119 anomaly_score: 8241.389
# 281/1000 epoch ge_loss: 2.673 d_loss: 0.111 anomaly_score: 9326.735
# 282/1000 epoch ge_loss: 2.648 d_loss: 0.205 anomaly_score: 8616.910
# 283/1000 epoch ge_loss: 2.725 d_loss: 0.247 anomaly_score: 10032.009
# 284/1000 epoch ge_loss: 2.427 d_loss: 0.162 anomaly_score: 9855.210
# 285/1000 epoch ge_loss: 2.534 d_loss: 0.163 anomaly_score: 9315.893
# 286/1000 epoch ge_loss: 2.651 d_loss: 0.162 anomaly_score: 9660.782
# 287/1000 epoch ge_loss: 2.540 d_loss: 0.151 anomaly_score: 10096.879
# 288/1000 epoch ge_loss: 2.707 d_loss: 0.121 anomaly_score: 8294.305
# 289/1000 epoch ge_loss: 2.859 d_loss: 0.131 anomaly_score: 9137.924
# 290/1000 epoch ge_loss: 2.872 d_loss: 0.170 anomaly_score: 12043.417
# 291/1000 epoch ge_loss: 2.927 d_loss: 0.192 anomaly_score: 9215.326
# 292/1000 epoch ge_loss: 2.641 d_loss: 0.172 anomaly_score: 8429.863
# 293/1000 epoch ge_loss: 2.720 d_loss: 0.162 anomaly_score: 8216.502
# 294/1000 epoch ge_loss: 2.707 d_loss: 0.200 anomaly_score: 10977.814
# 295/1000 epoch ge_loss: 2.797 d_loss: 0.115 anomaly_score: 11667.649
# 296/1000 epoch ge_loss: 2.797 d_loss: 0.149 anomaly_score: 9378.254
# 297/1000 epoch ge_loss: 2.676 d_loss: 0.157 anomaly_score: 8942.556
# 298/1000 epoch ge_loss: 2.804 d_loss: 0.159 anomaly_score: 7621.795
# 299/1000 epoch ge_loss: 2.585 d_loss: 0.129 anomaly_score: 8809.227
# 300/1000 epoch ge_loss: 2.721 d_loss: 0.149 anomaly_score: 9719.903
# 301/1000 epoch ge_loss: 2.822 d_loss: 0.098 anomaly_score: 9467.047
# 302/1000 epoch ge_loss: 2.729 d_loss: 0.148 anomaly_score: 11183.699
# 303/1000 epoch ge_loss: 2.864 d_loss: 0.125 anomaly_score: 9685.548
# 304/1000 epoch ge_loss: 2.859 d_loss: 0.145 anomaly_score: 9546.002
# 305/1000 epoch ge_loss: 2.684 d_loss: 0.140 anomaly_score: 8061.161
# 306/1000 epoch ge_loss: 2.866 d_loss: 0.147 anomaly_score: 8366.029
# 307/1000 epoch ge_loss: 2.822 d_loss: 0.172 anomaly_score: 9133.514
# 308/1000 epoch ge_loss: 3.139 d_loss: 0.188 anomaly_score: 8994.108
# 309/1000 epoch ge_loss: 2.630 d_loss: 0.133 anomaly_score: 8664.316
# 310/1000 epoch ge_loss: 2.960 d_loss: 0.203 anomaly_score: 9101.984
# 311/1000 epoch ge_loss: 2.710 d_loss: 0.147 anomaly_score: 9926.316
# 312/1000 epoch ge_loss: 2.586 d_loss: 0.160 anomaly_score: 8391.429
# 313/1000 epoch ge_loss: 2.498 d_loss: 0.192 anomaly_score: 7794.156
# 314/1000 epoch ge_loss: 2.721 d_loss: 0.135 anomaly_score: 7934.485
# 315/1000 epoch ge_loss: 2.755 d_loss: 0.173 anomaly_score: 8416.122
# 316/1000 epoch ge_loss: 2.676 d_loss: 0.156 anomaly_score: 8219.781
# 317/1000 epoch ge_loss: 2.539 d_loss: 0.170 anomaly_score: 9341.646
# 318/1000 epoch ge_loss: 2.649 d_loss: 0.107 anomaly_score: 9473.315
# 319/1000 epoch ge_loss: 2.709 d_loss: 0.168 anomaly_score: 9936.312
# 320/1000 epoch ge_loss: 2.811 d_loss: 0.138 anomaly_score: 9477.285
# 321/1000 epoch ge_loss: 2.896 d_loss: 0.148 anomaly_score: 8219.544
# 322/1000 epoch ge_loss: 2.832 d_loss: 0.193 anomaly_score: 10310.305
# 323/1000 epoch ge_loss: 2.754 d_loss: 0.145 anomaly_score: 10325.305
# 324/1000 epoch ge_loss: 2.892 d_loss: 0.120 anomaly_score: 7379.252
# 325/1000 epoch ge_loss: 2.802 d_loss: 0.113 anomaly_score: 8282.534
# 326/1000 epoch ge_loss: 3.012 d_loss: 0.165 anomaly_score: 7473.853
# 327/1000 epoch ge_loss: 2.863 d_loss: 0.207 anomaly_score: 8622.786
# 328/1000 epoch ge_loss: 2.815 d_loss: 0.153 anomaly_score: 9540.972
# 329/1000 epoch ge_loss: 2.769 d_loss: 0.161 anomaly_score: 8982.183
# 330/1000 epoch ge_loss: 2.595 d_loss: 0.156 anomaly_score: 9103.590
# 331/1000 epoch ge_loss: 2.771 d_loss: 0.145 anomaly_score: 8754.436
# 332/1000 epoch ge_loss: 2.838 d_loss: 0.157 anomaly_score: 9348.402
# 333/1000 epoch ge_loss: 3.038 d_loss: 0.124 anomaly_score: 8543.609
# 334/1000 epoch ge_loss: 2.992 d_loss: 0.139 anomaly_score: 7192.359
# 335/1000 epoch ge_loss: 2.960 d_loss: 0.124 anomaly_score: 9750.415
# 336/1000 epoch ge_loss: 3.041 d_loss: 0.107 anomaly_score: 11542.230
# 337/1000 epoch ge_loss: 2.840 d_loss: 0.167 anomaly_score: 8352.652
# 338/1000 epoch ge_loss: 2.879 d_loss: 0.147 anomaly_score: 7825.512
# 339/1000 epoch ge_loss: 2.837 d_loss: 0.189 anomaly_score: 7378.527
# 340/1000 epoch ge_loss: 2.651 d_loss: 0.129 anomaly_score: 8096.701
# 341/1000 epoch ge_loss: 2.931 d_loss: 0.149 anomaly_score: 8930.902
# 342/1000 epoch ge_loss: 2.963 d_loss: 0.122 anomaly_score: 9586.762
# 343/1000 epoch ge_loss: 3.078 d_loss: 0.095 anomaly_score: 9086.916
# 344/1000 epoch ge_loss: 2.890 d_loss: 0.169 anomaly_score: 8954.024
# 345/1000 epoch ge_loss: 3.003 d_loss: 0.139 anomaly_score: 8169.841
# 346/1000 epoch ge_loss: 2.899 d_loss: 0.160 anomaly_score: 9022.051
# 347/1000 epoch ge_loss: 2.885 d_loss: 0.170 anomaly_score: 14250.036
# 348/1000 epoch ge_loss: 2.996 d_loss: 0.119 anomaly_score: 9046.433
# 349/1000 epoch ge_loss: 2.902 d_loss: 0.139 anomaly_score: 8507.416
# 350/1000 epoch ge_loss: 2.701 d_loss: 0.111 anomaly_score: 9596.756
# 351/1000 epoch ge_loss: 2.997 d_loss: 0.123 anomaly_score: 11520.246
# 352/1000 epoch ge_loss: 2.994 d_loss: 0.165 anomaly_score: 11850.981
# 353/1000 epoch ge_loss: 2.984 d_loss: 0.130 anomaly_score: 8979.753
# 354/1000 epoch ge_loss: 3.029 d_loss: 0.157 anomaly_score: 8643.721
# 355/1000 epoch ge_loss: 3.005 d_loss: 0.134 anomaly_score: 9217.224
# 356/1000 epoch ge_loss: 3.024 d_loss: 0.120 anomaly_score: 8285.342
# 357/1000 epoch ge_loss: 3.158 d_loss: 0.153 anomaly_score: 9391.790
# 358/1000 epoch ge_loss: 2.862 d_loss: 0.138 anomaly_score: 10473.523
# 359/1000 epoch ge_loss: 2.857 d_loss: 0.131 anomaly_score: 11265.337
# 360/1000 epoch ge_loss: 2.639 d_loss: 0.177 anomaly_score: 8996.412
# 361/1000 epoch ge_loss: 2.656 d_loss: 0.170 anomaly_score: 7712.546
# 362/1000 epoch ge_loss: 2.991 d_loss: 0.148 anomaly_score: 8008.049
# 363/1000 epoch ge_loss: 2.800 d_loss: 0.133 anomaly_score: 7944.562
# 364/1000 epoch ge_loss: 2.907 d_loss: 0.115 anomaly_score: 10076.579
# 365/1000 epoch ge_loss: 3.029 d_loss: 0.167 anomaly_score: 12422.546
# 366/1000 epoch ge_loss: 2.898 d_loss: 0.201 anomaly_score: 10417.383
# 367/1000 epoch ge_loss: 3.129 d_loss: 0.145 anomaly_score: 7402.610
# 368/1000 epoch ge_loss: 2.821 d_loss: 0.131 anomaly_score: 8056.381
# 369/1000 epoch ge_loss: 3.059 d_loss: 0.157 anomaly_score: 7924.602
# 370/1000 epoch ge_loss: 2.992 d_loss: 0.131 anomaly_score: 8434.870
# 371/1000 epoch ge_loss: 2.823 d_loss: 0.162 anomaly_score: 6976.941
# 372/1000 epoch ge_loss: 3.134 d_loss: 0.104 anomaly_score: 6321.962
# 373/1000 epoch ge_loss: 2.754 d_loss: 0.134 anomaly_score: 7771.562
# 374/1000 epoch ge_loss: 2.790 d_loss: 0.149 anomaly_score: 8483.956
# 375/1000 epoch ge_loss: 2.726 d_loss: 0.158 anomaly_score: 11224.500
# 376/1000 epoch ge_loss: 2.654 d_loss: 0.154 anomaly_score: 11979.835
# 377/1000 epoch ge_loss: 2.972 d_loss: 0.157 anomaly_score: 8383.133
# 378/1000 epoch ge_loss: 2.773 d_loss: 0.161 anomaly_score: 9778.712
# 379/1000 epoch ge_loss: 3.192 d_loss: 0.133 anomaly_score: 9160.403
# 380/1000 epoch ge_loss: 2.842 d_loss: 0.130 anomaly_score: 10800.024
# 381/1000 epoch ge_loss: 3.023 d_loss: 0.102 anomaly_score: 8729.334
# 382/1000 epoch ge_loss: 3.064 d_loss: 0.135 anomaly_score: 9187.268
# 383/1000 epoch ge_loss: 2.840 d_loss: 0.167 anomaly_score: 9965.646
# 384/1000 epoch ge_loss: 3.101 d_loss: 0.111 anomaly_score: 9187.654
# 385/1000 epoch ge_loss: 2.955 d_loss: 0.152 anomaly_score: 8569.194
# 386/1000 epoch ge_loss: 2.971 d_loss: 0.142 anomaly_score: 8639.886
# 387/1000 epoch ge_loss: 2.770 d_loss: 0.154 anomaly_score: 10643.861
# 388/1000 epoch ge_loss: 2.829 d_loss: 0.129 anomaly_score: 11346.153
# 389/1000 epoch ge_loss: 2.942 d_loss: 0.122 anomaly_score: 9746.397
# 390/1000 epoch ge_loss: 3.096 d_loss: 0.125 anomaly_score: 8743.394
# 391/1000 epoch ge_loss: 3.029 d_loss: 0.163 anomaly_score: 8725.342
# 392/1000 epoch ge_loss: 3.028 d_loss: 0.100 anomaly_score: 8294.359
# 393/1000 epoch ge_loss: 2.917 d_loss: 0.132 anomaly_score: 7220.825
# 394/1000 epoch ge_loss: 3.247 d_loss: 0.132 anomaly_score: 6639.787
# 395/1000 epoch ge_loss: 3.164 d_loss: 0.093 anomaly_score: 6498.194
# 396/1000 epoch ge_loss: 3.152 d_loss: 0.150 anomaly_score: 7581.159
# 397/1000 epoch ge_loss: 3.082 d_loss: 0.141 anomaly_score: 10288.205
# 398/1000 epoch ge_loss: 3.161 d_loss: 0.136 anomaly_score: 9547.359
# 399/1000 epoch ge_loss: 3.261 d_loss: 0.128 anomaly_score: 8380.109
# 400/1000 epoch ge_loss: 3.214 d_loss: 0.137 anomaly_score: 8808.389
# 401/1000 epoch ge_loss: 3.303 d_loss: 0.144 anomaly_score: 7364.047
# 402/1000 epoch ge_loss: 3.087 d_loss: 0.120 anomaly_score: 7179.484
# 403/1000 epoch ge_loss: 3.132 d_loss: 0.163 anomaly_score: 8407.633
# 404/1000 epoch ge_loss: 3.107 d_loss: 0.100 anomaly_score: 8009.901
# 405/1000 epoch ge_loss: 3.232 d_loss: 0.159 anomaly_score: 9081.051
# 406/1000 epoch ge_loss: 3.078 d_loss: 0.115 anomaly_score: 9217.390
# 407/1000 epoch ge_loss: 3.155 d_loss: 0.121 anomaly_score: 7797.169
# 408/1000 epoch ge_loss: 3.221 d_loss: 0.114 anomaly_score: 7973.812
# 409/1000 epoch ge_loss: 3.078 d_loss: 0.117 anomaly_score: 6448.001
# 410/1000 epoch ge_loss: 2.899 d_loss: 0.147 anomaly_score: 6869.871
# 411/1000 epoch ge_loss: 3.036 d_loss: 0.123 anomaly_score: 7532.279
# 412/1000 epoch ge_loss: 3.066 d_loss: 0.125 anomaly_score: 6708.257
# 413/1000 epoch ge_loss: 3.149 d_loss: 0.162 anomaly_score: 8147.622
# 414/1000 epoch ge_loss: 3.130 d_loss: 0.088 anomaly_score: 8914.442
# 415/1000 epoch ge_loss: 3.239 d_loss: 0.130 anomaly_score: 8176.082
# 416/1000 epoch ge_loss: 2.941 d_loss: 0.183 anomaly_score: 7586.617
# 417/1000 epoch ge_loss: 2.930 d_loss: 0.203 anomaly_score: 6671.576
# 418/1000 epoch ge_loss: 3.069 d_loss: 0.138 anomaly_score: 7814.058
# 419/1000 epoch ge_loss: 2.920 d_loss: 0.125 anomaly_score: 8542.629
# 420/1000 epoch ge_loss: 3.030 d_loss: 0.173 anomaly_score: 8329.775
# 421/1000 epoch ge_loss: 2.934 d_loss: 0.124 anomaly_score: 8416.529
# 422/1000 epoch ge_loss: 2.978 d_loss: 0.127 anomaly_score: 9548.450
# 423/1000 epoch ge_loss: 3.203 d_loss: 0.144 anomaly_score: 9028.832
# 424/1000 epoch ge_loss: 3.185 d_loss: 0.138 anomaly_score: 9104.525
# 425/1000 epoch ge_loss: 2.875 d_loss: 0.137 anomaly_score: 8169.455
# 426/1000 epoch ge_loss: 2.834 d_loss: 0.150 anomaly_score: 7849.857
# 427/1000 epoch ge_loss: 2.965 d_loss: 0.129 anomaly_score: 9388.553
# 428/1000 epoch ge_loss: 3.116 d_loss: 0.128 anomaly_score: 10047.114
# 429/1000 epoch ge_loss: 2.956 d_loss: 0.105 anomaly_score: 7659.263
# 430/1000 epoch ge_loss: 3.141 d_loss: 0.152 anomaly_score: 8841.696
# 431/1000 epoch ge_loss: 3.099 d_loss: 0.094 anomaly_score: 8285.542
# 432/1000 epoch ge_loss: 3.300 d_loss: 0.108 anomaly_score: 6937.454
# 433/1000 epoch ge_loss: 3.218 d_loss: 0.156 anomaly_score: 6938.430
# 434/1000 epoch ge_loss: 3.156 d_loss: 0.104 anomaly_score: 7095.213
# 435/1000 epoch ge_loss: 3.162 d_loss: 0.120 anomaly_score: 8181.685
# 436/1000 epoch ge_loss: 3.018 d_loss: 0.130 anomaly_score: 11774.271
# 437/1000 epoch ge_loss: 3.223 d_loss: 0.098 anomaly_score: 9554.491
# 438/1000 epoch ge_loss: 3.064 d_loss: 0.150 anomaly_score: 7435.743
# 439/1000 epoch ge_loss: 3.097 d_loss: 0.114 anomaly_score: 8957.001
# 440/1000 epoch ge_loss: 3.238 d_loss: 0.091 anomaly_score: 8816.608
# 441/1000 epoch ge_loss: 3.161 d_loss: 0.139 anomaly_score: 9908.997
# 442/1000 epoch ge_loss: 3.790 d_loss: 0.131 anomaly_score: 11707.053
# 443/1000 epoch ge_loss: 3.367 d_loss: 0.107 anomaly_score: 8409.095
# 444/1000 epoch ge_loss: 3.075 d_loss: 0.128 anomaly_score: 7800.287
# 445/1000 epoch ge_loss: 3.170 d_loss: 0.134 anomaly_score: 7150.736
# 446/1000 epoch ge_loss: 3.270 d_loss: 0.110 anomaly_score: 6841.309
# 447/1000 epoch ge_loss: 3.251 d_loss: 0.130 anomaly_score: 7525.002
# 448/1000 epoch ge_loss: 3.339 d_loss: 0.096 anomaly_score: 6791.199
# 449/1000 epoch ge_loss: 3.373 d_loss: 0.109 anomaly_score: 7909.274
# 450/1000 epoch ge_loss: 3.134 d_loss: 0.135 anomaly_score: 9751.999
# 451/1000 epoch ge_loss: 3.136 d_loss: 0.116 anomaly_score: 8690.127
# 452/1000 epoch ge_loss: 3.163 d_loss: 0.130 anomaly_score: 8128.469
# 453/1000 epoch ge_loss: 3.164 d_loss: 0.099 anomaly_score: 8088.153
# 454/1000 epoch ge_loss: 3.300 d_loss: 0.107 anomaly_score: 8050.551
# 455/1000 epoch ge_loss: 3.345 d_loss: 0.125 anomaly_score: 9565.460
# 456/1000 epoch ge_loss: 3.394 d_loss: 0.125 anomaly_score: 10810.866
# 457/1000 epoch ge_loss: 3.186 d_loss: 0.115 anomaly_score: 11359.874
# 458/1000 epoch ge_loss: 3.101 d_loss: 0.135 anomaly_score: 10212.324
# 459/1000 epoch ge_loss: 3.189 d_loss: 0.157 anomaly_score: 9175.934
# 460/1000 epoch ge_loss: 3.046 d_loss: 0.150 anomaly_score: 8401.360
# 461/1000 epoch ge_loss: 3.158 d_loss: 0.077 anomaly_score: 7742.638
# 462/1000 epoch ge_loss: 3.130 d_loss: 0.120 anomaly_score: 8469.273
# 463/1000 epoch ge_loss: 3.121 d_loss: 0.129 anomaly_score: 7857.751
# 464/1000 epoch ge_loss: 3.454 d_loss: 0.156 anomaly_score: 6827.127
# 465/1000 epoch ge_loss: 3.144 d_loss: 0.099 anomaly_score: 10467.937
# 466/1000 epoch ge_loss: 3.234 d_loss: 0.107 anomaly_score: 10963.656
# 467/1000 epoch ge_loss: 3.356 d_loss: 0.119 anomaly_score: 9782.470
# 468/1000 epoch ge_loss: 3.323 d_loss: 0.116 anomaly_score: 9014.966
# 469/1000 epoch ge_loss: 3.338 d_loss: 0.127 anomaly_score: 8424.419
# 470/1000 epoch ge_loss: 3.171 d_loss: 0.130 anomaly_score: 7419.967
# 471/1000 epoch ge_loss: 3.117 d_loss: 0.101 anomaly_score: 7457.718
# 472/1000 epoch ge_loss: 3.701 d_loss: 0.133 anomaly_score: 7654.563
# 473/1000 epoch ge_loss: 3.362 d_loss: 0.120 anomaly_score: 9105.207
# 474/1000 epoch ge_loss: 3.553 d_loss: 0.128 anomaly_score: 7897.924
# 475/1000 epoch ge_loss: 3.201 d_loss: 0.090 anomaly_score: 7962.482
# 476/1000 epoch ge_loss: 3.146 d_loss: 0.179 anomaly_score: 8896.310
# 477/1000 epoch ge_loss: 3.429 d_loss: 0.101 anomaly_score: 9696.177
# 478/1000 epoch ge_loss: 3.317 d_loss: 0.180 anomaly_score: 9021.891
# 479/1000 epoch ge_loss: 3.257 d_loss: 0.126 anomaly_score: 11134.607
# 480/1000 epoch ge_loss: 3.208 d_loss: 0.107 anomaly_score: 8434.045
# 481/1000 epoch ge_loss: 3.102 d_loss: 0.081 anomaly_score: 7907.891
# 482/1000 epoch ge_loss: 3.199 d_loss: 0.066 anomaly_score: 8762.165
# 483/1000 epoch ge_loss: 3.250 d_loss: 0.081 anomaly_score: 9862.583
# 484/1000 epoch ge_loss: 3.256 d_loss: 0.107 anomaly_score: 9293.094
# 485/1000 epoch ge_loss: 3.229 d_loss: 0.093 anomaly_score: 8317.966
# 486/1000 epoch ge_loss: 3.170 d_loss: 0.165 anomaly_score: 8981.675
# 487/1000 epoch ge_loss: 3.348 d_loss: 0.115 anomaly_score: 6998.894
# 488/1000 epoch ge_loss: 3.372 d_loss: 0.109 anomaly_score: 8125.290
# 489/1000 epoch ge_loss: 3.476 d_loss: 0.094 anomaly_score: 8322.846
# 490/1000 epoch ge_loss: 3.395 d_loss: 0.096 anomaly_score: 7226.383
# 491/1000 epoch ge_loss: 3.433 d_loss: 0.122 anomaly_score: 8301.482
# 492/1000 epoch ge_loss: 3.266 d_loss: 0.109 anomaly_score: 8365.057
# 493/1000 epoch ge_loss: 3.695 d_loss: 0.122 anomaly_score: 7676.632
# 494/1000 epoch ge_loss: 3.096 d_loss: 0.129 anomaly_score: 8230.414
# 495/1000 epoch ge_loss: 3.218 d_loss: 0.149 anomaly_score: 8749.705
# 496/1000 epoch ge_loss: 3.711 d_loss: 0.095 anomaly_score: 8427.454
# 497/1000 epoch ge_loss: 3.169 d_loss: 0.110 anomaly_score: 8637.774
# 498/1000 epoch ge_loss: 3.315 d_loss: 0.142 anomaly_score: 7692.731
# 499/1000 epoch ge_loss: 3.212 d_loss: 0.120 anomaly_score: 8249.928
# 500/1000 epoch ge_loss: 3.264 d_loss: 0.140 anomaly_score: 7520.620
# 501/1000 epoch ge_loss: 3.351 d_loss: 0.104 anomaly_score: 7269.981
# 502/1000 epoch ge_loss: 3.504 d_loss: 0.073 anomaly_score: 8028.079
# 503/1000 epoch ge_loss: 3.271 d_loss: 0.107 anomaly_score: 9126.224
# 504/1000 epoch ge_loss: 3.295 d_loss: 0.095 anomaly_score: 10172.879
# 505/1000 epoch ge_loss: 3.262 d_loss: 0.090 anomaly_score: 9526.459
# 506/1000 epoch ge_loss: 3.442 d_loss: 0.066 anomaly_score: 9058.241
# 507/1000 epoch ge_loss: 3.337 d_loss: 0.102 anomaly_score: 8522.640
# 508/1000 epoch ge_loss: 3.223 d_loss: 0.115 anomaly_score: 8653.793
# 509/1000 epoch ge_loss: 3.485 d_loss: 0.145 anomaly_score: 8407.503
# 510/1000 epoch ge_loss: 3.364 d_loss: 0.139 anomaly_score: 9031.604
# 511/1000 epoch ge_loss: 3.388 d_loss: 0.126 anomaly_score: 9091.047
# 512/1000 epoch ge_loss: 3.580 d_loss: 0.088 anomaly_score: 8448.870
# 513/1000 epoch ge_loss: 3.862 d_loss: 0.129 anomaly_score: 6751.886
# 514/1000 epoch ge_loss: 3.321 d_loss: 0.105 anomaly_score: 7422.157
# 515/1000 epoch ge_loss: 3.792 d_loss: 0.101 anomaly_score: 7767.378
# 516/1000 epoch ge_loss: 3.733 d_loss: 0.105 anomaly_score: 8757.068
# 517/1000 epoch ge_loss: 3.795 d_loss: 0.100 anomaly_score: 8197.464
# 518/1000 epoch ge_loss: 3.251 d_loss: 0.111 anomaly_score: 7562.991
# 519/1000 epoch ge_loss: 3.532 d_loss: 0.117 anomaly_score: 7744.512
# 520/1000 epoch ge_loss: 3.191 d_loss: 0.131 anomaly_score: 7362.291
# 521/1000 epoch ge_loss: 3.097 d_loss: 0.136 anomaly_score: 7658.119
# 522/1000 epoch ge_loss: 3.296 d_loss: 0.095 anomaly_score: 7213.329
# 523/1000 epoch ge_loss: 3.536 d_loss: 0.106 anomaly_score: 7621.232
# 524/1000 epoch ge_loss: 3.230 d_loss: 0.170 anomaly_score: 10428.454
# 525/1000 epoch ge_loss: 3.028 d_loss: 0.132 anomaly_score: 10060.567
# 526/1000 epoch ge_loss: 3.485 d_loss: 0.091 anomaly_score: 8025.964
# 527/1000 epoch ge_loss: 3.495 d_loss: 0.083 anomaly_score: 8719.837
# 528/1000 epoch ge_loss: 3.471 d_loss: 0.084 anomaly_score: 11271.915
# 529/1000 epoch ge_loss: 3.206 d_loss: 0.124 anomaly_score: 10048.349
# 530/1000 epoch ge_loss: 3.365 d_loss: 0.078 anomaly_score: 10273.276
# 531/1000 epoch ge_loss: 3.362 d_loss: 0.087 anomaly_score: 8815.751
# 532/1000 epoch ge_loss: 3.436 d_loss: 0.124 anomaly_score: 7142.060
# 533/1000 epoch ge_loss: 3.352 d_loss: 0.099 anomaly_score: 8508.429
# 534/1000 epoch ge_loss: 3.417 d_loss: 0.104 anomaly_score: 9232.797
# 535/1000 epoch ge_loss: 3.473 d_loss: 0.101 anomaly_score: 7927.991
# 536/1000 epoch ge_loss: 3.388 d_loss: 0.106 anomaly_score: 7276.081
# 537/1000 epoch ge_loss: 3.290 d_loss: 0.149 anomaly_score: 7372.783
# 538/1000 epoch ge_loss: 3.491 d_loss: 0.075 anomaly_score: 7115.163
# 539/1000 epoch ge_loss: 3.286 d_loss: 0.104 anomaly_score: 7757.749
# 540/1000 epoch ge_loss: 3.639 d_loss: 0.082 anomaly_score: 7785.928
# 541/1000 epoch ge_loss: 3.545 d_loss: 0.086 anomaly_score: 9193.724
# 542/1000 epoch ge_loss: 3.627 d_loss: 0.113 anomaly_score: 8467.779
# 543/1000 epoch ge_loss: 3.373 d_loss: 0.098 anomaly_score: 8001.583
# 544/1000 epoch ge_loss: 3.509 d_loss: 0.100 anomaly_score: 7466.714
# 545/1000 epoch ge_loss: 3.427 d_loss: 0.097 anomaly_score: 7695.243
# 546/1000 epoch ge_loss: 3.511 d_loss: 0.066 anomaly_score: 7312.153
# 547/1000 epoch ge_loss: 3.632 d_loss: 0.096 anomaly_score: 9480.418
# 548/1000 epoch ge_loss: 3.810 d_loss: 0.063 anomaly_score: 7516.073
# 549/1000 epoch ge_loss: 3.645 d_loss: 0.061 anomaly_score: 7174.534
# 550/1000 epoch ge_loss: 3.558 d_loss: 0.120 anomaly_score: 7724.762
# 551/1000 epoch ge_loss: 3.553 d_loss: 0.099 anomaly_score: 7486.509
# 552/1000 epoch ge_loss: 3.886 d_loss: 0.128 anomaly_score: 8609.644
# 553/1000 epoch ge_loss: 3.286 d_loss: 0.109 anomaly_score: 7964.024
# 554/1000 epoch ge_loss: 3.655 d_loss: 0.110 anomaly_score: 7028.931
# 555/1000 epoch ge_loss: 3.652 d_loss: 0.077 anomaly_score: 7485.708
# 556/1000 epoch ge_loss: 3.710 d_loss: 0.110 anomaly_score: 6964.639
# 557/1000 epoch ge_loss: 3.632 d_loss: 0.087 anomaly_score: 6772.045
# 558/1000 epoch ge_loss: 3.594 d_loss: 0.142 anomaly_score: 6542.122
# 559/1000 epoch ge_loss: 3.461 d_loss: 0.144 anomaly_score: 6637.214
# 560/1000 epoch ge_loss: 3.402 d_loss: 0.126 anomaly_score: 8270.972
# 561/1000 epoch ge_loss: 3.220 d_loss: 0.088 anomaly_score: 9968.715
# 562/1000 epoch ge_loss: 3.390 d_loss: 0.120 anomaly_score: 8528.249
# 563/1000 epoch ge_loss: 3.448 d_loss: 0.117 anomaly_score: 7762.030
# 564/1000 epoch ge_loss: 3.415 d_loss: 0.137 anomaly_score: 7040.644
# 565/1000 epoch ge_loss: 3.303 d_loss: 0.187 anomaly_score: 6366.551
# 566/1000 epoch ge_loss: 3.528 d_loss: 0.107 anomaly_score: 7775.171
# 567/1000 epoch ge_loss: 3.298 d_loss: 0.094 anomaly_score: 6893.402
# 568/1000 epoch ge_loss: 3.475 d_loss: 0.100 anomaly_score: 7433.817
# 569/1000 epoch ge_loss: 3.421 d_loss: 0.113 anomaly_score: 7545.727
# 570/1000 epoch ge_loss: 3.560 d_loss: 0.086 anomaly_score: 6646.621
# 571/1000 epoch ge_loss: 3.666 d_loss: 0.102 anomaly_score: 7274.246
# 572/1000 epoch ge_loss: 3.749 d_loss: 0.096 anomaly_score: 7216.620
# 573/1000 epoch ge_loss: 3.270 d_loss: 0.139 anomaly_score: 7237.407
# 574/1000 epoch ge_loss: 3.381 d_loss: 0.078 anomaly_score: 6616.598
# 575/1000 epoch ge_loss: 3.366 d_loss: 0.115 anomaly_score: 6840.291
# 576/1000 epoch ge_loss: 3.709 d_loss: 0.082 anomaly_score: 8210.550
# 577/1000 epoch ge_loss: 3.634 d_loss: 0.085 anomaly_score: 7977.046
# 578/1000 epoch ge_loss: 3.776 d_loss: 0.099 anomaly_score: 7178.884
# 579/1000 epoch ge_loss: 3.647 d_loss: 0.088 anomaly_score: 7051.540
# 580/1000 epoch ge_loss: 3.533 d_loss: 0.116 anomaly_score: 7847.813
# 581/1000 epoch ge_loss: 3.417 d_loss: 0.119 anomaly_score: 9856.240
# 582/1000 epoch ge_loss: 3.780 d_loss: 0.066 anomaly_score: 8541.558
# 583/1000 epoch ge_loss: 3.679 d_loss: 0.136 anomaly_score: 7897.947
# 584/1000 epoch ge_loss: 3.736 d_loss: 0.099 anomaly_score: 9826.529
# 585/1000 epoch ge_loss: 3.432 d_loss: 0.106 anomaly_score: 8238.909
# 586/1000 epoch ge_loss: 3.871 d_loss: 0.091 anomaly_score: 7009.433
# 587/1000 epoch ge_loss: 3.684 d_loss: 0.098 anomaly_score: 6802.134
# 588/1000 epoch ge_loss: 3.542 d_loss: 0.109 anomaly_score: 7422.555
# 589/1000 epoch ge_loss: 3.722 d_loss: 0.095 anomaly_score: 8648.032
# 590/1000 epoch ge_loss: 3.538 d_loss: 0.142 anomaly_score: 8424.441
# 591/1000 epoch ge_loss: 3.379 d_loss: 0.122 anomaly_score: 7119.574
# 592/1000 epoch ge_loss: 3.310 d_loss: 0.116 anomaly_score: 6636.181
# 593/1000 epoch ge_loss: 3.562 d_loss: 0.115 anomaly_score: 6389.958
# 594/1000 epoch ge_loss: 3.804 d_loss: 0.085 anomaly_score: 6943.234
# 595/1000 epoch ge_loss: 3.708 d_loss: 0.072 anomaly_score: 6725.069
# 596/1000 epoch ge_loss: 3.734 d_loss: 0.129 anomaly_score: 6206.047
# 597/1000 epoch ge_loss: 3.367 d_loss: 0.118 anomaly_score: 6310.881
# 598/1000 epoch ge_loss: 3.555 d_loss: 0.124 anomaly_score: 9083.378
# 599/1000 epoch ge_loss: 3.385 d_loss: 0.103 anomaly_score: 7154.610
# 600/1000 epoch ge_loss: 3.434 d_loss: 0.091 anomaly_score: 7254.459
# 601/1000 epoch ge_loss: 3.678 d_loss: 0.090 anomaly_score: 7267.147
# 602/1000 epoch ge_loss: 3.287 d_loss: 0.123 anomaly_score: 7504.293
# 603/1000 epoch ge_loss: 3.591 d_loss: 0.091 anomaly_score: 7294.660
# 604/1000 epoch ge_loss: 3.695 d_loss: 0.130 anomaly_score: 6628.211
# 605/1000 epoch ge_loss: 3.688 d_loss: 0.135 anomaly_score: 6886.221
# 606/1000 epoch ge_loss: 3.629 d_loss: 0.102 anomaly_score: 7756.322
# 607/1000 epoch ge_loss: 3.719 d_loss: 0.087 anomaly_score: 9070.457
# 608/1000 epoch ge_loss: 3.526 d_loss: 0.105 anomaly_score: 9094.495
# 609/1000 epoch ge_loss: 3.457 d_loss: 0.127 anomaly_score: 8059.734
# 610/1000 epoch ge_loss: 3.302 d_loss: 0.149 anomaly_score: 7320.078
# 611/1000 epoch ge_loss: 3.672 d_loss: 0.093 anomaly_score: 8043.914
# 612/1000 epoch ge_loss: 3.326 d_loss: 0.114 anomaly_score: 10101.197
# 613/1000 epoch ge_loss: 3.407 d_loss: 0.101 anomaly_score: 10589.033
# 614/1000 epoch ge_loss: 3.381 d_loss: 0.091 anomaly_score: 9701.601
# 615/1000 epoch ge_loss: 3.566 d_loss: 0.083 anomaly_score: 7876.029
# 616/1000 epoch ge_loss: 3.693 d_loss: 0.104 anomaly_score: 7914.849
# 617/1000 epoch ge_loss: 3.813 d_loss: 0.088 anomaly_score: 7813.172
# 618/1000 epoch ge_loss: 3.783 d_loss: 0.075 anomaly_score: 7564.226
# 619/1000 epoch ge_loss: 3.643 d_loss: 0.091 anomaly_score: 6962.053
# 620/1000 epoch ge_loss: 3.406 d_loss: 0.076 anomaly_score: 6154.367
# 621/1000 epoch ge_loss: 3.807 d_loss: 0.079 anomaly_score: 6164.769
# 622/1000 epoch ge_loss: 3.728 d_loss: 0.093 anomaly_score: 7637.954
# 623/1000 epoch ge_loss: 3.451 d_loss: 0.098 anomaly_score: 8426.122
# 624/1000 epoch ge_loss: 3.722 d_loss: 0.058 anomaly_score: 7413.204
# 625/1000 epoch ge_loss: 3.555 d_loss: 0.128 anomaly_score: 6733.958
# 626/1000 epoch ge_loss: 3.724 d_loss: 0.081 anomaly_score: 7282.617
# 627/1000 epoch ge_loss: 3.473 d_loss: 0.079 anomaly_score: 8848.114
# 628/1000 epoch ge_loss: 3.645 d_loss: 0.085 anomaly_score: 8093.230
# 629/1000 epoch ge_loss: 3.485 d_loss: 0.071 anomaly_score: 7949.646
# 630/1000 epoch ge_loss: 3.404 d_loss: 0.133 anomaly_score: 7669.987
# 631/1000 epoch ge_loss: 3.982 d_loss: 0.117 anomaly_score: 6319.710
# 632/1000 epoch ge_loss: 3.666 d_loss: 0.085 anomaly_score: 6722.785
# 633/1000 epoch ge_loss: 3.934 d_loss: 0.126 anomaly_score: 6467.732
# 634/1000 epoch ge_loss: 3.526 d_loss: 0.119 anomaly_score: 7263.433
# 635/1000 epoch ge_loss: 3.677 d_loss: 0.103 anomaly_score: 8336.421
# 636/1000 epoch ge_loss: 3.416 d_loss: 0.106 anomaly_score: 9975.779
# 637/1000 epoch ge_loss: 3.343 d_loss: 0.101 anomaly_score: 10480.722
# 638/1000 epoch ge_loss: 3.460 d_loss: 0.101 anomaly_score: 8581.919
# 639/1000 epoch ge_loss: 3.628 d_loss: 0.107 anomaly_score: 7375.275
# 640/1000 epoch ge_loss: 3.734 d_loss: 0.075 anomaly_score: 6337.525
# 641/1000 epoch ge_loss: 3.846 d_loss: 0.074 anomaly_score: 7783.761
# 642/1000 epoch ge_loss: 3.585 d_loss: 0.110 anomaly_score: 10957.940
# 643/1000 epoch ge_loss: 3.657 d_loss: 0.103 anomaly_score: 12139.744
# 644/1000 epoch ge_loss: 3.724 d_loss: 0.112 anomaly_score: 10905.385
# 645/1000 epoch ge_loss: 3.723 d_loss: 0.113 anomaly_score: 9558.440
# 646/1000 epoch ge_loss: 3.866 d_loss: 0.131 anomaly_score: 8094.504
# 647/1000 epoch ge_loss: 3.832 d_loss: 0.097 anomaly_score: 10530.840
# 648/1000 epoch ge_loss: 3.646 d_loss: 0.119 anomaly_score: 11372.326
# 649/1000 epoch ge_loss: 3.548 d_loss: 0.105 anomaly_score: 9520.458
# 650/1000 epoch ge_loss: 3.643 d_loss: 0.081 anomaly_score: 8927.390
# 651/1000 epoch ge_loss: 3.611 d_loss: 0.105 anomaly_score: 8915.055
# 652/1000 epoch ge_loss: 3.639 d_loss: 0.094 anomaly_score: 10573.890
# 653/1000 epoch ge_loss: 3.516 d_loss: 0.090 anomaly_score: 10459.410
# 654/1000 epoch ge_loss: 3.594 d_loss: 0.086 anomaly_score: 10278.444
# 655/1000 epoch ge_loss: 3.697 d_loss: 0.086 anomaly_score: 9528.883
# 656/1000 epoch ge_loss: 3.952 d_loss: 0.079 anomaly_score: 8970.616
# 657/1000 epoch ge_loss: 3.790 d_loss: 0.118 anomaly_score: 7780.566
# 658/1000 epoch ge_loss: 3.736 d_loss: 0.075 anomaly_score: 7255.555
# 659/1000 epoch ge_loss: 3.620 d_loss: 0.090 anomaly_score: 7194.004
# 660/1000 epoch ge_loss: 3.806 d_loss: 0.083 anomaly_score: 6942.636
# 661/1000 epoch ge_loss: 3.825 d_loss: 0.097 anomaly_score: 6514.614
# 662/1000 epoch ge_loss: 3.411 d_loss: 0.072 anomaly_score: 6951.263
# 663/1000 epoch ge_loss: 4.139 d_loss: 0.091 anomaly_score: 7449.749
# 664/1000 epoch ge_loss: 3.419 d_loss: 0.084 anomaly_score: 7560.062
# 665/1000 epoch ge_loss: 3.790 d_loss: 0.075 anomaly_score: 7460.412
# 666/1000 epoch ge_loss: 3.725 d_loss: 0.105 anomaly_score: 7890.146
# 667/1000 epoch ge_loss: 3.911 d_loss: 0.093 anomaly_score: 7482.519
# 668/1000 epoch ge_loss: 4.120 d_loss: 0.059 anomaly_score: 7341.894
# 669/1000 epoch ge_loss: 3.559 d_loss: 0.069 anomaly_score: 8112.651
# 670/1000 epoch ge_loss: 3.768 d_loss: 0.071 anomaly_score: 9482.705
# 671/1000 epoch ge_loss: 3.696 d_loss: 0.081 anomaly_score: 8422.183
# 672/1000 epoch ge_loss: 3.773 d_loss: 0.096 anomaly_score: 8080.152
# 673/1000 epoch ge_loss: 3.726 d_loss: 0.077 anomaly_score: 7232.682
# 674/1000 epoch ge_loss: 3.892 d_loss: 0.084 anomaly_score: 7991.127
# 675/1000 epoch ge_loss: 3.810 d_loss: 0.073 anomaly_score: 7790.684
# 676/1000 epoch ge_loss: 3.705 d_loss: 0.075 anomaly_score: 7208.432
# 677/1000 epoch ge_loss: 3.658 d_loss: 0.083 anomaly_score: 8227.245
# 678/1000 epoch ge_loss: 3.918 d_loss: 0.091 anomaly_score: 8754.330
# 679/1000 epoch ge_loss: 4.125 d_loss: 0.120 anomaly_score: 7040.519
# 680/1000 epoch ge_loss: 3.937 d_loss: 0.069 anomaly_score: 6332.004
# 681/1000 epoch ge_loss: 3.841 d_loss: 0.070 anomaly_score: 6111.552
# 682/1000 epoch ge_loss: 3.713 d_loss: 0.079 anomaly_score: 6310.756
# 683/1000 epoch ge_loss: 4.105 d_loss: 0.125 anomaly_score: 6987.195
# 684/1000 epoch ge_loss: 3.938 d_loss: 0.094 anomaly_score: 7400.228
# 685/1000 epoch ge_loss: 3.712 d_loss: 0.080 anomaly_score: 9849.709
# 686/1000 epoch ge_loss: 3.661 d_loss: 0.122 anomaly_score: 9563.346
# 687/1000 epoch ge_loss: 4.150 d_loss: 0.110 anomaly_score: 7148.071
# 688/1000 epoch ge_loss: 3.661 d_loss: 0.099 anomaly_score: 7215.091
# 689/1000 epoch ge_loss: 3.734 d_loss: 0.111 anomaly_score: 8366.597
# 690/1000 epoch ge_loss: 3.820 d_loss: 0.108 anomaly_score: 9145.913
# 691/1000 epoch ge_loss: 3.929 d_loss: 0.120 anomaly_score: 8941.114
# 692/1000 epoch ge_loss: 3.895 d_loss: 0.096 anomaly_score: 8589.215
# 693/1000 epoch ge_loss: 3.853 d_loss: 0.070 anomaly_score: 9376.519
# 694/1000 epoch ge_loss: 4.238 d_loss: 0.062 anomaly_score: 7863.032
# 695/1000 epoch ge_loss: 4.320 d_loss: 0.080 anomaly_score: 6628.539
# 696/1000 epoch ge_loss: 3.981 d_loss: 0.092 anomaly_score: 6467.017
# 697/1000 epoch ge_loss: 4.111 d_loss: 0.131 anomaly_score: 6985.205
# 698/1000 epoch ge_loss: 4.006 d_loss: 0.078 anomaly_score: 8251.456
# 699/1000 epoch ge_loss: 3.957 d_loss: 0.111 anomaly_score: 7315.423
# 700/1000 epoch ge_loss: 3.602 d_loss: 0.103 anomaly_score: 7326.742
# 701/1000 epoch ge_loss: 3.785 d_loss: 0.081 anomaly_score: 7036.732
# 702/1000 epoch ge_loss: 3.741 d_loss: 0.081 anomaly_score: 8938.878
# 703/1000 epoch ge_loss: 3.932 d_loss: 0.085 anomaly_score: 8458.510
# ...
# 765/1000 epoch ge_loss: 3.725 d_loss: 0.092 anomaly_score: 6113.835
# 766/1000 epoch ge_loss: 4.019 d_loss: 0.063 anomaly_score: 6191.227
# 767/1000 epoch ge_loss: 3.850 d_loss: 0.091 anomaly_score: 6085.103
# 768/1000 epoch ge_loss: 3.896 d_loss: 0.092 anomaly_score: 6299.704
# 769/1000 epoch ge_loss: 3.746 d_loss: 0.064 anomaly_score: 6362.471
# 770/1000 epoch ge_loss: 3.949 d_loss: 0.056 anomaly_score: 5913.421
# 771/1000 epoch ge_loss: 3.785 d_loss: 0.072 anomaly_score: 6233.235
# 772/1000 epoch ge_loss: 3.486 d_loss: 0.084 anomaly_score: 5942.436
# 773/1000 epoch ge_loss: 4.023 d_loss: 0.089 anomaly_score: 7451.855
# 774/1000 epoch ge_loss: 4.239 d_loss: 0.074 anomaly_score: 9945.952
# 775/1000 epoch ge_loss: 3.930 d_loss: 0.080 anomaly_score: 8573.971
# 776/1000 epoch ge_loss: 3.875 d_loss: 0.058 anomaly_score: 7839.899
# 777/1000 epoch ge_loss: 3.901 d_loss: 0.100 anomaly_score: 6572.868
# 778/1000 epoch ge_loss: 4.087 d_loss: 0.079 anomaly_score: 6851.699
# 779/1000 epoch ge_loss: 4.000 d_loss: 0.079 anomaly_score: 7697.197
# 780/1000 epoch ge_loss: 4.438 d_loss: 0.091 anomaly_score: 7519.233
# 781/1000 epoch ge_loss: 3.833 d_loss: 0.114 anomaly_score: 6477.714
# 782/1000 epoch ge_loss: 4.000 d_loss: 0.067 anomaly_score: 6723.982
# 783/1000 epoch ge_loss: 4.167 d_loss: 0.065 anomaly_score: 7628.411
# 784/1000 epoch ge_loss: 4.169 d_loss: 0.080 anomaly_score: 8205.210
# 785/1000 epoch ge_loss: 4.417 d_loss: 0.117 anomaly_score: 7010.051
# 786/1000 epoch ge_loss: 4.345 d_loss: 0.075 anomaly_score: 7026.700
# 787/1000 epoch ge_loss: 4.098 d_loss: 0.086 anomaly_score: 6840.491
# 788/1000 epoch ge_loss: 4.085 d_loss: 0.113 anomaly_score: 7525.341
# 789/1000 epoch ge_loss: 4.354 d_loss: 0.080 anomaly_score: 8267.616
# 790/1000 epoch ge_loss: 4.409 d_loss: 0.070 anomaly_score: 7597.537
# 791/1000 epoch ge_loss: 4.129 d_loss: 0.078 anomaly_score: 7154.868
# 792/1000 epoch ge_loss: 4.145 d_loss: 0.061 anomaly_score: 6565.724
# 793/1000 epoch ge_loss: 4.062 d_loss: 0.080 anomaly_score: 6393.570
# 794/1000 epoch ge_loss: 4.277 d_loss: 0.106 anomaly_score: 6542.367
# 795/1000 epoch ge_loss: 4.822 d_loss: 0.097 anomaly_score: 7108.167
# 796/1000 epoch ge_loss: 4.031 d_loss: 0.079 anomaly_score: 9341.035
# 797/1000 epoch ge_loss: 4.025 d_loss: 0.075 anomaly_score: 8974.179
# 798/1000 epoch ge_loss: 3.762 d_loss: 0.102 anomaly_score: 8209.583
# 799/1000 epoch ge_loss: 4.020 d_loss: 0.058 anomaly_score: 6793.530
# 800/1000 epoch ge_loss: 4.364 d_loss: 0.081 anomaly_score: 7087.661
# 801/1000 epoch ge_loss: 4.215 d_loss: 0.102 anomaly_score: 7069.895
# 802/1000 epoch ge_loss: 3.786 d_loss: 0.062 anomaly_score: 7724.710
# 803/1000 epoch ge_loss: 4.177 d_loss: 0.060 anomaly_score: 8364.587
# 804/1000 epoch ge_loss: 4.038 d_loss: 0.052 anomaly_score: 7059.724
# 805/1000 epoch ge_loss: 3.739 d_loss: 0.132 anomaly_score: 6015.248
# 806/1000 epoch ge_loss: 4.053 d_loss: 0.083 anomaly_score: 6459.466
# 807/1000 epoch ge_loss: 4.499 d_loss: 0.055 anomaly_score: 5829.432
# 808/1000 epoch ge_loss: 4.199 d_loss: 0.078 anomaly_score: 5805.061
# 809/1000 epoch ge_loss: 4.233 d_loss: 0.052 anomaly_score: 5990.203
# 810/1000 epoch ge_loss: 4.189 d_loss: 0.090 anomaly_score: 6093.293
# 811/1000 epoch ge_loss: 4.480 d_loss: 0.070 anomaly_score: 6185.416
# 812/1000 epoch ge_loss: 4.225 d_loss: 0.073 anomaly_score: 7166.333
# 813/1000 epoch ge_loss: 4.310 d_loss: 0.075 anomaly_score: 7854.492
# 814/1000 epoch ge_loss: 3.979 d_loss: 0.040 anomaly_score: 9301.200
# 815/1000 epoch ge_loss: 3.897 d_loss: 0.067 anomaly_score: 8963.497
# 816/1000 epoch ge_loss: 3.968 d_loss: 0.091 anomaly_score: 9213.210
# 817/1000 epoch ge_loss: 4.026 d_loss: 0.078 anomaly_score: 10021.954
# 818/1000 epoch ge_loss: 4.238 d_loss: 0.064 anomaly_score: 9888.756
# 819/1000 epoch ge_loss: 4.429 d_loss: 0.053 anomaly_score: 8878.526
# 820/1000 epoch ge_loss: 3.943 d_loss: 0.100 anomaly_score: 8928.935
# 821/1000 epoch ge_loss: 4.132 d_loss: 0.092 anomaly_score: 7291.240
# 822/1000 epoch ge_loss: 4.151 d_loss: 0.084 anomaly_score: 7733.627
# 823/1000 epoch ge_loss: 4.108 d_loss: 0.081 anomaly_score: 7745.276
# 824/1000 epoch ge_loss: 3.932 d_loss: 0.068 anomaly_score: 7741.033
# 825/1000 epoch ge_loss: 4.365 d_loss: 0.070 anomaly_score: 7056.210
# 826/1000 epoch ge_loss: 3.980 d_loss: 0.086 anomaly_score: 6873.473
# 827/1000 epoch ge_loss: 3.878 d_loss: 0.082 anomaly_score: 7172.449
# 828/1000 epoch ge_loss: 4.173 d_loss: 0.081 anomaly_score: 7268.447
# 829/1000 epoch ge_loss: 4.247 d_loss: 0.065 anomaly_score: 7825.979
# 830/1000 epoch ge_loss: 3.870 d_loss: 0.090 anomaly_score: 8148.959
# 831/1000 epoch ge_loss: 4.127 d_loss: 0.073 anomaly_score: 7861.529
# 832/1000 epoch ge_loss: 3.933 d_loss: 0.066 anomaly_score: 7673.421
# 833/1000 epoch ge_loss: 4.001 d_loss: 0.070 anomaly_score: 6950.720
# 834/1000 epoch ge_loss: 4.149 d_loss: 0.089 anomaly_score: 7613.891
# 835/1000 epoch ge_loss: 4.049 d_loss: 0.058 anomaly_score: 8067.331
# 836/1000 epoch ge_loss: 4.115 d_loss: 0.072 anomaly_score: 7461.493
# 837/1000 epoch ge_loss: 4.270 d_loss: 0.069 anomaly_score: 7244.608
# 838/1000 epoch ge_loss: 3.978 d_loss: 0.071 anomaly_score: 7141.201
# 839/1000 epoch ge_loss: 4.289 d_loss: 0.075 anomaly_score: 6931.859
# 840/1000 epoch ge_loss: 4.236 d_loss: 0.051 anomaly_score: 6961.623
# 841/1000 epoch ge_loss: 4.270 d_loss: 0.070 anomaly_score: 7142.476
# 842/1000 epoch ge_loss: 4.377 d_loss: 0.063 anomaly_score: 7452.855
# 843/1000 epoch ge_loss: 4.241 d_loss: 0.066 anomaly_score: 7856.954
# 844/1000 epoch ge_loss: 4.109 d_loss: 0.082 anomaly_score: 7990.568
# 845/1000 epoch ge_loss: 3.835 d_loss: 0.063 anomaly_score: 7724.584
# 846/1000 epoch ge_loss: 4.008 d_loss: 0.078 anomaly_score: 8320.661
# 847/1000 epoch ge_loss: 3.908 d_loss: 0.087 anomaly_score: 8444.694
# 848/1000 epoch ge_loss: 4.114 d_loss: 0.069 anomaly_score: 6561.042
# 849/1000 epoch ge_loss: 4.056 d_loss: 0.053 anomaly_score: 6249.160
# 850/1000 epoch ge_loss: 4.044 d_loss: 0.075 anomaly_score: 6621.052
# 851/1000 epoch ge_loss: 3.841 d_loss: 0.069 anomaly_score: 7236.509
# 852/1000 epoch ge_loss: 3.971 d_loss: 0.072 anomaly_score: 7140.961
# 853/1000 epoch ge_loss: 3.868 d_loss: 0.077 anomaly_score: 7696.527
# 854/1000 epoch ge_loss: 4.093 d_loss: 0.102 anomaly_score: 7325.012
# 855/1000 epoch ge_loss: 4.201 d_loss: 0.061 anomaly_score: 7789.866
# 856/1000 epoch ge_loss: 4.067 d_loss: 0.063 anomaly_score: 7969.602
# 857/1000 epoch ge_loss: 3.845 d_loss: 0.085 anomaly_score: 7729.216
# 858/1000 epoch ge_loss: 4.188 d_loss: 0.052 anomaly_score: 7045.909
# 859/1000 epoch ge_loss: 4.265 d_loss: 0.073 anomaly_score: 8077.978
# 860/1000 epoch ge_loss: 4.251 d_loss: 0.044 anomaly_score: 7539.175
# 861/1000 epoch ge_loss: 4.032 d_loss: 0.063 anomaly_score: 8191.009
# 862/1000 epoch ge_loss: 4.133 d_loss: 0.063 anomaly_score: 8833.876
# 863/1000 epoch ge_loss: 4.527 d_loss: 0.077 anomaly_score: 9494.639
# 864/1000 epoch ge_loss: 5.218 d_loss: 0.107 anomaly_score: 8658.137
# 865/1000 epoch ge_loss: 4.186 d_loss: 0.070 anomaly_score: 8006.836
# 866/1000 epoch ge_loss: 4.375 d_loss: 0.075 anomaly_score: 7380.064
# 867/1000 epoch ge_loss: 4.507 d_loss: 0.078 anomaly_score: 7288.951
# 868/1000 epoch ge_loss: 4.709 d_loss: 0.072 anomaly_score: 6752.337
# 869/1000 epoch ge_loss: 4.130 d_loss: 0.071 anomaly_score: 7036.324
# 870/1000 epoch ge_loss: 4.025 d_loss: 0.089 anomaly_score: 7161.770
# 871/1000 epoch ge_loss: 4.422 d_loss: 0.074 anomaly_score: 7284.857
# 872/1000 epoch ge_loss: 4.155 d_loss: 0.058 anomaly_score: 7335.969
# 873/1000 epoch ge_loss: 3.981 d_loss: 0.070 anomaly_score: 7625.869
# 874/1000 epoch ge_loss: 4.206 d_loss: 0.057 anomaly_score: 7882.079
# 875/1000 epoch ge_loss: 4.355 d_loss: 0.084 anomaly_score: 7859.956
# 876/1000 epoch ge_loss: 3.774 d_loss: 0.102 anomaly_score: 7347.648
# 877/1000 epoch ge_loss: 4.124 d_loss: 0.079 anomaly_score: 6966.882
# 878/1000 epoch ge_loss: 4.095 d_loss: 0.111 anomaly_score: 7750.088
# 879/1000 epoch ge_loss: 3.987 d_loss: 0.076 anomaly_score: 10459.850
# 880/1000 epoch ge_loss: 4.226 d_loss: 0.062 anomaly_score: 10433.660
# 881/1000 epoch ge_loss: 4.456 d_loss: 0.062 anomaly_score: 8913.138
# 882/1000 epoch ge_loss: 4.511 d_loss: 0.095 anomaly_score: 8877.625
# 883/1000 epoch ge_loss: 4.173 d_loss: 0.065 anomaly_score: 8481.425
# 884/1000 epoch ge_loss: 3.950 d_loss: 0.068 anomaly_score: 8489.798
# 885/1000 epoch ge_loss: 4.261 d_loss: 0.057 anomaly_score: 6960.422
# 886/1000 epoch ge_loss: 4.311 d_loss: 0.082 anomaly_score: 6595.195
# 887/1000 epoch ge_loss: 3.980 d_loss: 0.104 anomaly_score: 6870.207
# 888/1000 epoch ge_loss: 4.262 d_loss: 0.080 anomaly_score: 7603.709
# 889/1000 epoch ge_loss: 4.793 d_loss: 0.059 anomaly_score: 7480.458
# 890/1000 epoch ge_loss: 4.275 d_loss: 0.073 anomaly_score: 7872.301
# 891/1000 epoch ge_loss: 4.383 d_loss: 0.092 anomaly_score: 8291.696
# 892/1000 epoch ge_loss: 4.508 d_loss: 0.050 anomaly_score: 9508.369
# 893/1000 epoch ge_loss: 4.422 d_loss: 0.044 anomaly_score: 10212.757
# 894/1000 epoch ge_loss: 3.936 d_loss: 0.059 anomaly_score: 10885.592
# 895/1000 epoch ge_loss: 4.176 d_loss: 0.084 anomaly_score: 7842.996
# 896/1000 epoch ge_loss: 4.371 d_loss: 0.070 anomaly_score: 6897.840
# 897/1000 epoch ge_loss: 3.838 d_loss: 0.092 anomaly_score: 6742.611
# 898/1000 epoch ge_loss: 4.138 d_loss: 0.108 anomaly_score: 7178.057
# 899/1000 epoch ge_loss: 4.072 d_loss: 0.070 anomaly_score: 6960.076
# 900/1000 epoch ge_loss: 4.441 d_loss: 0.051 anomaly_score: 6962.957
# 901/1000 epoch ge_loss: 4.335 d_loss: 0.058 anomaly_score: 7629.280
# 902/1000 epoch ge_loss: 4.182 d_loss: 0.095 anomaly_score: 7494.061
# 903/1000 epoch ge_loss: 4.307 d_loss: 0.064 anomaly_score: 7369.353
# 904/1000 epoch ge_loss: 4.220 d_loss: 0.070 anomaly_score: 6341.501
# 905/1000 epoch ge_loss: 4.568 d_loss: 0.060 anomaly_score: 6277.200
# 906/1000 epoch ge_loss: 4.210 d_loss: 0.059 anomaly_score: 6589.228
# 907/1000 epoch ge_loss: 4.274 d_loss: 0.067 anomaly_score: 6773.271
# 908/1000 epoch ge_loss: 4.316 d_loss: 0.061 anomaly_score: 7713.808
# 909/1000 epoch ge_loss: 4.239 d_loss: 0.063 anomaly_score: 7574.939
# 910/1000 epoch ge_loss: 4.573 d_loss: 0.067 anomaly_score: 6738.338
# 911/1000 epoch ge_loss: 4.275 d_loss: 0.066 anomaly_score: 6915.277
# 912/1000 epoch ge_loss: 4.139 d_loss: 0.062 anomaly_score: 6472.283
# 913/1000 epoch ge_loss: 4.280 d_loss: 0.069 anomaly_score: 7520.436
# 914/1000 epoch ge_loss: 4.149 d_loss: 0.054 anomaly_score: 7267.365
# 915/1000 epoch ge_loss: 4.130 d_loss: 0.074 anomaly_score: 6262.458
# 916/1000 epoch ge_loss: 3.848 d_loss: 0.084 anomaly_score: 6978.728
# 917/1000 epoch ge_loss: 4.208 d_loss: 0.079 anomaly_score: 7642.741
# 918/1000 epoch ge_loss: 4.166 d_loss: 0.056 anomaly_score: 7646.471
# 919/1000 epoch ge_loss: 4.361 d_loss: 0.087 anomaly_score: 7742.966
# 920/1000 epoch ge_loss: 4.148 d_loss: 0.067 anomaly_score: 8668.101
# 921/1000 epoch ge_loss: 4.429 d_loss: 0.058 anomaly_score: 10644.264
# 922/1000 epoch ge_loss: 4.239 d_loss: 0.074 anomaly_score: 12088.006
# 923/1000 epoch ge_loss: 4.373 d_loss: 0.045 anomaly_score: 10501.221
# 924/1000 epoch ge_loss: 4.146 d_loss: 0.090 anomaly_score: 8204.698
# 925/1000 epoch ge_loss: 3.988 d_loss: 0.076 anomaly_score: 7709.694
# 926/1000 epoch ge_loss: 4.140 d_loss: 0.056 anomaly_score: 6414.424
# 927/1000 epoch ge_loss: 3.946 d_loss: 0.060 anomaly_score: 6184.393
# 928/1000 epoch ge_loss: 4.406 d_loss: 0.087 anomaly_score: 6474.656
# 929/1000 epoch ge_loss: 4.389 d_loss: 0.067 anomaly_score: 6695.961
# 930/1000 epoch ge_loss: 3.984 d_loss: 0.069 anomaly_score: 6947.382
# 931/1000 epoch ge_loss: 3.964 d_loss: 0.085 anomaly_score: 7173.034
# 932/1000 epoch ge_loss: 4.540 d_loss: 0.075 anomaly_score: 7433.393
# 933/1000 epoch ge_loss: 4.142 d_loss: 0.066 anomaly_score: 7371.686
# 934/1000 epoch ge_loss: 4.300 d_loss: 0.088 anomaly_score: 7428.493
# 935/1000 epoch ge_loss: 4.154 d_loss: 0.053 anomaly_score: 6363.100
# 936/1000 epoch ge_loss: 4.298 d_loss: 0.067 anomaly_score: 5748.835
# 937/1000 epoch ge_loss: 4.577 d_loss: 0.033 anomaly_score: 5588.791
# 938/1000 epoch ge_loss: 4.120 d_loss: 0.068 anomaly_score: 5536.058
# 939/1000 epoch ge_loss: 4.566 d_loss: 0.083 anomaly_score: 6799.058
# 940/1000 epoch ge_loss: 4.769 d_loss: 0.072 anomaly_score: 6444.435
# 941/1000 epoch ge_loss: 4.487 d_loss: 0.081 anomaly_score: 6647.959
# 942/1000 epoch ge_loss: 5.011 d_loss: 0.056 anomaly_score: 7279.791
# 943/1000 epoch ge_loss: 4.511 d_loss: 0.070 anomaly_score: 8294.318
# 944/1000 epoch ge_loss: 4.626 d_loss: 0.083 anomaly_score: 8214.598
# 945/1000 epoch ge_loss: 4.501 d_loss: 0.070 anomaly_score: 8012.283
# 946/1000 epoch ge_loss: 4.872 d_loss: 0.057 anomaly_score: 8167.068
# 947/1000 epoch ge_loss: 4.801 d_loss: 0.059 anomaly_score: 7482.417
# 948/1000 epoch ge_loss: 4.365 d_loss: 0.065 anomaly_score: 7006.931
# 949/1000 epoch ge_loss: 4.348 d_loss: 0.059 anomaly_score: 6263.013
# 950/1000 epoch ge_loss: 4.290 d_loss: 0.095 anomaly_score: 6155.201
# 951/1000 epoch ge_loss: 4.549 d_loss: 0.094 anomaly_score: 6231.242
# 952/1000 epoch ge_loss: 4.478 d_loss: 0.071 anomaly_score: 6219.058
# 953/1000 epoch ge_loss: 3.874 d_loss: 0.052 anomaly_score: 6100.778
# 954/1000 epoch ge_loss: 4.730 d_loss: 0.064 anomaly_score: 6218.662
# 955/1000 epoch ge_loss: 4.187 d_loss: 0.053 anomaly_score: 6929.940
# 956/1000 epoch ge_loss: 4.255 d_loss: 0.045 anomaly_score: 7135.813
# 957/1000 epoch ge_loss: 4.595 d_loss: 0.049 anomaly_score: 6906.095
# 958/1000 epoch ge_loss: 4.186 d_loss: 0.067 anomaly_score: 7357.191
# 959/1000 epoch ge_loss: 4.640 d_loss: 0.060 anomaly_score: 8983.795
# 960/1000 epoch ge_loss: 4.221 d_loss: 0.052 anomaly_score: 10404.860
# 961/1000 epoch ge_loss: 4.182 d_loss: 0.040 anomaly_score: 9730.736
# 962/1000 epoch ge_loss: 4.445 d_loss: 0.068 anomaly_score: 10422.508
# 963/1000 epoch ge_loss: 4.535 d_loss: 0.058 anomaly_score: 9867.150
# 964/1000 epoch ge_loss: 3.947 d_loss: 0.086 anomaly_score: 8950.121
# 965/1000 epoch ge_loss: 4.330 d_loss: 0.042 anomaly_score: 8125.794
# 966/1000 epoch ge_loss: 4.014 d_loss: 0.061 anomaly_score: 7441.901
# 967/1000 epoch ge_loss: 4.084 d_loss: 0.089 anomaly_score: 7645.232
# 968/1000 epoch ge_loss: 4.083 d_loss: 0.072 anomaly_score: 7979.824
# 969/1000 epoch ge_loss: 4.342 d_loss: 0.081 anomaly_score: 8537.601
# 970/1000 epoch ge_loss: 4.445 d_loss: 0.060 anomaly_score: 8664.024
# 971/1000 epoch ge_loss: 4.522 d_loss: 0.049 anomaly_score: 7359.850
# 972/1000 epoch ge_loss: 4.371 d_loss: 0.080 anomaly_score: 6395.333
# 973/1000 epoch ge_loss: 4.320 d_loss: 0.062 anomaly_score: 6259.189
# 974/1000 epoch ge_loss: 4.720 d_loss: 0.087 anomaly_score: 6897.685
# 975/1000 epoch ge_loss: 4.315 d_loss: 0.071 anomaly_score: 7515.660
# 976/1000 epoch ge_loss: 4.178 d_loss: 0.048 anomaly_score: 8104.559
# 977/1000 epoch ge_loss: 4.239 d_loss: 0.066 anomaly_score: 8260.246
# 978/1000 epoch ge_loss: 4.342 d_loss: 0.081 anomaly_score: 7964.250
# 979/1000 epoch ge_loss: 4.256 d_loss: 0.077 anomaly_score: 7578.400
# 980/1000 epoch ge_loss: 4.628 d_loss: 0.047 anomaly_score: 7954.941
# 981/1000 epoch ge_loss: 4.364 d_loss: 0.109 anomaly_score: 7984.747
# 982/1000 epoch ge_loss: 4.270 d_loss: 0.060 anomaly_score: 7063.572
# 983/1000 epoch ge_loss: 4.088 d_loss: 0.049 anomaly_score: 6449.194
# 984/1000 epoch ge_loss: 4.504 d_loss: 0.061 anomaly_score: 6951.469
# 985/1000 epoch ge_loss: 4.623 d_loss: 0.089 anomaly_score: 6717.909
# 986/1000 epoch ge_loss: 4.605 d_loss: 0.038 anomaly_score: 7061.248
# 987/1000 epoch ge_loss: 4.421 d_loss: 0.056 anomaly_score: 7616.629
# 988/1000 epoch ge_loss: 3.831 d_loss: 0.088 anomaly_score: 7873.204
# 989/1000 epoch ge_loss: 4.212 d_loss: 0.082 anomaly_score: 7812.383
# 990/1000 epoch ge_loss: 4.551 d_loss: 0.055 anomaly_score: 7438.308
# 991/1000 epoch ge_loss: 4.294 d_loss: 0.056 anomaly_score: 7863.361
# 992/1000 epoch ge_loss: 4.459 d_loss: 0.042 anomaly_score: 7562.776
# 993/1000 epoch ge_loss: 4.258 d_loss: 0.097 anomaly_score: 7171.374
# 994/1000 epoch ge_loss: 3.912 d_loss: 0.052 anomaly_score: 6262.185
# 995/1000 epoch ge_loss: 4.152 d_loss: 0.093 anomaly_score: 6657.984
# 996/1000 epoch ge_loss: 4.592 d_loss: 0.053 anomaly_score: 6570.208
# 997/1000 epoch ge_loss: 4.241 d_loss: 0.036 anomaly_score: 7417.249
# 998/1000 epoch ge_loss: 4.398 d_loss: 0.072 anomaly_score: 7759.158
# 999/1000 epoch ge_loss: 4.693 d_loss: 0.057 anomaly_score: 7524.452

# %%
# Generator+EncoderとDiscriminatorのLossの推移と、anomaly scoreの推移
plt.figure(figsize=(12, 8*2))

plt.subplot(211)
plt.plot(range(len(loss_ge_list)), loss_ge_list, label="ge loss",color="blue")
plt.legend()

plt.plot(range(len(loss_d_list)), loss_d_list, label="d loss",color="orange")
plt.legend()
plt.subplot(212)
plt.plot(range(len(anomaly_score_list)), anomaly_score_list, label="anomaly score",color="green")
plt.legend()

plt.show()

# %% [markdown]
# # 潜在変数Zの最適化とテスト画像での異常検知

# %%
# 学習したモデルの読み込み

LOAD_EPOCH = 1000

G = Generator().to(device)
G.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Generator_{LOAD_EPOCH}.pkl"))
G.eval()


E = Encoder().to(device)
E.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Encoder_{LOAD_EPOCH}.pkl"))
E.eval()

D = Discriminator().to(device)
D.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Discriminator_{LOAD_EPOCH}.pkl"))
D.eval()
print("load model")
# Out:
# load model

# %%
# 正常な画像で実行

random_image_size = 10

test_root_normal = './data/fruits-360/Test/Physalis/'
test_dataset_normal = LoadFromFolder(test_root_normal, transform=transform_dict["test"])

test_images_normal = random.sample(list(test_dataset_normal), random_image_size)

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_normal)):

    x = test_images_normal[idx].view(1, 3, 96, 96).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %%
# 画像に傷を模した記号を付与する関数

def add_damage(image_path):
    
    folder = os.path.dirname(image_path)
    save_folder = folder + "_damaged"
    save_base_path = os.path.basename(image_path).replace(".jpg", "_damaged.jpg")
    save_path = os.path.join(save_folder, save_base_path)
    
    os.makedirs(save_folder, exist_ok=True)
    
    image = cv2.imread(image_path)
    center_x = random.randint(20, 76)
    center_y = random.randint(20, 76)
    color_r = random.randint(0, 255)
    color_g = random.randint(0, 255)
    color_b = random.randint(0, 255)
    
    center = (center_x, center_y)
    color = (color_r, color_g, color_b)
    
    cv2.circle(image, center = center, radius = 10, color = color,thickness=-1)
    cv2.imwrite(save_path, image)
    
images_path = glob('./data/fruits-360/Test/Physalis/*.jpg')
[add_damage(image_path) for image_path in images_path]
print("add damage")
# Out:
# add damage

# %%
# 異常な画像で実行

test_root_anomaly = './data/fruits-360/Test/Physalis_damaged/'
test_dataset_anomaly = LoadFromFolder(test_root_anomaly, transform=transform_dict["test"])

test_images_anomaly = random.sample(list(test_dataset_anomaly), random_image_size)

# うまく再現されず、異常スコアが高くなっていれば成功
for idx in range(len(test_images_anomaly)):

    x = test_images_anomaly[idx].view(1, 3, 96, 96).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()
