# %% [markdown]
# # 環境確認

# %%
import sys
import torch

print("Pythonのバージョン：",sys.version)
print("PyTorchのバージョン：", torch.__version__)
print("使用しているGPUの確認")
# !nvidia-smi
# Out:
# Pythonのバージョン： 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0]
# PyTorchのバージョン： 1.10.0+cu111
# 使用しているGPUの確認
# Fri Feb 18 04:20:35 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # データのダウンロード

# %%
# Fruits-360 dataset をダウンロードし、解凍する

# !wget https://md-datasets-cache-zipfiles-prod.s3.eu-west-1.amazonaws.com/rp73yg93n8-1.zip -nc -P ./data/
# !unzip -n ./data/rp73yg93n8-1.zip -d ./data/
# !unzip -n -q ./data/fruits-360_dataset.zip -d ./data/
# Out:
# --2022-02-18 04:20:36--  https://md-datasets-cache-zipfiles-prod.s3.eu-west-1.amazonaws.com/rp73yg93n8-1.zip
# Resolving md-datasets-cache-zipfiles-prod.s3.eu-west-1.amazonaws.com (md-datasets-cache-zipfiles-prod.s3.eu-west-1.amazonaws.com)... 52.218.53.195
# Connecting to md-datasets-cache-zipfiles-prod.s3.eu-west-1.amazonaws.com (md-datasets-cache-zipfiles-prod.s3.eu-west-1.amazonaws.com)|52.218.53.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 418811602 (399M) [application/octet-stream]
# Saving to: ‘./data/rp73yg93n8-1.zip’
#
# rp73yg93n8-1.zip    100%[===================>] 399.41M  28.2MB/s    in 16s
#
# 2022-02-18 04:20:53 (24.6 MB/s) - ‘./data/rp73yg93n8-1.zip’ saved [418811602/418811602]
#
# Archive:  ./data/rp73yg93n8-1.zip
#   inflating: ./data/fruits-360_dataset.zip

# %% [markdown]
# # 事前準備

# %%
import os
import random
from glob import glob
from warnings import filterwarnings

import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.init as init
from natsort import natsorted
from PIL import Image
from skimage import io, transform
from torch import nn, optim
from torch.autograd import Variable
from torch.nn import functional as F
from torch.utils.data import Dataset
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
from torchvision.utils import make_grid, save_image

from torchsummary import summary

filterwarnings("ignore")  # warningをオフにする

# ランダムシードの設定
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
'''初期設定'''

COLAB_FLG = False  # COLABで実行する場合はTrue, それ以外で実行する場合はFalse

if COLAB_FLG:
    from google.colab import drive
    drive.mount('/content/gdrive') # マウント先
    ATTACH_PATH = "/content/gdrive/MyDrive/Colab Notebooks/EfficientGAN-RGB"  # 保存先のベースディレクトリ
else:
    ATTACH_PATH = "."  # ローカルならカレントディレクトリ
    
    
SAVE_MODEL_PATH = f"{ATTACH_PATH}/results/EfficientGAN/model/"  # モデルの保存先
SAVE_IMAGE_FROM_Z_PATH = f"{ATTACH_PATH}/results/EfficientGAN/image/image_from_z/"  # 乱数から生成した画像の保存先
SAVE_IMAGE_RECONSTRUCT = f"{ATTACH_PATH}/results/EfficientGAN/image/RECONSTRUCT/"  # 再構成した画像の保存先

# 保存先のディレクトリを作成する
os.makedirs(SAVE_MODEL_PATH, exist_ok=True)
os.makedirs(SAVE_IMAGE_FROM_Z_PATH, exist_ok=True)
os.makedirs(SAVE_IMAGE_RECONSTRUCT, exist_ok=True)

# %%
'''ハイパーパラメータの設定'''

import argparse

parser = argparse.ArgumentParser()
parser.add_argument("--image_size", type=int, default=96)
parser.add_argument("--num_epochs", type=int, default=1000)
parser.add_argument("--batch_size", type=int, default=16)
parser.add_argument("--lr", type=float, default=4e-4)
parser.add_argument("--z_dim", type=int, default=128) # ノイズの次元
parser.add_argument("--beta1", type=float, default=0.5) # Adamのハイパーパラメータ
parser.add_argument("--beta2", type=float, default=0.999) # Adamのハイパーパラメータ
opt = parser.parse_args(args=[])
print(opt)
# Out:
# Namespace(batch_size=16, beta1=0.5, beta2=0.999, image_size=96, lr=0.0004, num_epochs=1000, z_dim=128)

# %%
# デバイスの設定
device = "cuda" if torch.cuda.is_available() else "cpu"
kwargs = {'num_workers': 1, 'pin_memory': True} if torch.cuda.is_available() else {} # GPUが使える場合、DataLoaderでのミニバッチの取り出しを高速化

# %% [markdown]
# # DataLoader

# %%
train_root = './data/fruits-360/Training/Physalis/'  # train dataの保存してあるディレクトリ
val_root = './data/fruits-360/Test/Physalis/'  # val dataの保存してあるディレクトリ

# %%
# ディレクトリから画像を読み込んでDataLoaderに渡す用のクラス

class LoadFromFolder(Dataset):
    def __init__(self, main_dir, transform):
        self.main_dir = main_dir
        self.transform = transform
        all_imgs = natsorted(os.listdir(main_dir)) # ディレクトリ一覧を取得して自然ソート
        self.all_imgs_name = natsorted(all_imgs)
        self.imgs_loc = [os.path.join(self.main_dir, i) for i in self.all_imgs_name] # 画像のディレクトリ一覧

    def __len__(self):
        return len(self.all_imgs_name)
    
    def load_image(self, path):
        image = Image.open(path).convert("RGB")
        tensor_image = self.transform(image)
        return tensor_image
    
    def __getitem__(self, idx):
        
        # 後ほどsliceで画像を複数枚取得したいのでsliceでも取れるようにする
        if type(idx) == slice:
            paths = self.imgs_loc[idx]
            tensor_image = [self.load_image(path) for path in paths]
            tensor_image = torch.cat(tensor_image).reshape(len(tensor_image), *tensor_image[0].shape)
        elif type(idx) == int:
            path = self.imgs_loc[idx]
            tensor_image = self.load_image(path)
        return tensor_image

# %%
# 画像を読み込む際の前処理

transform_dict = {
    "train": transforms.Compose(
        [
            transforms.Resize((opt.image_size, opt.image_size)),  # image_sizeにreshape
            transforms.RandomHorizontalFlip(), # ランダムに左右反転を行う
            transforms.ToTensor(),
        ]
    ),
    "test": transforms.Compose(
        [
            transforms.Resize((opt.image_size, opt.image_size)),  # image_sizeにreshape
            transforms.ToTensor(),
        ]
    ),
}

# %%
# データを読み込む
train_dataset = LoadFromFolder(train_root, transform=transform_dict["train"])

test_dataset = LoadFromFolder(val_root, transform=transform_dict["test"])

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size = opt.batch_size, shuffle=True, **kwargs)

val_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size = opt.batch_size, shuffle=True, **kwargs)

# %% [markdown]
# # Encoder

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.main = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=4, stride=2, padding=1, bias=False), # 48x48
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1, bias=False), # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False), # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False), # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(256, 512, kernel_size=6, stride=1, bias=False), # 1x1
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),  
            
            nn.Conv2d(512, 512, kernel_size=1, stride=1, bias=False), # 1x1
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),  
        )

        self.last = nn.Sequential(nn.Conv2d(512, opt.z_dim, kernel_size=1, stride=1, bias=False))

    def forward(self, x):

        out = self.main(x)
        out = self.last(out)
        out = out.view(out.size()[0], -1, 1, 1)
        return out

# %%
# ネットワークを可視化する

summary(Encoder().to(device), (3, 96, 96))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 48, 48]           1,536
#        BatchNorm2d-2           [-1, 32, 48, 48]              64
#          LeakyReLU-3           [-1, 32, 48, 48]               0
#             Conv2d-4           [-1, 64, 24, 24]          32,768
#        BatchNorm2d-5           [-1, 64, 24, 24]             128
#          LeakyReLU-6           [-1, 64, 24, 24]               0
#             Conv2d-7          [-1, 128, 12, 12]         131,072
#        BatchNorm2d-8          [-1, 128, 12, 12]             256
#          LeakyReLU-9          [-1, 128, 12, 12]               0
#            Conv2d-10            [-1, 256, 6, 6]         524,288
#       BatchNorm2d-11            [-1, 256, 6, 6]             512
#         LeakyReLU-12            [-1, 256, 6, 6]               0
#            Conv2d-13            [-1, 512, 1, 1]       4,718,592
#       BatchNorm2d-14            [-1, 512, 1, 1]           1,024
#         LeakyReLU-15            [-1, 512, 1, 1]               0
#            Conv2d-16            [-1, 512, 1, 1]         262,144
#       BatchNorm2d-17            [-1, 512, 1, 1]           1,024
#         LeakyReLU-18            [-1, 512, 1, 1]               0
#            Conv2d-19            [-1, 128, 1, 1]          65,536
# ================================================================
# Total params: 5,738,944
# Trainable params: 5,738,944
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 3.19
# Params size (MB): 21.89
# Estimated Total Size (MB): 25.19
# ----------------------------------------------------------------

# %% [markdown]
# # Generator

# %%
class Generator(nn.Module):
    def __init__(self):
        super().__init__()

        self.main = nn.Sequential(
            nn.ConvTranspose2d(opt.z_dim, 256, kernel_size=6, stride=1, padding=0, bias=False),  # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),  # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),  # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1, bias=False),  # 48x48
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2),
            nn.ConvTranspose2d(32, 3, kernel_size=4, stride=2, padding=1, bias=False),  # 96x96
            nn.Tanh(),
        )

    def forward(self, z):
        out = self.main(z)
        return out

# %%
# ネットワークを可視化する

summary(Generator().to(device), tuple([opt.z_dim, 1, 1]))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1            [-1, 256, 6, 6]       1,179,648
#        BatchNorm2d-2            [-1, 256, 6, 6]             512
#          LeakyReLU-3            [-1, 256, 6, 6]               0
#    ConvTranspose2d-4          [-1, 128, 12, 12]         524,288
#        BatchNorm2d-5          [-1, 128, 12, 12]             256
#          LeakyReLU-6          [-1, 128, 12, 12]               0
#    ConvTranspose2d-7           [-1, 64, 24, 24]         131,072
#        BatchNorm2d-8           [-1, 64, 24, 24]             128
#          LeakyReLU-9           [-1, 64, 24, 24]               0
#   ConvTranspose2d-10           [-1, 32, 48, 48]          32,768
#       BatchNorm2d-11           [-1, 32, 48, 48]              64
#         LeakyReLU-12           [-1, 32, 48, 48]               0
#   ConvTranspose2d-13            [-1, 3, 96, 96]           1,536
#              Tanh-14            [-1, 3, 96, 96]               0
# ================================================================
# Total params: 1,870,272
# Trainable params: 1,870,272
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.59
# Params size (MB): 7.13
# Estimated Total Size (MB): 10.72
# ----------------------------------------------------------------

# %% [markdown]
# # Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()

        self.x_layer = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=4, stride=2, padding=1),  # 48x48
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.3),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1),  # 24x24
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.3),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),  # 12x12
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.3),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),  # 6x6
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.3),
            nn.Conv2d(256, 256, kernel_size=6, stride=1),  # 1x1
        )
        self.z_layer = nn.Sequential(
            nn.Conv2d(opt.z_dim, 256, kernel_size=1, stride=1),
            nn.LeakyReLU(0.1, inplace=True),
            nn.Dropout2d(p=0.2),
        )

        self.last1 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=1, stride=1),
            nn.LeakyReLU(0.1, inplace=False),
            nn.Dropout2d(p=0.2),
        )
        self.last2 = nn.Sequential(
            nn.Conv2d(512, 1, kernel_size=1, stride=1),
        )

    def forward(self, x, z):

        output_x = self.x_layer(x)
        output_z = self.z_layer(z)

        concat_x_z = torch.cat((output_x, output_z), 1)
        output = self.last1(concat_x_z)

        feature = output.view(output.size()[0], -1)

        output = self.last2(output)
        output = F.sigmoid(output)
        return output.squeeze(), feature

# %%
# ネットワークを可視化する

summary(Discriminator().to(device), [(3, opt.image_size, opt.image_size), (opt.z_dim, 1, 1)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 48, 48]           1,568
#          LeakyReLU-2           [-1, 32, 48, 48]               0
#          Dropout2d-3           [-1, 32, 48, 48]               0
#             Conv2d-4           [-1, 64, 24, 24]          32,832
#        BatchNorm2d-5           [-1, 64, 24, 24]             128
#          LeakyReLU-6           [-1, 64, 24, 24]               0
#          Dropout2d-7           [-1, 64, 24, 24]               0
#             Conv2d-8          [-1, 128, 12, 12]         131,200
#        BatchNorm2d-9          [-1, 128, 12, 12]             256
#         LeakyReLU-10          [-1, 128, 12, 12]               0
#         Dropout2d-11          [-1, 128, 12, 12]               0
#            Conv2d-12            [-1, 256, 6, 6]         524,544
#       BatchNorm2d-13            [-1, 256, 6, 6]             512
#         LeakyReLU-14            [-1, 256, 6, 6]               0
#         Dropout2d-15            [-1, 256, 6, 6]               0
#            Conv2d-16            [-1, 256, 1, 1]       2,359,552
#            Conv2d-17            [-1, 256, 1, 1]          33,024
#         LeakyReLU-18            [-1, 256, 1, 1]               0
#         Dropout2d-19            [-1, 256, 1, 1]               0
#            Conv2d-20            [-1, 512, 1, 1]         262,656
#         LeakyReLU-21            [-1, 512, 1, 1]               0
#         Dropout2d-22            [-1, 512, 1, 1]               0
#            Conv2d-23              [-1, 1, 1, 1]             513
# ================================================================
# Total params: 3,346,785
# Trainable params: 3,346,785
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 13.50
# Forward/backward pass size (MB): 3.68
# Params size (MB): 12.77
# Estimated Total Size (MB): 29.94
# ----------------------------------------------------------------

# %%
# 重みの初期化を行う関数

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# %%
E = Encoder().to(device)
E.apply(weights_init)

G = Generator().to(device)
G.apply(weights_init)

D = Discriminator().to(device)
D.apply(weights_init)

criterion = nn.BCELoss()  # 評価関数
criterion_L1 = nn.L1Loss(reduction="sum") # 異常スコア計測用

# gとeは共通のoptimizer
optimizer_ge = torch.optim.Adam(list(G.parameters()) + list(E.parameters()), lr=opt.lr, betas=(0.5,0.999))
optimizer_d = torch.optim.Adam(D.parameters(), lr=opt.lr, betas=(0.5,0.999))

scheduler_ge = torch.optim.lr_scheduler.StepLR(optimizer_ge, step_size=50, gamma=0.9)
scheduler_d = torch.optim.lr_scheduler.StepLR(optimizer_d, step_size=50, gamma=0.9)

# %% [markdown]
# # 学習

# %%
def Anomaly_score(x, E_x, G_E_x, Lambda=0.1):
    
    _,x_feature = D(x, E_x)
    _,G_E_x_feature = D(G_E_x, E_x)
    
    residual_loss = criterion_L1(x, G_E_x)
    discrimination_loss = criterion_L1(x_feature, G_E_x_feature)
    
    total_loss = (1-Lambda)*residual_loss + Lambda*discrimination_loss
    total_loss = total_loss.item()

    return total_loss

# %%
Losses_D = []
Losses_GE = []
anomaly_scores = []


for epoch in range(opt.num_epochs):
    loss_d_sum = 0
    loss_ge_sum = 0
    anomaly_score_sum = 0
    
    for i,(x, x_val) in enumerate(zip(train_loader, val_loader)):
        
        G.train()
        D.train()
        E.train()

        # 値の設定
        y_true = Variable(torch.ones(x.size()[0])).to(device)
        y_fake = Variable(torch.zeros(x.size()[0])).to(device)
        
        x = Variable(x).to(device)
        z = Variable(init.normal(torch.Tensor(x.size()[0],opt.z_dim, 1, 1),mean=0,std=0.1)).to(device)
        
        # Discriminatorに対するノイズ
        noise1 = Variable(torch.Tensor(x.size()).normal_(0, 0.1 * (opt.num_epochs - epoch) / opt.num_epochs),
                          requires_grad=False).to(device)
        noise2 = Variable(torch.Tensor(x.size()).normal_(0, 0.1 * (opt.num_epochs - epoch) / opt.num_epochs),
                          requires_grad=False).to(device)

        # Discriminator
        optimizer_d.zero_grad()
        
        E_x = E(x) 
        p_true, _ = D(x + noise1, E_x)
        
        G_z = G(z)
        p_fake, _ = D(G_z + noise2, z)
        
        loss_d = criterion(p_true, y_true) + criterion(p_fake, y_fake)
        loss_d.backward(retain_graph=True)
        optimizer_d.step()
        
        # Generator, Encoder
        optimizer_ge.zero_grad()
        
        p_true, _ = D(x + noise1, E_x)
        p_fake, _ = D(G_z + noise2, z)
        
        loss_ge = criterion(p_fake, y_true) + criterion(p_true, y_fake)
        loss_ge.backward(retain_graph=True)
        optimizer_ge.step()
        
        loss_d_sum += loss_d.item()
        loss_ge_sum += loss_ge.item()
        
        # anomaly scoreの記録
        
        G.eval()
        D.eval()
        E.eval()
        x_val = Variable(x_val).to(device)
        E_x_val = E(x_val)
        G_E_x_val = G(E_x_val)
        anomaly_score_sum += Anomaly_score(x_val, E_x_val, G_E_x_val)
            
        # 画像を保存
        if i == 0:
        
            save_image_size_for_z = min(opt.batch_size, 8)
            save_images = G(z)
            save_image(save_images[:save_image_size_for_z], f"{SAVE_IMAGE_FROM_Z_PATH}/epoch_{epoch}.png", nrow=4)

            save_image_size_for_recon = min(opt.batch_size, 8)
            images = x[:save_image_size_for_recon]
            G_E_x = G(E(images))
            diff_images = torch.abs(images - G_E_x)
            comparison = torch.cat([images , G_E_x, diff_images]).to("cpu")
            save_image(comparison, f"{SAVE_IMAGE_RECONSTRUCT}/epoch_{epoch}.png", nrow=save_image_size_for_recon)
            
    scheduler_ge.step()
    scheduler_d.step()
        
    # lossを記録
    loss_d_mean = loss_d_sum / len(train_loader)
    loss_ge_mean = loss_ge_sum / len(train_loader)
    anomaly_score_mean = anomaly_score_sum / len(train_loader)
    
    print(f"{epoch}/{opt.num_epochs} epoch ge_loss: {loss_ge_mean:.3f} d_loss: {loss_d_mean:.3f} anomaly_score: {anomaly_score_mean:.3f}")
    
    Losses_D.append(loss_d_mean)
    Losses_GE.append(loss_ge_mean)
    anomaly_scores.append(anomaly_score_mean)
    
    # モデルを保存
    if (epoch + 1) % 10 == 0:
        torch.save(G.state_dict(),f'{SAVE_MODEL_PATH}/Generator_{epoch + 1}.pkl')
        torch.save(E.state_dict(),f'{SAVE_MODEL_PATH}/Encoder_{epoch + 1}.pkl')
        torch.save(D.state_dict(),f'{SAVE_MODEL_PATH}/Discriminator_{epoch + 1}.pkl')
# Out:
# 0/1000 epoch ge_loss: 2.631 d_loss: 0.201 anomaly_score: 86415.908
# 1/1000 epoch ge_loss: 5.626 d_loss: 0.056 anomaly_score: 83617.163
# 2/1000 epoch ge_loss: 5.952 d_loss: 0.022 anomaly_score: 74440.908
# 3/1000 epoch ge_loss: 6.223 d_loss: 0.116 anomaly_score: 61844.244
# 4/1000 epoch ge_loss: 5.763 d_loss: 0.046 anomaly_score: 51908.989
# 5/1000 epoch ge_loss: 2.382 d_loss: 0.497 anomaly_score: 41814.465
# 6/1000 epoch ge_loss: 2.397 d_loss: 0.224 anomaly_score: 30477.207
# 7/1000 epoch ge_loss: 2.278 d_loss: 0.231 anomaly_score: 31653.076
# 8/1000 epoch ge_loss: 1.993 d_loss: 0.224 anomaly_score: 23323.779
# 9/1000 epoch ge_loss: 1.218 d_loss: 0.402 anomaly_score: 25880.478
# 10/1000 epoch ge_loss: 1.652 d_loss: 0.393 anomaly_score: 23529.919
# 11/1000 epoch ge_loss: 1.276 d_loss: 0.344 anomaly_score: 24166.828
# 12/1000 epoch ge_loss: 1.213 d_loss: 0.413 anomaly_score: 23324.767
# 13/1000 epoch ge_loss: 1.121 d_loss: 0.434 anomaly_score: 20289.260
# 14/1000 epoch ge_loss: 0.780 d_loss: 0.415 anomaly_score: 18973.536
# 15/1000 epoch ge_loss: 0.903 d_loss: 0.376 anomaly_score: 19671.093
# 16/1000 epoch ge_loss: 1.057 d_loss: 0.410 anomaly_score: 21300.388
# 17/1000 epoch ge_loss: 0.901 d_loss: 0.517 anomaly_score: 19178.740
# 18/1000 epoch ge_loss: 0.823 d_loss: 0.389 anomaly_score: 19237.597
# 19/1000 epoch ge_loss: 1.048 d_loss: 0.368 anomaly_score: 25584.795
# 20/1000 epoch ge_loss: 1.023 d_loss: 0.446 anomaly_score: 20426.366
# 21/1000 epoch ge_loss: 1.146 d_loss: 0.353 anomaly_score: 20145.699
# 22/1000 epoch ge_loss: 1.030 d_loss: 0.422 anomaly_score: 18716.193
# 23/1000 epoch ge_loss: 1.142 d_loss: 0.377 anomaly_score: 17420.215
# 24/1000 epoch ge_loss: 1.339 d_loss: 0.359 anomaly_score: 15904.877
# 25/1000 epoch ge_loss: 1.496 d_loss: 0.320 anomaly_score: 19229.570
# 26/1000 epoch ge_loss: 0.955 d_loss: 0.444 anomaly_score: 14006.496
# 27/1000 epoch ge_loss: 1.359 d_loss: 0.303 anomaly_score: 18599.249
# 28/1000 epoch ge_loss: 1.418 d_loss: 0.388 anomaly_score: 17486.334
# 29/1000 epoch ge_loss: 1.148 d_loss: 0.300 anomaly_score: 16224.070
# 30/1000 epoch ge_loss: 1.533 d_loss: 0.282 anomaly_score: 18439.223
# 31/1000 epoch ge_loss: 1.447 d_loss: 0.342 anomaly_score: 16916.888
# 32/1000 epoch ge_loss: 1.241 d_loss: 0.364 anomaly_score: 15525.219
# 33/1000 epoch ge_loss: 1.393 d_loss: 0.326 anomaly_score: 17582.245
# 34/1000 epoch ge_loss: 1.205 d_loss: 0.339 anomaly_score: 18077.261
# 35/1000 epoch ge_loss: 1.343 d_loss: 0.325 anomaly_score: 16303.491
# 36/1000 epoch ge_loss: 1.282 d_loss: 0.378 anomaly_score: 15809.801
# 37/1000 epoch ge_loss: 1.060 d_loss: 0.356 anomaly_score: 15478.898
# 38/1000 epoch ge_loss: 1.256 d_loss: 0.304 anomaly_score: 14383.383
# 39/1000 epoch ge_loss: 1.286 d_loss: 0.365 anomaly_score: 13036.179
# 40/1000 epoch ge_loss: 1.372 d_loss: 0.317 anomaly_score: 14193.813
# 41/1000 epoch ge_loss: 1.197 d_loss: 0.381 anomaly_score: 16047.804
# 42/1000 epoch ge_loss: 1.313 d_loss: 0.349 anomaly_score: 14363.795
# 43/1000 epoch ge_loss: 1.180 d_loss: 0.351 anomaly_score: 12268.737
# 44/1000 epoch ge_loss: 1.307 d_loss: 0.300 anomaly_score: 13904.732
# 45/1000 epoch ge_loss: 1.385 d_loss: 0.348 anomaly_score: 15374.097
# 46/1000 epoch ge_loss: 1.355 d_loss: 0.326 anomaly_score: 13226.489
# 47/1000 epoch ge_loss: 1.335 d_loss: 0.332 anomaly_score: 13851.235
# 48/1000 epoch ge_loss: 1.150 d_loss: 0.318 anomaly_score: 13673.837
# 49/1000 epoch ge_loss: 1.346 d_loss: 0.339 anomaly_score: 12149.484
# 50/1000 epoch ge_loss: 1.185 d_loss: 0.344 anomaly_score: 12578.889
# 51/1000 epoch ge_loss: 1.427 d_loss: 0.257 anomaly_score: 12938.174
# 52/1000 epoch ge_loss: 1.464 d_loss: 0.304 anomaly_score: 10929.907
# 53/1000 epoch ge_loss: 1.427 d_loss: 0.293 anomaly_score: 12802.642
# 54/1000 epoch ge_loss: 1.374 d_loss: 0.346 anomaly_score: 11621.955
# 55/1000 epoch ge_loss: 1.269 d_loss: 0.321 anomaly_score: 11843.714
# 56/1000 epoch ge_loss: 1.285 d_loss: 0.308 anomaly_score: 12471.235
# 57/1000 epoch ge_loss: 1.456 d_loss: 0.320 anomaly_score: 12969.100
# 58/1000 epoch ge_loss: 1.514 d_loss: 0.330 anomaly_score: 12374.197
# 59/1000 epoch ge_loss: 1.272 d_loss: 0.323 anomaly_score: 12002.823
# 60/1000 epoch ge_loss: 1.349 d_loss: 0.329 anomaly_score: 11754.745
# 61/1000 epoch ge_loss: 1.270 d_loss: 0.266 anomaly_score: 11041.392
# 62/1000 epoch ge_loss: 1.623 d_loss: 0.254 anomaly_score: 12684.004
# 63/1000 epoch ge_loss: 1.495 d_loss: 0.334 anomaly_score: 13142.110
# 64/1000 epoch ge_loss: 1.449 d_loss: 0.328 anomaly_score: 11589.084
# 65/1000 epoch ge_loss: 1.390 d_loss: 0.334 anomaly_score: 11681.019
# 66/1000 epoch ge_loss: 1.239 d_loss: 0.378 anomaly_score: 11173.547
# 67/1000 epoch ge_loss: 1.271 d_loss: 0.311 anomaly_score: 13691.924
# 68/1000 epoch ge_loss: 1.298 d_loss: 0.351 anomaly_score: 13340.784
# 69/1000 epoch ge_loss: 1.360 d_loss: 0.296 anomaly_score: 10252.362
# 70/1000 epoch ge_loss: 1.402 d_loss: 0.295 anomaly_score: 11232.388
# 71/1000 epoch ge_loss: 1.378 d_loss: 0.297 anomaly_score: 10522.936
# 72/1000 epoch ge_loss: 1.510 d_loss: 0.335 anomaly_score: 11143.535
# 73/1000 epoch ge_loss: 1.566 d_loss: 0.268 anomaly_score: 12360.913
# 74/1000 epoch ge_loss: 1.538 d_loss: 0.307 anomaly_score: 12750.729
# 75/1000 epoch ge_loss: 1.495 d_loss: 0.290 anomaly_score: 11717.966
# 76/1000 epoch ge_loss: 1.534 d_loss: 0.381 anomaly_score: 11471.502
# 77/1000 epoch ge_loss: 1.309 d_loss: 0.319 anomaly_score: 13792.521
# 78/1000 epoch ge_loss: 1.400 d_loss: 0.278 anomaly_score: 14071.812
# 79/1000 epoch ge_loss: 1.565 d_loss: 0.239 anomaly_score: 10097.085
# 80/1000 epoch ge_loss: 1.585 d_loss: 0.328 anomaly_score: 11461.332
# 81/1000 epoch ge_loss: 1.431 d_loss: 0.315 anomaly_score: 10939.566
# 82/1000 epoch ge_loss: 1.486 d_loss: 0.265 anomaly_score: 11414.300
# 83/1000 epoch ge_loss: 1.454 d_loss: 0.302 anomaly_score: 11540.711
# 84/1000 epoch ge_loss: 1.572 d_loss: 0.279 anomaly_score: 10714.902
# 85/1000 epoch ge_loss: 1.686 d_loss: 0.266 anomaly_score: 10344.109
# 86/1000 epoch ge_loss: 1.652 d_loss: 0.304 anomaly_score: 12560.627
# 87/1000 epoch ge_loss: 1.710 d_loss: 0.257 anomaly_score: 11402.195
# 88/1000 epoch ge_loss: 1.619 d_loss: 0.289 anomaly_score: 10712.293
# 89/1000 epoch ge_loss: 1.410 d_loss: 0.337 anomaly_score: 10786.921
# 90/1000 epoch ge_loss: 1.625 d_loss: 0.271 anomaly_score: 13142.909
# 91/1000 epoch ge_loss: 1.549 d_loss: 0.264 anomaly_score: 11498.961
# 92/1000 epoch ge_loss: 1.825 d_loss: 0.292 anomaly_score: 9419.301
# 93/1000 epoch ge_loss: 1.565 d_loss: 0.307 anomaly_score: 11145.906
# 94/1000 epoch ge_loss: 1.557 d_loss: 0.316 anomaly_score: 10899.690
# 95/1000 epoch ge_loss: 1.664 d_loss: 0.242 anomaly_score: 10027.664
# 96/1000 epoch ge_loss: 1.757 d_loss: 0.241 anomaly_score: 8933.534
# 97/1000 epoch ge_loss: 1.683 d_loss: 0.307 anomaly_score: 10212.264
# 98/1000 epoch ge_loss: 1.736 d_loss: 0.228 anomaly_score: 13660.792
# 99/1000 epoch ge_loss: 1.959 d_loss: 0.247 anomaly_score: 9554.168
# 100/1000 epoch ge_loss: 1.665 d_loss: 0.225 anomaly_score: 9506.106
# 101/1000 epoch ge_loss: 1.832 d_loss: 0.242 anomaly_score: 13491.919
# 102/1000 epoch ge_loss: 1.806 d_loss: 0.319 anomaly_score: 10026.642
# 103/1000 epoch ge_loss: 1.641 d_loss: 0.294 anomaly_score: 11525.118
# 104/1000 epoch ge_loss: 1.805 d_loss: 0.243 anomaly_score: 9262.243
# 105/1000 epoch ge_loss: 1.709 d_loss: 0.303 anomaly_score: 9590.807
# 106/1000 epoch ge_loss: 1.675 d_loss: 0.273 anomaly_score: 8264.941
# 107/1000 epoch ge_loss: 1.665 d_loss: 0.275 anomaly_score: 13432.006
# 108/1000 epoch ge_loss: 1.714 d_loss: 0.230 anomaly_score: 8779.879
# 109/1000 epoch ge_loss: 1.886 d_loss: 0.218 anomaly_score: 9172.353
# 110/1000 epoch ge_loss: 1.967 d_loss: 0.261 anomaly_score: 9239.479
# 111/1000 epoch ge_loss: 1.867 d_loss: 0.258 anomaly_score: 9127.423
# 112/1000 epoch ge_loss: 1.866 d_loss: 0.296 anomaly_score: 10630.147
# 113/1000 epoch ge_loss: 1.828 d_loss: 0.264 anomaly_score: 12037.042
# 114/1000 epoch ge_loss: 1.776 d_loss: 0.248 anomaly_score: 9238.468
# 115/1000 epoch ge_loss: 1.938 d_loss: 0.199 anomaly_score: 9791.061
# 116/1000 epoch ge_loss: 1.992 d_loss: 0.211 anomaly_score: 9956.459
# 117/1000 epoch ge_loss: 2.027 d_loss: 0.245 anomaly_score: 8990.392
# 118/1000 epoch ge_loss: 2.046 d_loss: 0.271 anomaly_score: 13430.290
# 119/1000 epoch ge_loss: 1.927 d_loss: 0.243 anomaly_score: 9762.945
# 120/1000 epoch ge_loss: 1.933 d_loss: 0.229 anomaly_score: 11065.822
# 121/1000 epoch ge_loss: 1.806 d_loss: 0.232 anomaly_score: 9874.291
# 122/1000 epoch ge_loss: 1.898 d_loss: 0.280 anomaly_score: 9937.760
# 123/1000 epoch ge_loss: 1.902 d_loss: 0.259 anomaly_score: 9118.158
# 124/1000 epoch ge_loss: 1.920 d_loss: 0.248 anomaly_score: 10270.482
# 125/1000 epoch ge_loss: 1.805 d_loss: 0.232 anomaly_score: 11447.929
# 126/1000 epoch ge_loss: 2.102 d_loss: 0.193 anomaly_score: 8426.088
# 127/1000 epoch ge_loss: 2.136 d_loss: 0.240 anomaly_score: 8809.537
# 128/1000 epoch ge_loss: 2.075 d_loss: 0.263 anomaly_score: 8904.926
# 129/1000 epoch ge_loss: 2.036 d_loss: 0.238 anomaly_score: 11636.681
# 130/1000 epoch ge_loss: 2.002 d_loss: 0.200 anomaly_score: 9663.848
# 131/1000 epoch ge_loss: 2.105 d_loss: 0.224 anomaly_score: 10404.634
# 132/1000 epoch ge_loss: 2.062 d_loss: 0.205 anomaly_score: 8291.910
# 133/1000 epoch ge_loss: 2.132 d_loss: 0.194 anomaly_score: 9883.806
# 134/1000 epoch ge_loss: 2.251 d_loss: 0.248 anomaly_score: 8790.192
# 135/1000 epoch ge_loss: 1.918 d_loss: 0.253 anomaly_score: 9073.401
# 136/1000 epoch ge_loss: 2.019 d_loss: 0.255 anomaly_score: 9473.466
# 137/1000 epoch ge_loss: 2.059 d_loss: 0.247 anomaly_score: 9662.771
# 138/1000 epoch ge_loss: 2.067 d_loss: 0.195 anomaly_score: 9539.954
# 139/1000 epoch ge_loss: 2.124 d_loss: 0.218 anomaly_score: 10207.453
# 140/1000 epoch ge_loss: 2.099 d_loss: 0.272 anomaly_score: 9524.629
# 141/1000 epoch ge_loss: 2.028 d_loss: 0.281 anomaly_score: 11620.177
# 142/1000 epoch ge_loss: 1.824 d_loss: 0.248 anomaly_score: 10764.158
# 143/1000 epoch ge_loss: 2.084 d_loss: 0.213 anomaly_score: 8614.436
# 144/1000 epoch ge_loss: 2.145 d_loss: 0.206 anomaly_score: 8866.076
# 145/1000 epoch ge_loss: 2.182 d_loss: 0.336 anomaly_score: 10766.106
# 146/1000 epoch ge_loss: 1.844 d_loss: 0.268 anomaly_score: 10663.562
# 147/1000 epoch ge_loss: 1.918 d_loss: 0.197 anomaly_score: 9951.813
# 148/1000 epoch ge_loss: 2.318 d_loss: 0.206 anomaly_score: 8293.692
# 149/1000 epoch ge_loss: 2.204 d_loss: 0.263 anomaly_score: 10219.479
# 150/1000 epoch ge_loss: 2.015 d_loss: 0.224 anomaly_score: 11262.879
# 151/1000 epoch ge_loss: 2.067 d_loss: 0.244 anomaly_score: 10756.630
# 152/1000 epoch ge_loss: 1.924 d_loss: 0.200 anomaly_score: 12232.529
# 153/1000 epoch ge_loss: 1.981 d_loss: 0.184 anomaly_score: 12321.861
# 154/1000 epoch ge_loss: 2.291 d_loss: 0.238 anomaly_score: 8598.318
# 155/1000 epoch ge_loss: 2.091 d_loss: 0.259 anomaly_score: 8929.758
# 156/1000 epoch ge_loss: 2.029 d_loss: 0.210 anomaly_score: 12170.932
# 157/1000 epoch ge_loss: 2.127 d_loss: 0.212 anomaly_score: 12310.410
# 158/1000 epoch ge_loss: 2.072 d_loss: 0.259 anomaly_score: 11677.107
# 159/1000 epoch ge_loss: 1.984 d_loss: 0.219 anomaly_score: 8371.069
# 160/1000 epoch ge_loss: 2.046 d_loss: 0.241 anomaly_score: 7341.231
# 161/1000 epoch ge_loss: 1.891 d_loss: 0.232 anomaly_score: 9737.160
# 162/1000 epoch ge_loss: 2.144 d_loss: 0.198 anomaly_score: 11308.568
# 163/1000 epoch ge_loss: 2.098 d_loss: 0.214 anomaly_score: 11048.063
# 164/1000 epoch ge_loss: 2.134 d_loss: 0.187 anomaly_score: 11160.520
# 165/1000 epoch ge_loss: 2.194 d_loss: 0.190 anomaly_score: 10552.649
# 166/1000 epoch ge_loss: 2.336 d_loss: 0.242 anomaly_score: 9513.465
# 167/1000 epoch ge_loss: 2.115 d_loss: 0.221 anomaly_score: 10869.107
# 168/1000 epoch ge_loss: 2.105 d_loss: 0.233 anomaly_score: 10180.194
# 169/1000 epoch ge_loss: 2.079 d_loss: 0.212 anomaly_score: 10145.277
# 170/1000 epoch ge_loss: 2.123 d_loss: 0.194 anomaly_score: 8458.723
# 171/1000 epoch ge_loss: 2.319 d_loss: 0.251 anomaly_score: 9839.517
# 172/1000 epoch ge_loss: 2.100 d_loss: 0.265 anomaly_score: 11782.665
# 173/1000 epoch ge_loss: 2.131 d_loss: 0.250 anomaly_score: 11520.770
# 174/1000 epoch ge_loss: 1.954 d_loss: 0.234 anomaly_score: 10445.813
# 175/1000 epoch ge_loss: 2.141 d_loss: 0.159 anomaly_score: 9953.087
# 176/1000 epoch ge_loss: 2.180 d_loss: 0.205 anomaly_score: 9807.766
# 177/1000 epoch ge_loss: 2.344 d_loss: 0.188 anomaly_score: 9717.615
# 178/1000 epoch ge_loss: 2.225 d_loss: 0.178 anomaly_score: 9510.058
# 179/1000 epoch ge_loss: 2.191 d_loss: 0.242 anomaly_score: 10295.540
# 180/1000 epoch ge_loss: 2.177 d_loss: 0.269 anomaly_score: 9756.764
# 181/1000 epoch ge_loss: 2.081 d_loss: 0.189 anomaly_score: 10723.617
# 182/1000 epoch ge_loss: 2.161 d_loss: 0.193 anomaly_score: 9240.576
# 183/1000 epoch ge_loss: 2.376 d_loss: 0.185 anomaly_score: 9759.185
# 184/1000 epoch ge_loss: 2.384 d_loss: 0.219 anomaly_score: 12506.610
# 185/1000 epoch ge_loss: 2.196 d_loss: 0.238 anomaly_score: 12119.787
# 186/1000 epoch ge_loss: 2.356 d_loss: 0.193 anomaly_score: 9065.525
# 187/1000 epoch ge_loss: 2.340 d_loss: 0.189 anomaly_score: 9479.683
# 188/1000 epoch ge_loss: 2.359 d_loss: 0.233 anomaly_score: 9847.870
# 189/1000 epoch ge_loss: 2.398 d_loss: 0.203 anomaly_score: 10812.504
# 190/1000 epoch ge_loss: 2.552 d_loss: 0.223 anomaly_score: 9677.820
# 191/1000 epoch ge_loss: 2.125 d_loss: 0.227 anomaly_score: 8227.216
# 192/1000 epoch ge_loss: 2.327 d_loss: 0.230 anomaly_score: 9704.741
# 193/1000 epoch ge_loss: 2.199 d_loss: 0.228 anomaly_score: 11502.410
# 194/1000 epoch ge_loss: 2.187 d_loss: 0.203 anomaly_score: 10796.726
# 195/1000 epoch ge_loss: 2.256 d_loss: 0.191 anomaly_score: 10778.973
# 196/1000 epoch ge_loss: 2.466 d_loss: 0.184 anomaly_score: 10603.269
# 197/1000 epoch ge_loss: 2.383 d_loss: 0.176 anomaly_score: 9033.587
# 198/1000 epoch ge_loss: 2.315 d_loss: 0.176 anomaly_score: 10253.344
# 199/1000 epoch ge_loss: 2.562 d_loss: 0.165 anomaly_score: 10095.073
# 200/1000 epoch ge_loss: 2.473 d_loss: 0.175 anomaly_score: 9059.724
# 201/1000 epoch ge_loss: 2.360 d_loss: 0.234 anomaly_score: 7457.913
# 202/1000 epoch ge_loss: 2.133 d_loss: 0.255 anomaly_score: 9021.416
# 203/1000 epoch ge_loss: 2.242 d_loss: 0.152 anomaly_score: 10779.602
# 204/1000 epoch ge_loss: 2.402 d_loss: 0.194 anomaly_score: 12331.123
# 205/1000 epoch ge_loss: 2.367 d_loss: 0.237 anomaly_score: 8644.437
# 206/1000 epoch ge_loss: 2.251 d_loss: 0.185 anomaly_score: 7938.159
# 207/1000 epoch ge_loss: 2.219 d_loss: 0.180 anomaly_score: 8300.708
# 208/1000 epoch ge_loss: 2.464 d_loss: 0.159 anomaly_score: 7926.843
# 209/1000 epoch ge_loss: 2.315 d_loss: 0.188 anomaly_score: 7438.395
# 210/1000 epoch ge_loss: 2.396 d_loss: 0.188 anomaly_score: 7794.751
# 211/1000 epoch ge_loss: 2.370 d_loss: 0.164 anomaly_score: 7080.369
# 212/1000 epoch ge_loss: 2.394 d_loss: 0.167 anomaly_score: 9180.541
# 213/1000 epoch ge_loss: 2.429 d_loss: 0.184 anomaly_score: 8073.679
# 214/1000 epoch ge_loss: 2.458 d_loss: 0.220 anomaly_score: 8868.149
# 215/1000 epoch ge_loss: 2.431 d_loss: 0.190 anomaly_score: 8387.003
# 216/1000 epoch ge_loss: 2.424 d_loss: 0.233 anomaly_score: 10262.742
# 217/1000 epoch ge_loss: 2.214 d_loss: 0.144 anomaly_score: 7329.496
# 218/1000 epoch ge_loss: 2.453 d_loss: 0.171 anomaly_score: 8178.363
# 219/1000 epoch ge_loss: 2.621 d_loss: 0.153 anomaly_score: 10657.890
# 220/1000 epoch ge_loss: 2.525 d_loss: 0.180 anomaly_score: 11836.856
# 221/1000 epoch ge_loss: 2.517 d_loss: 0.209 anomaly_score: 8749.974
# 222/1000 epoch ge_loss: 2.539 d_loss: 0.243 anomaly_score: 8967.246
# 223/1000 epoch ge_loss: 2.319 d_loss: 0.171 anomaly_score: 9122.348
# 224/1000 epoch ge_loss: 2.467 d_loss: 0.183 anomaly_score: 10319.796
# 225/1000 epoch ge_loss: 2.554 d_loss: 0.202 anomaly_score: 8226.349
# 226/1000 epoch ge_loss: 2.384 d_loss: 0.194 anomaly_score: 8907.784
# 227/1000 epoch ge_loss: 2.466 d_loss: 0.169 anomaly_score: 8238.544
# 228/1000 epoch ge_loss: 2.425 d_loss: 0.158 anomaly_score: 8928.090
# 229/1000 epoch ge_loss: 2.781 d_loss: 0.155 anomaly_score: 9651.694
# 230/1000 epoch ge_loss: 2.579 d_loss: 0.236 anomaly_score: 11613.183
# 231/1000 epoch ge_loss: 2.519 d_loss: 0.136 anomaly_score: 11768.330
# 232/1000 epoch ge_loss: 2.450 d_loss: 0.158 anomaly_score: 8723.157
# 233/1000 epoch ge_loss: 2.668 d_loss: 0.141 anomaly_score: 9878.248
# 234/1000 epoch ge_loss: 2.524 d_loss: 0.225 anomaly_score: 8430.607
# 235/1000 epoch ge_loss: 2.542 d_loss: 0.178 anomaly_score: 12515.705
# 236/1000 epoch ge_loss: 2.599 d_loss: 0.199 anomaly_score: 11444.380
# 237/1000 epoch ge_loss: 2.432 d_loss: 0.177 anomaly_score: 10576.086
# 238/1000 epoch ge_loss: 2.517 d_loss: 0.151 anomaly_score: 9579.543
# 239/1000 epoch ge_loss: 2.582 d_loss: 0.168 anomaly_score: 9188.692
# 240/1000 epoch ge_loss: 2.566 d_loss: 0.185 anomaly_score: 8261.489
# 241/1000 epoch ge_loss: 2.742 d_loss: 0.169 anomaly_score: 7743.995
# 242/1000 epoch ge_loss: 2.569 d_loss: 0.159 anomaly_score: 9886.756
# 243/1000 epoch ge_loss: 2.636 d_loss: 0.179 anomaly_score: 11681.266
# 244/1000 epoch ge_loss: 2.543 d_loss: 0.133 anomaly_score: 11375.009
# 245/1000 epoch ge_loss: 2.578 d_loss: 0.172 anomaly_score: 9720.479
# 246/1000 epoch ge_loss: 2.623 d_loss: 0.176 anomaly_score: 12221.886
# 247/1000 epoch ge_loss: 2.788 d_loss: 0.168 anomaly_score: 9610.965
# 248/1000 epoch ge_loss: 2.491 d_loss: 0.197 anomaly_score: 8992.205
# 249/1000 epoch ge_loss: 2.674 d_loss: 0.172 anomaly_score: 9082.351
# 250/1000 epoch ge_loss: 2.822 d_loss: 0.146 anomaly_score: 9913.107
# 251/1000 epoch ge_loss: 2.869 d_loss: 0.140 anomaly_score: 9176.965
# 252/1000 epoch ge_loss: 2.749 d_loss: 0.181 anomaly_score: 10935.968
# 253/1000 epoch ge_loss: 2.484 d_loss: 0.152 anomaly_score: 13365.451
# 254/1000 epoch ge_loss: 2.573 d_loss: 0.168 anomaly_score: 10904.469
# 255/1000 epoch ge_loss: 2.766 d_loss: 0.177 anomaly_score: 10469.817
# 256/1000 epoch ge_loss: 2.717 d_loss: 0.181 anomaly_score: 9161.287
# 257/1000 epoch ge_loss: 2.592 d_loss: 0.216 anomaly_score: 8271.314
# 258/1000 epoch ge_loss: 2.616 d_loss: 0.186 anomaly_score: 12858.552
# 259/1000 epoch ge_loss: 2.686 d_loss: 0.159 anomaly_score: 12190.308
# 260/1000 epoch ge_loss: 2.687 d_loss: 0.157 anomaly_score: 9031.100
# 261/1000 epoch ge_loss: 2.648 d_loss: 0.146 anomaly_score: 8268.419
# 262/1000 epoch ge_loss: 2.841 d_loss: 0.133 anomaly_score: 8764.469
# 263/1000 epoch ge_loss: 2.851 d_loss: 0.145 anomaly_score: 11535.921
# 264/1000 epoch ge_loss: 2.723 d_loss: 0.174 anomaly_score: 9011.456
# 265/1000 epoch ge_loss: 2.773 d_loss: 0.172 anomaly_score: 8243.377
# 266/1000 epoch ge_loss: 2.507 d_loss: 0.243 anomaly_score: 9448.454
# 267/1000 epoch ge_loss: 2.569 d_loss: 0.171 anomaly_score: 10743.782
# 268/1000 epoch ge_loss: 2.541 d_loss: 0.157 anomaly_score: 9466.087
# 269/1000 epoch ge_loss: 2.470 d_loss: 0.214 anomaly_score: 9500.196
# 270/1000 epoch ge_loss: 2.577 d_loss: 0.163 anomaly_score: 7383.781
# 271/1000 epoch ge_loss: 2.651 d_loss: 0.144 anomaly_score: 10212.886
# 272/1000 epoch ge_loss: 2.724 d_loss: 0.152 anomaly_score: 11927.145
# 273/1000 epoch ge_loss: 2.650 d_loss: 0.133 anomaly_score: 9243.553
# 274/1000 epoch ge_loss: 2.748 d_loss: 0.144 anomaly_score: 7430.574
# 275/1000 epoch ge_loss: 2.711 d_loss: 0.193 anomaly_score: 8750.708
# 276/1000 epoch ge_loss: 2.659 d_loss: 0.184 anomaly_score: 8403.468
# 277/1000 epoch ge_loss: 2.544 d_loss: 0.202 anomaly_score: 8632.067
# 278/1000 epoch ge_loss: 2.420 d_loss: 0.145 anomaly_score: 8071.500
# 279/1000 epoch ge_loss: 2.542 d_loss: 0.167 anomaly_score: 8043.231
# 280/1000 epoch ge_loss: 2.620 d_loss: 0.170 anomaly_score: 7663.478
# 281/1000 epoch ge_loss: 2.790 d_loss: 0.130 anomaly_score: 7731.671
# 282/1000 epoch ge_loss: 2.901 d_loss: 0.167 anomaly_score: 8522.306
# 283/1000 epoch ge_loss: 2.670 d_loss: 0.168 anomaly_score: 10989.912
# 284/1000 epoch ge_loss: 2.703 d_loss: 0.271 anomaly_score: 7886.361
# 285/1000 epoch ge_loss: 2.497 d_loss: 0.168 anomaly_score: 10784.572
# 286/1000 epoch ge_loss: 2.633 d_loss: 0.153 anomaly_score: 10445.550
# 287/1000 epoch ge_loss: 2.645 d_loss: 0.194 anomaly_score: 9079.549
# 288/1000 epoch ge_loss: 2.698 d_loss: 0.164 anomaly_score: 9194.986
# 289/1000 epoch ge_loss: 2.764 d_loss: 0.147 anomaly_score: 10040.302
# 290/1000 epoch ge_loss: 2.913 d_loss: 0.151 anomaly_score: 8788.004
# 291/1000 epoch ge_loss: 2.555 d_loss: 0.235 anomaly_score: 13558.652
# 292/1000 epoch ge_loss: 2.682 d_loss: 0.138 anomaly_score: 11539.105
# 293/1000 epoch ge_loss: 2.592 d_loss: 0.165 anomaly_score: 9572.563
# 294/1000 epoch ge_loss: 2.696 d_loss: 0.127 anomaly_score: 8664.353
# 295/1000 epoch ge_loss: 2.642 d_loss: 0.148 anomaly_score: 8070.092
# 296/1000 epoch ge_loss: 2.692 d_loss: 0.125 anomaly_score: 8814.693
# 297/1000 epoch ge_loss: 2.631 d_loss: 0.213 anomaly_score: 11759.646
# 298/1000 epoch ge_loss: 2.711 d_loss: 0.193 anomaly_score: 10389.813
# 299/1000 epoch ge_loss: 2.438 d_loss: 0.165 anomaly_score: 8714.885
# 300/1000 epoch ge_loss: 2.686 d_loss: 0.176 anomaly_score: 9272.158
# 301/1000 epoch ge_loss: 2.622 d_loss: 0.148 anomaly_score: 7731.896
# 302/1000 epoch ge_loss: 2.670 d_loss: 0.163 anomaly_score: 8316.081
# 303/1000 epoch ge_loss: 2.896 d_loss: 0.133 anomaly_score: 7831.855
# 304/1000 epoch ge_loss: 2.905 d_loss: 0.126 anomaly_score: 8852.505
# 305/1000 epoch ge_loss: 2.764 d_loss: 0.127 anomaly_score: 8721.911
# 306/1000 epoch ge_loss: 2.747 d_loss: 0.155 anomaly_score: 8997.422
# 307/1000 epoch ge_loss: 2.879 d_loss: 0.157 anomaly_score: 10193.950
# 308/1000 epoch ge_loss: 2.904 d_loss: 0.136 anomaly_score: 11591.198
# 309/1000 epoch ge_loss: 2.824 d_loss: 0.157 anomaly_score: 9822.303
# 310/1000 epoch ge_loss: 2.942 d_loss: 0.166 anomaly_score: 8197.214
# 311/1000 epoch ge_loss: 2.890 d_loss: 0.138 anomaly_score: 8517.232
# 312/1000 epoch ge_loss: 2.759 d_loss: 0.194 anomaly_score: 9724.431
# 313/1000 epoch ge_loss: 2.587 d_loss: 0.183 anomaly_score: 8873.264
# 314/1000 epoch ge_loss: 3.016 d_loss: 0.153 anomaly_score: 8841.221
# 315/1000 epoch ge_loss: 2.791 d_loss: 0.134 anomaly_score: 9175.299
# 316/1000 epoch ge_loss: 2.887 d_loss: 0.148 anomaly_score: 11630.933
# 317/1000 epoch ge_loss: 2.960 d_loss: 0.173 anomaly_score: 8090.481
# 318/1000 epoch ge_loss: 2.725 d_loss: 0.135 anomaly_score: 8892.158
# 319/1000 epoch ge_loss: 2.802 d_loss: 0.158 anomaly_score: 9960.510
# 320/1000 epoch ge_loss: 2.774 d_loss: 0.148 anomaly_score: 8421.111
# 321/1000 epoch ge_loss: 3.119 d_loss: 0.191 anomaly_score: 8049.784
# 322/1000 epoch ge_loss: 2.846 d_loss: 0.164 anomaly_score: 11147.667
# 323/1000 epoch ge_loss: 2.682 d_loss: 0.138 anomaly_score: 10357.999
# 324/1000 epoch ge_loss: 2.601 d_loss: 0.190 anomaly_score: 8835.382
# 325/1000 epoch ge_loss: 2.606 d_loss: 0.141 anomaly_score: 8662.517
# 326/1000 epoch ge_loss: 2.719 d_loss: 0.160 anomaly_score: 7277.369
# 327/1000 epoch ge_loss: 2.543 d_loss: 0.152 anomaly_score: 10904.063
# 328/1000 epoch ge_loss: 2.756 d_loss: 0.125 anomaly_score: 13305.810
# 329/1000 epoch ge_loss: 2.842 d_loss: 0.172 anomaly_score: 9791.046
# 330/1000 epoch ge_loss: 2.650 d_loss: 0.153 anomaly_score: 9735.302
# 331/1000 epoch ge_loss: 2.888 d_loss: 0.121 anomaly_score: 9643.956
# 332/1000 epoch ge_loss: 2.736 d_loss: 0.163 anomaly_score: 10351.300
# 333/1000 epoch ge_loss: 2.984 d_loss: 0.126 anomaly_score: 8589.008
# 334/1000 epoch ge_loss: 2.791 d_loss: 0.181 anomaly_score: 8934.950
# 335/1000 epoch ge_loss: 2.721 d_loss: 0.145 anomaly_score: 8094.386
# 336/1000 epoch ge_loss: 2.719 d_loss: 0.155 anomaly_score: 7894.022
# 337/1000 epoch ge_loss: 2.782 d_loss: 0.162 anomaly_score: 8393.982
# 338/1000 epoch ge_loss: 2.773 d_loss: 0.126 anomaly_score: 8654.543
# 339/1000 epoch ge_loss: 2.716 d_loss: 0.167 anomaly_score: 10545.086
# 340/1000 epoch ge_loss: 2.787 d_loss: 0.129 anomaly_score: 9057.804
# 341/1000 epoch ge_loss: 2.918 d_loss: 0.144 anomaly_score: 7997.050
# 342/1000 epoch ge_loss: 2.976 d_loss: 0.143 anomaly_score: 8158.138
# 343/1000 epoch ge_loss: 2.790 d_loss: 0.212 anomaly_score: 7410.989
# 344/1000 epoch ge_loss: 2.927 d_loss: 0.123 anomaly_score: 7630.870
# 345/1000 epoch ge_loss: 2.977 d_loss: 0.124 anomaly_score: 10332.909
# 346/1000 epoch ge_loss: 2.869 d_loss: 0.175 anomaly_score: 14409.050
# 347/1000 epoch ge_loss: 2.906 d_loss: 0.140 anomaly_score: 10993.215
# 348/1000 epoch ge_loss: 2.885 d_loss: 0.141 anomaly_score: 10389.181
# 349/1000 epoch ge_loss: 2.903 d_loss: 0.163 anomaly_score: 9934.698
# 350/1000 epoch ge_loss: 2.847 d_loss: 0.132 anomaly_score: 8370.247
# 351/1000 epoch ge_loss: 2.664 d_loss: 0.146 anomaly_score: 9105.750
# 352/1000 epoch ge_loss: 2.832 d_loss: 0.146 anomaly_score: 7869.093
# 353/1000 epoch ge_loss: 2.919 d_loss: 0.121 anomaly_score: 8590.903
# 354/1000 epoch ge_loss: 2.931 d_loss: 0.143 anomaly_score: 8263.197
# 355/1000 epoch ge_loss: 2.949 d_loss: 0.151 anomaly_score: 9444.389
# 356/1000 epoch ge_loss: 2.925 d_loss: 0.145 anomaly_score: 8662.814
# 357/1000 epoch ge_loss: 2.883 d_loss: 0.160 anomaly_score: 6714.567
# 358/1000 epoch ge_loss: 2.803 d_loss: 0.164 anomaly_score: 8497.389
# 359/1000 epoch ge_loss: 2.827 d_loss: 0.139 anomaly_score: 9450.881
# 360/1000 epoch ge_loss: 2.883 d_loss: 0.101 anomaly_score: 9572.641
# 361/1000 epoch ge_loss: 2.671 d_loss: 0.167 anomaly_score: 9756.360
# 362/1000 epoch ge_loss: 2.896 d_loss: 0.114 anomaly_score: 8587.561
# 363/1000 epoch ge_loss: 2.961 d_loss: 0.119 anomaly_score: 8077.053
# 364/1000 epoch ge_loss: 2.855 d_loss: 0.124 anomaly_score: 8439.438
# 365/1000 epoch ge_loss: 3.081 d_loss: 0.168 anomaly_score: 7783.720
# 366/1000 epoch ge_loss: 3.079 d_loss: 0.124 anomaly_score: 9247.096
# 367/1000 epoch ge_loss: 2.957 d_loss: 0.124 anomaly_score: 10289.249
# 368/1000 epoch ge_loss: 2.767 d_loss: 0.199 anomaly_score: 9982.715
# 369/1000 epoch ge_loss: 2.920 d_loss: 0.155 anomaly_score: 9328.402
# 370/1000 epoch ge_loss: 2.912 d_loss: 0.116 anomaly_score: 7713.336
# 371/1000 epoch ge_loss: 2.858 d_loss: 0.155 anomaly_score: 8033.712
# 372/1000 epoch ge_loss: 2.751 d_loss: 0.148 anomaly_score: 7437.868
# 373/1000 epoch ge_loss: 2.953 d_loss: 0.145 anomaly_score: 8124.178
# 374/1000 epoch ge_loss: 3.109 d_loss: 0.127 anomaly_score: 8057.024
# 375/1000 epoch ge_loss: 3.086 d_loss: 0.141 anomaly_score: 8671.273
# 376/1000 epoch ge_loss: 3.067 d_loss: 0.151 anomaly_score: 13434.588
# 377/1000 epoch ge_loss: 2.938 d_loss: 0.139 anomaly_score: 11515.430
# 378/1000 epoch ge_loss: 2.714 d_loss: 0.177 anomaly_score: 7838.274
# 379/1000 epoch ge_loss: 2.909 d_loss: 0.180 anomaly_score: 7537.357
# 380/1000 epoch ge_loss: 2.804 d_loss: 0.162 anomaly_score: 9437.057
# 381/1000 epoch ge_loss: 2.823 d_loss: 0.161 anomaly_score: 6610.587
# 382/1000 epoch ge_loss: 2.749 d_loss: 0.123 anomaly_score: 7416.400
# 383/1000 epoch ge_loss: 2.866 d_loss: 0.136 anomaly_score: 9627.744
# 384/1000 epoch ge_loss: 2.865 d_loss: 0.119 anomaly_score: 7758.707
# 385/1000 epoch ge_loss: 2.937 d_loss: 0.116 anomaly_score: 8622.411
# 386/1000 epoch ge_loss: 3.191 d_loss: 0.092 anomaly_score: 7823.614
# 387/1000 epoch ge_loss: 2.821 d_loss: 0.139 anomaly_score: 10618.429
# 388/1000 epoch ge_loss: 2.914 d_loss: 0.106 anomaly_score: 11072.411
# 389/1000 epoch ge_loss: 2.967 d_loss: 0.150 anomaly_score: 8262.787
# 390/1000 epoch ge_loss: 2.948 d_loss: 0.133 anomaly_score: 8420.327
# 391/1000 epoch ge_loss: 2.822 d_loss: 0.107 anomaly_score: 8816.037
# 392/1000 epoch ge_loss: 2.895 d_loss: 0.129 anomaly_score: 9541.451
# 393/1000 epoch ge_loss: 3.116 d_loss: 0.132 anomaly_score: 11736.787
# 394/1000 epoch ge_loss: 3.218 d_loss: 0.126 anomaly_score: 11421.260
# 395/1000 epoch ge_loss: 2.945 d_loss: 0.125 anomaly_score: 8809.955
# 396/1000 epoch ge_loss: 3.104 d_loss: 0.115 anomaly_score: 9553.353
# 397/1000 epoch ge_loss: 2.992 d_loss: 0.168 anomaly_score: 9345.689
# 398/1000 epoch ge_loss: 3.203 d_loss: 0.117 anomaly_score: 7831.350
# 399/1000 epoch ge_loss: 2.993 d_loss: 0.178 anomaly_score: 7273.595
# 400/1000 epoch ge_loss: 3.009 d_loss: 0.157 anomaly_score: 12083.969
# 401/1000 epoch ge_loss: 3.038 d_loss: 0.106 anomaly_score: 9571.800
# 402/1000 epoch ge_loss: 3.089 d_loss: 0.110 anomaly_score: 11177.336
# 403/1000 epoch ge_loss: 3.182 d_loss: 0.163 anomaly_score: 10346.432
# 404/1000 epoch ge_loss: 3.030 d_loss: 0.161 anomaly_score: 8461.914
# 405/1000 epoch ge_loss: 2.958 d_loss: 0.136 anomaly_score: 9151.474
# 406/1000 epoch ge_loss: 3.019 d_loss: 0.134 anomaly_score: 9388.671
# 407/1000 epoch ge_loss: 3.060 d_loss: 0.135 anomaly_score: 9456.683
# 408/1000 epoch ge_loss: 3.146 d_loss: 0.161 anomaly_score: 8088.712
# 409/1000 epoch ge_loss: 2.982 d_loss: 0.145 anomaly_score: 8331.118
# 410/1000 epoch ge_loss: 2.831 d_loss: 0.129 anomaly_score: 9527.028
# 411/1000 epoch ge_loss: 2.924 d_loss: 0.123 anomaly_score: 8320.457
# 412/1000 epoch ge_loss: 3.039 d_loss: 0.146 anomaly_score: 9546.642
# 413/1000 epoch ge_loss: 3.037 d_loss: 0.154 anomaly_score: 9909.168
# 414/1000 epoch ge_loss: 3.063 d_loss: 0.100 anomaly_score: 7902.079
# 415/1000 epoch ge_loss: 3.146 d_loss: 0.118 anomaly_score: 9438.861
# 416/1000 epoch ge_loss: 3.256 d_loss: 0.117 anomaly_score: 10509.909
# 417/1000 epoch ge_loss: 2.936 d_loss: 0.110 anomaly_score: 10413.470
# 418/1000 epoch ge_loss: 3.085 d_loss: 0.107 anomaly_score: 9453.894
# 419/1000 epoch ge_loss: 3.317 d_loss: 0.082 anomaly_score: 10177.917
# 420/1000 epoch ge_loss: 3.207 d_loss: 0.149 anomaly_score: 8612.668
# 421/1000 epoch ge_loss: 3.473 d_loss: 0.155 anomaly_score: 8404.498
# 422/1000 epoch ge_loss: 3.035 d_loss: 0.119 anomaly_score: 8693.838
# 423/1000 epoch ge_loss: 3.254 d_loss: 0.130 anomaly_score: 8384.667
# 424/1000 epoch ge_loss: 3.139 d_loss: 0.174 anomaly_score: 8523.691
# 425/1000 epoch ge_loss: 3.002 d_loss: 0.134 anomaly_score: 9214.903
# 426/1000 epoch ge_loss: 2.923 d_loss: 0.120 anomaly_score: 10208.953
# 427/1000 epoch ge_loss: 3.301 d_loss: 0.119 anomaly_score: 10505.792
# 428/1000 epoch ge_loss: 3.025 d_loss: 0.137 anomaly_score: 8307.927
# 429/1000 epoch ge_loss: 2.874 d_loss: 0.152 anomaly_score: 7568.443
# 430/1000 epoch ge_loss: 3.053 d_loss: 0.131 anomaly_score: 8139.860
# 431/1000 epoch ge_loss: 2.898 d_loss: 0.118 anomaly_score: 10069.591
# 432/1000 epoch ge_loss: 3.255 d_loss: 0.107 anomaly_score: 12439.939
# 433/1000 epoch ge_loss: 3.086 d_loss: 0.105 anomaly_score: 12355.554
# 434/1000 epoch ge_loss: 2.973 d_loss: 0.104 anomaly_score: 9573.235
# 435/1000 epoch ge_loss: 3.162 d_loss: 0.126 anomaly_score: 8302.972
# 436/1000 epoch ge_loss: 3.486 d_loss: 0.118 anomaly_score: 7555.079
# 437/1000 epoch ge_loss: 3.091 d_loss: 0.133 anomaly_score: 8200.931
# 438/1000 epoch ge_loss: 3.153 d_loss: 0.140 anomaly_score: 8583.628
# 439/1000 epoch ge_loss: 3.403 d_loss: 0.107 anomaly_score: 8524.456
# 440/1000 epoch ge_loss: 3.228 d_loss: 0.118 anomaly_score: 11850.178
# 441/1000 epoch ge_loss: 3.187 d_loss: 0.129 anomaly_score: 13001.920
# 442/1000 epoch ge_loss: 3.276 d_loss: 0.129 anomaly_score: 10971.263
# 443/1000 epoch ge_loss: 3.222 d_loss: 0.087 anomaly_score: 8738.076
# 444/1000 epoch ge_loss: 3.262 d_loss: 0.117 anomaly_score: 9253.005
# 445/1000 epoch ge_loss: 3.208 d_loss: 0.114 anomaly_score: 8763.254
# 446/1000 epoch ge_loss: 3.195 d_loss: 0.084 anomaly_score: 7970.896
# 447/1000 epoch ge_loss: 3.068 d_loss: 0.166 anomaly_score: 9862.071
# 448/1000 epoch ge_loss: 3.130 d_loss: 0.172 anomaly_score: 10747.450
# 449/1000 epoch ge_loss: 3.053 d_loss: 0.129 anomaly_score: 10685.376
# 450/1000 epoch ge_loss: 3.353 d_loss: 0.122 anomaly_score: 9182.455
# 451/1000 epoch ge_loss: 2.919 d_loss: 0.137 anomaly_score: 9229.157
# 452/1000 epoch ge_loss: 3.201 d_loss: 0.129 anomaly_score: 11000.783
# 453/1000 epoch ge_loss: 3.027 d_loss: 0.114 anomaly_score: 7714.327
# 454/1000 epoch ge_loss: 3.007 d_loss: 0.144 anomaly_score: 9423.253
# 455/1000 epoch ge_loss: 3.121 d_loss: 0.136 anomaly_score: 8698.644
# 456/1000 epoch ge_loss: 3.218 d_loss: 0.132 anomaly_score: 9185.958
# 457/1000 epoch ge_loss: 3.070 d_loss: 0.110 anomaly_score: 10278.360
# 458/1000 epoch ge_loss: 3.155 d_loss: 0.129 anomaly_score: 11881.760
# 459/1000 epoch ge_loss: 3.013 d_loss: 0.111 anomaly_score: 10342.836
# 460/1000 epoch ge_loss: 2.830 d_loss: 0.146 anomaly_score: 9160.245
# 461/1000 epoch ge_loss: 3.235 d_loss: 0.131 anomaly_score: 7393.904
# 462/1000 epoch ge_loss: 2.940 d_loss: 0.122 anomaly_score: 8967.742
# 463/1000 epoch ge_loss: 3.161 d_loss: 0.097 anomaly_score: 10271.559
# 464/1000 epoch ge_loss: 3.041 d_loss: 0.124 anomaly_score: 11209.880
# 465/1000 epoch ge_loss: 3.316 d_loss: 0.086 anomaly_score: 11568.806
# 466/1000 epoch ge_loss: 2.875 d_loss: 0.123 anomaly_score: 11808.712
# 467/1000 epoch ge_loss: 3.232 d_loss: 0.121 anomaly_score: 13917.161
# 468/1000 epoch ge_loss: 3.249 d_loss: 0.147 anomaly_score: 12001.563
# 469/1000 epoch ge_loss: 3.017 d_loss: 0.142 anomaly_score: 8468.320
# 470/1000 epoch ge_loss: 3.152 d_loss: 0.103 anomaly_score: 8873.691
# 471/1000 epoch ge_loss: 3.096 d_loss: 0.103 anomaly_score: 7835.307
# 472/1000 epoch ge_loss: 3.223 d_loss: 0.149 anomaly_score: 6781.826
# 473/1000 epoch ge_loss: 3.105 d_loss: 0.128 anomaly_score: 7233.673
# 474/1000 epoch ge_loss: 3.427 d_loss: 0.130 anomaly_score: 7211.017
# 475/1000 epoch ge_loss: 3.287 d_loss: 0.121 anomaly_score: 8167.705
# 476/1000 epoch ge_loss: 3.180 d_loss: 0.129 anomaly_score: 9236.029
# 477/1000 epoch ge_loss: 3.122 d_loss: 0.117 anomaly_score: 8297.852
# 478/1000 epoch ge_loss: 3.629 d_loss: 0.133 anomaly_score: 7907.121
# 479/1000 epoch ge_loss: 3.231 d_loss: 0.090 anomaly_score: 8582.488
# 480/1000 epoch ge_loss: 3.336 d_loss: 0.115 anomaly_score: 8704.135
# 481/1000 epoch ge_loss: 3.028 d_loss: 0.156 anomaly_score: 7930.536
# 482/1000 epoch ge_loss: 3.338 d_loss: 0.102 anomaly_score: 8177.238
# 483/1000 epoch ge_loss: 3.509 d_loss: 0.134 anomaly_score: 7380.385
# 484/1000 epoch ge_loss: 3.176 d_loss: 0.141 anomaly_score: 8478.395
# 485/1000 epoch ge_loss: 3.330 d_loss: 0.144 anomaly_score: 9769.147
# 486/1000 epoch ge_loss: 3.130 d_loss: 0.126 anomaly_score: 13032.660
# 487/1000 epoch ge_loss: 3.471 d_loss: 0.134 anomaly_score: 11596.068
# 488/1000 epoch ge_loss: 3.298 d_loss: 0.158 anomaly_score: 11214.747
# 489/1000 epoch ge_loss: 3.041 d_loss: 0.182 anomaly_score: 7768.773
# 490/1000 epoch ge_loss: 3.186 d_loss: 0.113 anomaly_score: 8057.002
# 491/1000 epoch ge_loss: 2.961 d_loss: 0.128 anomaly_score: 7836.376
# 492/1000 epoch ge_loss: 3.135 d_loss: 0.088 anomaly_score: 8504.867
# 493/1000 epoch ge_loss: 3.168 d_loss: 0.118 anomaly_score: 7899.812
# 494/1000 epoch ge_loss: 3.175 d_loss: 0.119 anomaly_score: 8356.864
# 495/1000 epoch ge_loss: 3.238 d_loss: 0.113 anomaly_score: 9416.716
# 496/1000 epoch ge_loss: 3.182 d_loss: 0.106 anomaly_score: 9542.781
# 497/1000 epoch ge_loss: 2.996 d_loss: 0.108 anomaly_score: 8844.388
# 498/1000 epoch ge_loss: 3.328 d_loss: 0.128 anomaly_score: 7352.902
# 499/1000 epoch ge_loss: 3.275 d_loss: 0.121 anomaly_score: 7400.961
# 500/1000 epoch ge_loss: 3.005 d_loss: 0.111 anomaly_score: 8012.323
# 501/1000 epoch ge_loss: 3.200 d_loss: 0.086 anomaly_score: 7060.344
# 502/1000 epoch ge_loss: 3.363 d_loss: 0.106 anomaly_score: 7699.514
# 503/1000 epoch ge_loss: 3.069 d_loss: 0.083 anomaly_score: 8614.606
# 504/1000 epoch ge_loss: 3.531 d_loss: 0.091 anomaly_score: 8189.844
# 505/1000 epoch ge_loss: 3.351 d_loss: 0.095 anomaly_score: 7700.982
# 506/1000 epoch ge_loss: 3.378 d_loss: 0.115 anomaly_score: 7479.264
# 507/1000 epoch ge_loss: 3.383 d_loss: 0.063 anomaly_score: 7789.811
# 508/1000 epoch ge_loss: 3.433 d_loss: 0.124 anomaly_score: 7340.677
# 509/1000 epoch ge_loss: 3.479 d_loss: 0.137 anomaly_score: 7351.253
# 510/1000 epoch ge_loss: 3.603 d_loss: 0.082 anomaly_score: 7347.291
# 511/1000 epoch ge_loss: 3.263 d_loss: 0.119 anomaly_score: 8450.068
# 512/1000 epoch ge_loss: 3.564 d_loss: 0.089 anomaly_score: 10080.551
# 513/1000 epoch ge_loss: 3.475 d_loss: 0.109 anomaly_score: 11060.675
# 514/1000 epoch ge_loss: 3.504 d_loss: 0.099 anomaly_score: 9742.935
# 515/1000 epoch ge_loss: 3.526 d_loss: 0.135 anomaly_score: 9039.491
# 516/1000 epoch ge_loss: 3.462 d_loss: 0.119 anomaly_score: 8800.698
# 517/1000 epoch ge_loss: 3.610 d_loss: 0.094 anomaly_score: 9094.138
# 518/1000 epoch ge_loss: 3.373 d_loss: 0.094 anomaly_score: 8952.197
# 519/1000 epoch ge_loss: 3.409 d_loss: 0.127 anomaly_score: 9691.788
# 520/1000 epoch ge_loss: 3.482 d_loss: 0.105 anomaly_score: 8122.999
# 521/1000 epoch ge_loss: 3.555 d_loss: 0.094 anomaly_score: 8585.418
# 522/1000 epoch ge_loss: 3.257 d_loss: 0.157 anomaly_score: 10443.215
# 523/1000 epoch ge_loss: 3.471 d_loss: 0.085 anomaly_score: 11968.679
# 524/1000 epoch ge_loss: 3.503 d_loss: 0.107 anomaly_score: 10565.602
# 525/1000 epoch ge_loss: 3.264 d_loss: 0.102 anomaly_score: 7861.942
# 526/1000 epoch ge_loss: 3.410 d_loss: 0.118 anomaly_score: 9043.020
# 527/1000 epoch ge_loss: 3.296 d_loss: 0.134 anomaly_score: 8809.492
# 528/1000 epoch ge_loss: 3.296 d_loss: 0.142 anomaly_score: 8310.773
# 529/1000 epoch ge_loss: 3.393 d_loss: 0.132 anomaly_score: 8513.376
# 530/1000 epoch ge_loss: 3.324 d_loss: 0.093 anomaly_score: 9214.657
# 531/1000 epoch ge_loss: 3.400 d_loss: 0.101 anomaly_score: 9225.590
# 532/1000 epoch ge_loss: 3.718 d_loss: 0.118 anomaly_score: 9358.203
# 533/1000 epoch ge_loss: 3.493 d_loss: 0.097 anomaly_score: 8726.654
# 534/1000 epoch ge_loss: 3.590 d_loss: 0.097 anomaly_score: 8140.620
# 535/1000 epoch ge_loss: 3.428 d_loss: 0.095 anomaly_score: 8350.041
# 536/1000 epoch ge_loss: 3.451 d_loss: 0.054 anomaly_score: 10484.834
# 537/1000 epoch ge_loss: 3.452 d_loss: 0.135 anomaly_score: 10720.848
# 538/1000 epoch ge_loss: 3.838 d_loss: 0.134 anomaly_score: 8037.874
# 539/1000 epoch ge_loss: 3.648 d_loss: 0.080 anomaly_score: 7074.724
# 540/1000 epoch ge_loss: 3.323 d_loss: 0.108 anomaly_score: 7107.488
# 541/1000 epoch ge_loss: 3.522 d_loss: 0.147 anomaly_score: 7142.508
# 542/1000 epoch ge_loss: 3.470 d_loss: 0.092 anomaly_score: 7611.064
# 543/1000 epoch ge_loss: 3.352 d_loss: 0.082 anomaly_score: 8657.971
# 544/1000 epoch ge_loss: 3.429 d_loss: 0.144 anomaly_score: 9323.499
# 545/1000 epoch ge_loss: 3.639 d_loss: 0.071 anomaly_score: 11419.447
# 546/1000 epoch ge_loss: 3.407 d_loss: 0.086 anomaly_score: 7395.523
# 547/1000 epoch ge_loss: 3.471 d_loss: 0.094 anomaly_score: 7446.745
# 548/1000 epoch ge_loss: 3.806 d_loss: 0.078 anomaly_score: 7205.187
# 549/1000 epoch ge_loss: 3.452 d_loss: 0.113 anomaly_score: 7144.600
# 550/1000 epoch ge_loss: 3.461 d_loss: 0.131 anomaly_score: 7867.580
# 551/1000 epoch ge_loss: 3.280 d_loss: 0.123 anomaly_score: 8808.871
# 552/1000 epoch ge_loss: 3.514 d_loss: 0.159 anomaly_score: 10634.236
# 553/1000 epoch ge_loss: 3.244 d_loss: 0.099 anomaly_score: 9585.018
# 554/1000 epoch ge_loss: 3.398 d_loss: 0.092 anomaly_score: 9845.339
# 555/1000 epoch ge_loss: 3.505 d_loss: 0.081 anomaly_score: 9780.739
# 556/1000 epoch ge_loss: 3.351 d_loss: 0.092 anomaly_score: 9935.736
# 557/1000 epoch ge_loss: 3.448 d_loss: 0.111 anomaly_score: 9769.644
# 558/1000 epoch ge_loss: 3.171 d_loss: 0.123 anomaly_score: 8190.485
# 559/1000 epoch ge_loss: 3.457 d_loss: 0.115 anomaly_score: 9047.181
# 560/1000 epoch ge_loss: 3.527 d_loss: 0.133 anomaly_score: 7220.507
# 561/1000 epoch ge_loss: 3.398 d_loss: 0.100 anomaly_score: 6550.640
# 562/1000 epoch ge_loss: 3.528 d_loss: 0.126 anomaly_score: 7758.494
# 563/1000 epoch ge_loss: 3.419 d_loss: 0.152 anomaly_score: 8363.612
# 564/1000 epoch ge_loss: 3.324 d_loss: 0.127 anomaly_score: 8370.350
# 565/1000 epoch ge_loss: 3.212 d_loss: 0.124 anomaly_score: 11253.018
# 566/1000 epoch ge_loss: 3.564 d_loss: 0.095 anomaly_score: 10966.118
# 567/1000 epoch ge_loss: 3.462 d_loss: 0.119 anomaly_score: 9969.822
# 568/1000 epoch ge_loss: 3.213 d_loss: 0.167 anomaly_score: 8226.154
# 569/1000 epoch ge_loss: 3.414 d_loss: 0.071 anomaly_score: 8869.541
# 570/1000 epoch ge_loss: 3.413 d_loss: 0.078 anomaly_score: 10837.625
# 571/1000 epoch ge_loss: 3.473 d_loss: 0.113 anomaly_score: 9383.862
# 572/1000 epoch ge_loss: 3.403 d_loss: 0.068 anomaly_score: 7852.976
# 573/1000 epoch ge_loss: 3.415 d_loss: 0.112 anomaly_score: 8719.815
# 574/1000 epoch ge_loss: 3.249 d_loss: 0.103 anomaly_score: 8288.069
# 575/1000 epoch ge_loss: 3.538 d_loss: 0.107 anomaly_score: 8845.776
# 576/1000 epoch ge_loss: 3.342 d_loss: 0.110 anomaly_score: 9647.020
# 577/1000 epoch ge_loss: 3.491 d_loss: 0.099 anomaly_score: 8589.542
# 578/1000 epoch ge_loss: 3.695 d_loss: 0.070 anomaly_score: 9573.618
# 579/1000 epoch ge_loss: 3.465 d_loss: 0.085 anomaly_score: 10724.237
# 580/1000 epoch ge_loss: 3.579 d_loss: 0.100 anomaly_score: 11182.267
# 581/1000 epoch ge_loss: 3.514 d_loss: 0.125 anomaly_score: 8298.498
# 582/1000 epoch ge_loss: 4.044 d_loss: 0.086 anomaly_score: 9258.105
# 583/1000 epoch ge_loss: 3.230 d_loss: 0.134 anomaly_score: 8806.111
# 584/1000 epoch ge_loss: 3.537 d_loss: 0.085 anomaly_score: 8457.093
# 585/1000 epoch ge_loss: 3.394 d_loss: 0.090 anomaly_score: 7933.902
# 586/1000 epoch ge_loss: 3.628 d_loss: 0.073 anomaly_score: 8655.589
# 587/1000 epoch ge_loss: 3.612 d_loss: 0.077 anomaly_score: 8908.308
# 588/1000 epoch ge_loss: 3.454 d_loss: 0.093 anomaly_score: 9461.152
# 589/1000 epoch ge_loss: 3.478 d_loss: 0.094 anomaly_score: 9072.891
# 590/1000 epoch ge_loss: 3.556 d_loss: 0.086 anomaly_score: 8552.638
# 591/1000 epoch ge_loss: 3.916 d_loss: 0.061 anomaly_score: 9776.839
# 592/1000 epoch ge_loss: 3.501 d_loss: 0.135 anomaly_score: 9309.728
# 593/1000 epoch ge_loss: 3.837 d_loss: 0.103 anomaly_score: 8274.463
# 594/1000 epoch ge_loss: 3.926 d_loss: 0.089 anomaly_score: 8399.747
# 595/1000 epoch ge_loss: 3.653 d_loss: 0.133 anomaly_score: 8551.697
# 596/1000 epoch ge_loss: 3.633 d_loss: 0.104 anomaly_score: 9941.926
# 597/1000 epoch ge_loss: 3.855 d_loss: 0.121 anomaly_score: 10967.017
# 598/1000 epoch ge_loss: 3.625 d_loss: 0.132 anomaly_score: 10262.570
# 599/1000 epoch ge_loss: 3.523 d_loss: 0.099 anomaly_score: 10267.210
# 600/1000 epoch ge_loss: 3.745 d_loss: 0.119 anomaly_score: 8232.379
# 601/1000 epoch ge_loss: 3.401 d_loss: 0.090 anomaly_score: 7844.294
# 602/1000 epoch ge_loss: 3.390 d_loss: 0.089 anomaly_score: 8902.146
# 603/1000 epoch ge_loss: 3.766 d_loss: 0.083 anomaly_score: 8394.739
# 604/1000 epoch ge_loss: 3.749 d_loss: 0.079 anomaly_score: 8656.096
# 605/1000 epoch ge_loss: 3.586 d_loss: 0.113 anomaly_score: 8470.856
# 606/1000 epoch ge_loss: 3.524 d_loss: 0.090 anomaly_score: 9307.177
# 607/1000 epoch ge_loss: 3.450 d_loss: 0.101 anomaly_score: 10246.377
# 608/1000 epoch ge_loss: 3.510 d_loss: 0.099 anomaly_score: 7746.829
# 609/1000 epoch ge_loss: 3.561 d_loss: 0.150 anomaly_score: 6929.400
# 610/1000 epoch ge_loss: 3.510 d_loss: 0.094 anomaly_score: 7086.401
# 611/1000 epoch ge_loss: 3.524 d_loss: 0.120 anomaly_score: 7283.885
# 612/1000 epoch ge_loss: 3.462 d_loss: 0.093 anomaly_score: 6860.895
# 613/1000 epoch ge_loss: 3.584 d_loss: 0.084 anomaly_score: 6009.073
# 614/1000 epoch ge_loss: 3.506 d_loss: 0.088 anomaly_score: 7077.624
# 615/1000 epoch ge_loss: 3.487 d_loss: 0.080 anomaly_score: 8258.871
# 616/1000 epoch ge_loss: 3.686 d_loss: 0.114 anomaly_score: 8972.915
# 617/1000 epoch ge_loss: 3.592 d_loss: 0.092 anomaly_score: 8288.189
# 618/1000 epoch ge_loss: 3.458 d_loss: 0.117 anomaly_score: 7458.869
# 619/1000 epoch ge_loss: 3.438 d_loss: 0.093 anomaly_score: 8240.160
# 620/1000 epoch ge_loss: 3.423 d_loss: 0.116 anomaly_score: 10576.837
# 621/1000 epoch ge_loss: 3.984 d_loss: 0.103 anomaly_score: 10836.715
# 622/1000 epoch ge_loss: 3.738 d_loss: 0.104 anomaly_score: 11828.741
# 623/1000 epoch ge_loss: 3.294 d_loss: 0.121 anomaly_score: 9566.987
# 624/1000 epoch ge_loss: 3.704 d_loss: 0.092 anomaly_score: 6917.293
# 625/1000 epoch ge_loss: 3.541 d_loss: 0.094 anomaly_score: 7558.437
# 626/1000 epoch ge_loss: 3.632 d_loss: 0.112 anomaly_score: 8382.238
# 627/1000 epoch ge_loss: 3.410 d_loss: 0.110 anomaly_score: 7312.894
# 628/1000 epoch ge_loss: 3.815 d_loss: 0.081 anomaly_score: 7565.379
# 629/1000 epoch ge_loss: 3.560 d_loss: 0.114 anomaly_score: 8471.394
# 630/1000 epoch ge_loss: 3.748 d_loss: 0.083 anomaly_score: 9510.329
# 631/1000 epoch ge_loss: 3.616 d_loss: 0.112 anomaly_score: 7695.246
# 632/1000 epoch ge_loss: 3.655 d_loss: 0.073 anomaly_score: 7892.184
# 633/1000 epoch ge_loss: 3.594 d_loss: 0.074 anomaly_score: 8758.373
# 634/1000 epoch ge_loss: 3.462 d_loss: 0.094 anomaly_score: 8737.047
# 635/1000 epoch ge_loss: 3.866 d_loss: 0.076 anomaly_score: 9959.224
# 636/1000 epoch ge_loss: 3.513 d_loss: 0.094 anomaly_score: 8405.439
# 637/1000 epoch ge_loss: 3.591 d_loss: 0.136 anomaly_score: 9098.796
# 638/1000 epoch ge_loss: 3.487 d_loss: 0.088 anomaly_score: 7815.216
# 639/1000 epoch ge_loss: 3.602 d_loss: 0.080 anomaly_score: 7429.171
# 640/1000 epoch ge_loss: 3.798 d_loss: 0.096 anomaly_score: 8243.308
# 641/1000 epoch ge_loss: 3.849 d_loss: 0.132 anomaly_score: 7313.877
# 642/1000 epoch ge_loss: 3.740 d_loss: 0.063 anomaly_score: 8599.520
# 643/1000 epoch ge_loss: 3.731 d_loss: 0.118 anomaly_score: 10515.277
# 644/1000 epoch ge_loss: 3.697 d_loss: 0.093 anomaly_score: 9302.047
# 645/1000 epoch ge_loss: 3.412 d_loss: 0.124 anomaly_score: 8132.218
# 646/1000 epoch ge_loss: 3.587 d_loss: 0.098 anomaly_score: 8163.593
# 647/1000 epoch ge_loss: 3.316 d_loss: 0.117 anomaly_score: 8349.999
# 648/1000 epoch ge_loss: 3.731 d_loss: 0.071 anomaly_score: 8761.454
# 649/1000 epoch ge_loss: 3.853 d_loss: 0.080 anomaly_score: 9146.909
# 650/1000 epoch ge_loss: 3.376 d_loss: 0.135 anomaly_score: 8767.704
# 651/1000 epoch ge_loss: 3.604 d_loss: 0.099 anomaly_score: 9268.059
# 652/1000 epoch ge_loss: 3.469 d_loss: 0.134 anomaly_score: 9205.893
# 653/1000 epoch ge_loss: 3.488 d_loss: 0.062 anomaly_score: 9752.600
# 654/1000 epoch ge_loss: 3.679 d_loss: 0.081 anomaly_score: 10226.934
# 655/1000 epoch ge_loss: 3.744 d_loss: 0.115 anomaly_score: 9125.808
# 656/1000 epoch ge_loss: 3.889 d_loss: 0.082 anomaly_score: 9441.216
# 657/1000 epoch ge_loss: 3.612 d_loss: 0.088 anomaly_score: 10146.561
# 658/1000 epoch ge_loss: 3.833 d_loss: 0.081 anomaly_score: 10202.195
# 659/1000 epoch ge_loss: 3.682 d_loss: 0.085 anomaly_score: 9172.527
# 660/1000 epoch ge_loss: 3.809 d_loss: 0.086 anomaly_score: 8104.060
# 661/1000 epoch ge_loss: 3.519 d_loss: 0.072 anomaly_score: 8103.128
# 662/1000 epoch ge_loss: 3.775 d_loss: 0.075 anomaly_score: 8492.282
# 663/1000 epoch ge_loss: 3.802 d_loss: 0.086 anomaly_score: 8677.392
# 664/1000 epoch ge_loss: 3.762 d_loss: 0.098 anomaly_score: 9162.956
# 665/1000 epoch ge_loss: 3.820 d_loss: 0.089 anomaly_score: 9766.332
# 666/1000 epoch ge_loss: 3.988 d_loss: 0.054 anomaly_score: 8133.259
# 667/1000 epoch ge_loss: 4.029 d_loss: 0.139 anomaly_score: 7862.453
# 668/1000 epoch ge_loss: 3.736 d_loss: 0.109 anomaly_score: 8895.421
# 669/1000 epoch ge_loss: 3.851 d_loss: 0.075 anomaly_score: 8685.464
# 670/1000 epoch ge_loss: 3.569 d_loss: 0.076 anomaly_score: 9447.726
# 671/1000 epoch ge_loss: 3.562 d_loss: 0.074 anomaly_score: 10355.647
# 672/1000 epoch ge_loss: 3.690 d_loss: 0.117 anomaly_score: 10733.824
# 673/1000 epoch ge_loss: 3.718 d_loss: 0.111 anomaly_score: 10408.905
# 674/1000 epoch ge_loss: 3.706 d_loss: 0.094 anomaly_score: 11429.619
# 675/1000 epoch ge_loss: 3.834 d_loss: 0.090 anomaly_score: 10243.756
# 676/1000 epoch ge_loss: 3.752 d_loss: 0.097 anomaly_score: 7435.794
# 677/1000 epoch ge_loss: 3.820 d_loss: 0.078 anomaly_score: 6948.221
# 678/1000 epoch ge_loss: 3.705 d_loss: 0.149 anomaly_score: 7857.680
# 679/1000 epoch ge_loss: 3.934 d_loss: 0.126 anomaly_score: 6785.405
# 680/1000 epoch ge_loss: 3.839 d_loss: 0.119 anomaly_score: 6670.619
# 681/1000 epoch ge_loss: 3.639 d_loss: 0.089 anomaly_score: 8117.872
# 682/1000 epoch ge_loss: 3.786 d_loss: 0.090 anomaly_score: 9740.672
# 683/1000 epoch ge_loss: 3.646 d_loss: 0.156 anomaly_score: 9443.123
# 684/1000 epoch ge_loss: 3.608 d_loss: 0.081 anomaly_score: 9572.822
# 685/1000 epoch ge_loss: 3.621 d_loss: 0.104 anomaly_score: 9229.448
# 686/1000 epoch ge_loss: 3.454 d_loss: 0.104 anomaly_score: 7623.736
# 687/1000 epoch ge_loss: 3.952 d_loss: 0.074 anomaly_score: 7777.664
# 688/1000 epoch ge_loss: 3.717 d_loss: 0.084 anomaly_score: 7424.535
# 689/1000 epoch ge_loss: 3.583 d_loss: 0.120 anomaly_score: 7036.880
# 690/1000 epoch ge_loss: 3.660 d_loss: 0.132 anomaly_score: 8492.452
# 691/1000 epoch ge_loss: 3.681 d_loss: 0.102 anomaly_score: 8882.504
# 692/1000 epoch ge_loss: 3.463 d_loss: 0.112 anomaly_score: 8177.819
# 693/1000 epoch ge_loss: 3.746 d_loss: 0.104 anomaly_score: 7412.426
# 694/1000 epoch ge_loss: 4.145 d_loss: 0.081 anomaly_score: 8145.526
# 695/1000 epoch ge_loss: 3.502 d_loss: 0.099 anomaly_score: 8153.764
# 696/1000 epoch ge_loss: 3.839 d_loss: 0.086 anomaly_score: 8436.242
# 697/1000 epoch ge_loss: 3.560 d_loss: 0.089 anomaly_score: 8088.035
# 698/1000 epoch ge_loss: 3.654 d_loss: 0.073 anomaly_score: 7999.563
# 699/1000 epoch ge_loss: 3.533 d_loss: 0.087 anomaly_score: 9937.306
# 700/1000 epoch ge_loss: 3.579 d_loss: 0.082 anomaly_score: 9010.827
# 701/1000 epoch ge_loss: 3.719 d_loss: 0.069 anomaly_score: 7889.938
# 702/1000 epoch ge_loss: 3.911 d_loss: 0.096 anomaly_score: 8390.887
# ...
# 765/1000 epoch ge_loss: 4.225 d_loss: 0.121 anomaly_score: 9718.112
# 766/1000 epoch ge_loss: 3.964 d_loss: 0.126 anomaly_score: 8815.117
# 767/1000 epoch ge_loss: 3.700 d_loss: 0.064 anomaly_score: 9228.208
# 768/1000 epoch ge_loss: 3.661 d_loss: 0.117 anomaly_score: 9859.788
# 769/1000 epoch ge_loss: 3.910 d_loss: 0.068 anomaly_score: 9385.051
# 770/1000 epoch ge_loss: 3.777 d_loss: 0.074 anomaly_score: 9718.352
# 771/1000 epoch ge_loss: 4.063 d_loss: 0.078 anomaly_score: 9354.251
# 772/1000 epoch ge_loss: 3.984 d_loss: 0.104 anomaly_score: 9448.517
# 773/1000 epoch ge_loss: 4.103 d_loss: 0.081 anomaly_score: 9209.136
# 774/1000 epoch ge_loss: 3.893 d_loss: 0.078 anomaly_score: 7866.322
# 775/1000 epoch ge_loss: 3.989 d_loss: 0.065 anomaly_score: 8753.162
# 776/1000 epoch ge_loss: 3.697 d_loss: 0.079 anomaly_score: 9618.850
# 777/1000 epoch ge_loss: 4.051 d_loss: 0.118 anomaly_score: 9735.881
# 778/1000 epoch ge_loss: 3.738 d_loss: 0.104 anomaly_score: 8119.620
# 779/1000 epoch ge_loss: 3.802 d_loss: 0.087 anomaly_score: 8507.096
# 780/1000 epoch ge_loss: 3.949 d_loss: 0.082 anomaly_score: 8268.310
# 781/1000 epoch ge_loss: 3.643 d_loss: 0.097 anomaly_score: 7884.924
# 782/1000 epoch ge_loss: 4.302 d_loss: 0.101 anomaly_score: 7811.789
# 783/1000 epoch ge_loss: 3.793 d_loss: 0.087 anomaly_score: 7634.919
# 784/1000 epoch ge_loss: 4.071 d_loss: 0.075 anomaly_score: 7336.416
# 785/1000 epoch ge_loss: 3.918 d_loss: 0.087 anomaly_score: 7033.831
# 786/1000 epoch ge_loss: 3.631 d_loss: 0.105 anomaly_score: 8182.756
# 787/1000 epoch ge_loss: 4.096 d_loss: 0.097 anomaly_score: 8879.533
# 788/1000 epoch ge_loss: 3.839 d_loss: 0.089 anomaly_score: 9668.533
# 789/1000 epoch ge_loss: 3.857 d_loss: 0.078 anomaly_score: 10090.000
# 790/1000 epoch ge_loss: 3.835 d_loss: 0.091 anomaly_score: 10502.215
# 791/1000 epoch ge_loss: 4.129 d_loss: 0.083 anomaly_score: 9544.744
# 792/1000 epoch ge_loss: 3.563 d_loss: 0.058 anomaly_score: 7720.529
# 793/1000 epoch ge_loss: 3.958 d_loss: 0.076 anomaly_score: 7424.919
# 794/1000 epoch ge_loss: 3.738 d_loss: 0.091 anomaly_score: 7161.586
# 795/1000 epoch ge_loss: 4.372 d_loss: 0.079 anomaly_score: 7083.984
# 796/1000 epoch ge_loss: 3.838 d_loss: 0.098 anomaly_score: 8007.702
# 797/1000 epoch ge_loss: 3.764 d_loss: 0.062 anomaly_score: 7279.864
# 798/1000 epoch ge_loss: 4.294 d_loss: 0.098 anomaly_score: 8562.664
# 799/1000 epoch ge_loss: 3.873 d_loss: 0.065 anomaly_score: 9780.757
# 800/1000 epoch ge_loss: 4.151 d_loss: 0.138 anomaly_score: 11137.407
# 801/1000 epoch ge_loss: 4.095 d_loss: 0.084 anomaly_score: 10922.315
# 802/1000 epoch ge_loss: 3.541 d_loss: 0.080 anomaly_score: 9759.331
# 803/1000 epoch ge_loss: 3.604 d_loss: 0.050 anomaly_score: 8770.625
# 804/1000 epoch ge_loss: 3.882 d_loss: 0.098 anomaly_score: 9631.969
# 805/1000 epoch ge_loss: 3.890 d_loss: 0.109 anomaly_score: 8628.808
# 806/1000 epoch ge_loss: 4.362 d_loss: 0.060 anomaly_score: 8701.666
# 807/1000 epoch ge_loss: 3.890 d_loss: 0.069 anomaly_score: 9144.975
# 808/1000 epoch ge_loss: 3.807 d_loss: 0.077 anomaly_score: 9720.805
# 809/1000 epoch ge_loss: 3.968 d_loss: 0.040 anomaly_score: 9644.327
# 810/1000 epoch ge_loss: 3.961 d_loss: 0.106 anomaly_score: 10118.603
# 811/1000 epoch ge_loss: 4.328 d_loss: 0.077 anomaly_score: 9285.098
# 812/1000 epoch ge_loss: 3.923 d_loss: 0.099 anomaly_score: 8030.035
# 813/1000 epoch ge_loss: 4.020 d_loss: 0.045 anomaly_score: 7338.588
# 814/1000 epoch ge_loss: 3.849 d_loss: 0.091 anomaly_score: 7289.538
# 815/1000 epoch ge_loss: 3.916 d_loss: 0.100 anomaly_score: 7608.268
# 816/1000 epoch ge_loss: 3.693 d_loss: 0.064 anomaly_score: 7608.176
# 817/1000 epoch ge_loss: 4.394 d_loss: 0.065 anomaly_score: 7719.958
# 818/1000 epoch ge_loss: 4.133 d_loss: 0.071 anomaly_score: 8383.707
# 819/1000 epoch ge_loss: 4.041 d_loss: 0.105 anomaly_score: 7817.921
# 820/1000 epoch ge_loss: 4.309 d_loss: 0.051 anomaly_score: 8046.324
# 821/1000 epoch ge_loss: 4.121 d_loss: 0.070 anomaly_score: 8299.145
# 822/1000 epoch ge_loss: 4.441 d_loss: 0.083 anomaly_score: 9230.676
# 823/1000 epoch ge_loss: 4.218 d_loss: 0.052 anomaly_score: 9204.466
# 824/1000 epoch ge_loss: 3.973 d_loss: 0.069 anomaly_score: 7260.081
# 825/1000 epoch ge_loss: 3.975 d_loss: 0.070 anomaly_score: 7446.944
# 826/1000 epoch ge_loss: 3.816 d_loss: 0.078 anomaly_score: 7359.308
# 827/1000 epoch ge_loss: 4.093 d_loss: 0.072 anomaly_score: 7708.747
# 828/1000 epoch ge_loss: 4.078 d_loss: 0.092 anomaly_score: 7292.074
# 829/1000 epoch ge_loss: 4.299 d_loss: 0.079 anomaly_score: 7376.652
# 830/1000 epoch ge_loss: 4.161 d_loss: 0.111 anomaly_score: 8649.253
# 831/1000 epoch ge_loss: 3.802 d_loss: 0.089 anomaly_score: 9006.956
# 832/1000 epoch ge_loss: 3.906 d_loss: 0.098 anomaly_score: 8857.616
# 833/1000 epoch ge_loss: 4.679 d_loss: 0.098 anomaly_score: 8187.595
# 834/1000 epoch ge_loss: 4.242 d_loss: 0.036 anomaly_score: 9373.393
# 835/1000 epoch ge_loss: 3.885 d_loss: 0.117 anomaly_score: 9578.592
# 836/1000 epoch ge_loss: 3.973 d_loss: 0.070 anomaly_score: 8885.828
# 837/1000 epoch ge_loss: 3.795 d_loss: 0.050 anomaly_score: 8543.264
# 838/1000 epoch ge_loss: 3.963 d_loss: 0.078 anomaly_score: 8250.124
# 839/1000 epoch ge_loss: 3.889 d_loss: 0.079 anomaly_score: 8905.250
# 840/1000 epoch ge_loss: 3.972 d_loss: 0.071 anomaly_score: 8986.091
# 841/1000 epoch ge_loss: 3.861 d_loss: 0.083 anomaly_score: 9779.639
# 842/1000 epoch ge_loss: 3.998 d_loss: 0.063 anomaly_score: 9084.847
# 843/1000 epoch ge_loss: 4.112 d_loss: 0.071 anomaly_score: 8867.201
# 844/1000 epoch ge_loss: 4.058 d_loss: 0.078 anomaly_score: 8635.374
# 845/1000 epoch ge_loss: 3.864 d_loss: 0.115 anomaly_score: 8753.240
# 846/1000 epoch ge_loss: 3.788 d_loss: 0.099 anomaly_score: 8985.700
# 847/1000 epoch ge_loss: 4.433 d_loss: 0.072 anomaly_score: 10801.288
# 848/1000 epoch ge_loss: 3.884 d_loss: 0.094 anomaly_score: 11789.259
# 849/1000 epoch ge_loss: 3.911 d_loss: 0.091 anomaly_score: 11142.562
# 850/1000 epoch ge_loss: 3.736 d_loss: 0.103 anomaly_score: 8967.598
# 851/1000 epoch ge_loss: 4.208 d_loss: 0.088 anomaly_score: 7477.362
# 852/1000 epoch ge_loss: 4.486 d_loss: 0.084 anomaly_score: 6360.480
# 853/1000 epoch ge_loss: 3.771 d_loss: 0.062 anomaly_score: 7553.644
# 854/1000 epoch ge_loss: 3.822 d_loss: 0.094 anomaly_score: 7657.362
# 855/1000 epoch ge_loss: 3.797 d_loss: 0.085 anomaly_score: 7680.092
# 856/1000 epoch ge_loss: 4.004 d_loss: 0.072 anomaly_score: 6958.988
# 857/1000 epoch ge_loss: 3.701 d_loss: 0.079 anomaly_score: 7210.707
# 858/1000 epoch ge_loss: 4.268 d_loss: 0.065 anomaly_score: 7501.221
# 859/1000 epoch ge_loss: 4.500 d_loss: 0.056 anomaly_score: 9160.454
# 860/1000 epoch ge_loss: 3.946 d_loss: 0.078 anomaly_score: 8972.976
# 861/1000 epoch ge_loss: 4.337 d_loss: 0.069 anomaly_score: 7301.589
# 862/1000 epoch ge_loss: 4.754 d_loss: 0.060 anomaly_score: 7507.852
# 863/1000 epoch ge_loss: 4.048 d_loss: 0.052 anomaly_score: 7901.094
# 864/1000 epoch ge_loss: 3.943 d_loss: 0.094 anomaly_score: 7773.715
# 865/1000 epoch ge_loss: 4.026 d_loss: 0.038 anomaly_score: 8947.943
# 866/1000 epoch ge_loss: 4.057 d_loss: 0.072 anomaly_score: 9141.602
# 867/1000 epoch ge_loss: 3.974 d_loss: 0.055 anomaly_score: 8802.699
# 868/1000 epoch ge_loss: 4.106 d_loss: 0.082 anomaly_score: 7374.182
# 869/1000 epoch ge_loss: 3.966 d_loss: 0.065 anomaly_score: 7617.215
# 870/1000 epoch ge_loss: 4.046 d_loss: 0.071 anomaly_score: 6862.995
# 871/1000 epoch ge_loss: 3.913 d_loss: 0.064 anomaly_score: 8044.900
# 872/1000 epoch ge_loss: 4.083 d_loss: 0.065 anomaly_score: 10241.831
# 873/1000 epoch ge_loss: 3.820 d_loss: 0.053 anomaly_score: 10230.533
# 874/1000 epoch ge_loss: 3.984 d_loss: 0.086 anomaly_score: 10685.726
# 875/1000 epoch ge_loss: 4.219 d_loss: 0.065 anomaly_score: 10919.617
# 876/1000 epoch ge_loss: 3.787 d_loss: 0.122 anomaly_score: 10747.265
# 877/1000 epoch ge_loss: 4.106 d_loss: 0.081 anomaly_score: 8888.995
# 878/1000 epoch ge_loss: 3.993 d_loss: 0.086 anomaly_score: 7975.387
# 879/1000 epoch ge_loss: 4.098 d_loss: 0.057 anomaly_score: 7343.293
# 880/1000 epoch ge_loss: 4.220 d_loss: 0.115 anomaly_score: 7411.724
# 881/1000 epoch ge_loss: 3.847 d_loss: 0.048 anomaly_score: 7394.876
# 882/1000 epoch ge_loss: 4.023 d_loss: 0.078 anomaly_score: 6328.434
# 883/1000 epoch ge_loss: 4.057 d_loss: 0.059 anomaly_score: 6603.706
# 884/1000 epoch ge_loss: 3.865 d_loss: 0.073 anomaly_score: 6787.041
# 885/1000 epoch ge_loss: 4.070 d_loss: 0.110 anomaly_score: 6816.748
# 886/1000 epoch ge_loss: 3.898 d_loss: 0.102 anomaly_score: 7561.421
# 887/1000 epoch ge_loss: 4.051 d_loss: 0.105 anomaly_score: 8148.985
# 888/1000 epoch ge_loss: 4.222 d_loss: 0.078 anomaly_score: 8011.668
# 889/1000 epoch ge_loss: 4.007 d_loss: 0.080 anomaly_score: 8315.777
# 890/1000 epoch ge_loss: 4.264 d_loss: 0.104 anomaly_score: 10142.926
# 891/1000 epoch ge_loss: 4.401 d_loss: 0.069 anomaly_score: 9405.206
# 892/1000 epoch ge_loss: 4.184 d_loss: 0.065 anomaly_score: 6943.009
# 893/1000 epoch ge_loss: 4.264 d_loss: 0.073 anomaly_score: 6764.080
# 894/1000 epoch ge_loss: 3.841 d_loss: 0.065 anomaly_score: 6037.716
# 895/1000 epoch ge_loss: 4.083 d_loss: 0.065 anomaly_score: 5993.349
# 896/1000 epoch ge_loss: 4.055 d_loss: 0.064 anomaly_score: 6439.313
# 897/1000 epoch ge_loss: 3.701 d_loss: 0.065 anomaly_score: 7283.492
# 898/1000 epoch ge_loss: 4.004 d_loss: 0.069 anomaly_score: 8983.742
# 899/1000 epoch ge_loss: 4.048 d_loss: 0.068 anomaly_score: 9287.161
# 900/1000 epoch ge_loss: 4.278 d_loss: 0.069 anomaly_score: 8335.478
# 901/1000 epoch ge_loss: 4.298 d_loss: 0.073 anomaly_score: 7294.497
# 902/1000 epoch ge_loss: 3.686 d_loss: 0.107 anomaly_score: 5890.978
# 903/1000 epoch ge_loss: 3.891 d_loss: 0.075 anomaly_score: 6686.727
# 904/1000 epoch ge_loss: 3.958 d_loss: 0.064 anomaly_score: 6600.338
# 905/1000 epoch ge_loss: 4.067 d_loss: 0.067 anomaly_score: 6773.368
# 906/1000 epoch ge_loss: 3.989 d_loss: 0.060 anomaly_score: 6603.758
# 907/1000 epoch ge_loss: 4.070 d_loss: 0.060 anomaly_score: 6334.317
# 908/1000 epoch ge_loss: 3.739 d_loss: 0.085 anomaly_score: 6966.288
# 909/1000 epoch ge_loss: 4.288 d_loss: 0.097 anomaly_score: 7471.087
# 910/1000 epoch ge_loss: 3.917 d_loss: 0.064 anomaly_score: 8099.112
# 911/1000 epoch ge_loss: 4.104 d_loss: 0.091 anomaly_score: 9842.303
# 912/1000 epoch ge_loss: 3.936 d_loss: 0.080 anomaly_score: 9417.865
# 913/1000 epoch ge_loss: 3.839 d_loss: 0.077 anomaly_score: 7862.365
# 914/1000 epoch ge_loss: 4.367 d_loss: 0.099 anomaly_score: 8105.307
# 915/1000 epoch ge_loss: 3.909 d_loss: 0.101 anomaly_score: 8493.974
# 916/1000 epoch ge_loss: 3.783 d_loss: 0.091 anomaly_score: 8198.391
# 917/1000 epoch ge_loss: 4.071 d_loss: 0.075 anomaly_score: 8590.684
# 918/1000 epoch ge_loss: 4.138 d_loss: 0.065 anomaly_score: 8112.364
# 919/1000 epoch ge_loss: 4.046 d_loss: 0.063 anomaly_score: 8407.897
# 920/1000 epoch ge_loss: 3.789 d_loss: 0.058 anomaly_score: 9140.338
# 921/1000 epoch ge_loss: 4.034 d_loss: 0.102 anomaly_score: 8965.363
# 922/1000 epoch ge_loss: 4.053 d_loss: 0.068 anomaly_score: 8201.575
# 923/1000 epoch ge_loss: 4.383 d_loss: 0.064 anomaly_score: 9112.697
# 924/1000 epoch ge_loss: 3.983 d_loss: 0.059 anomaly_score: 9068.024
# 925/1000 epoch ge_loss: 3.876 d_loss: 0.107 anomaly_score: 8632.301
# 926/1000 epoch ge_loss: 3.969 d_loss: 0.110 anomaly_score: 8816.995
# 927/1000 epoch ge_loss: 4.088 d_loss: 0.065 anomaly_score: 7986.212
# 928/1000 epoch ge_loss: 4.069 d_loss: 0.080 anomaly_score: 6990.238
# 929/1000 epoch ge_loss: 4.190 d_loss: 0.083 anomaly_score: 7738.441
# 930/1000 epoch ge_loss: 4.671 d_loss: 0.071 anomaly_score: 6819.477
# 931/1000 epoch ge_loss: 3.923 d_loss: 0.053 anomaly_score: 7393.059
# 932/1000 epoch ge_loss: 3.982 d_loss: 0.092 anomaly_score: 7733.237
# 933/1000 epoch ge_loss: 4.204 d_loss: 0.065 anomaly_score: 6849.969
# 934/1000 epoch ge_loss: 4.154 d_loss: 0.093 anomaly_score: 7513.705
# 935/1000 epoch ge_loss: 3.941 d_loss: 0.087 anomaly_score: 7059.110
# 936/1000 epoch ge_loss: 3.978 d_loss: 0.087 anomaly_score: 7151.420
# 937/1000 epoch ge_loss: 4.163 d_loss: 0.080 anomaly_score: 7473.037
# 938/1000 epoch ge_loss: 3.863 d_loss: 0.096 anomaly_score: 6398.825
# 939/1000 epoch ge_loss: 4.115 d_loss: 0.052 anomaly_score: 5665.082
# 940/1000 epoch ge_loss: 4.004 d_loss: 0.092 anomaly_score: 5970.417
# 941/1000 epoch ge_loss: 4.301 d_loss: 0.087 anomaly_score: 6642.786
# 942/1000 epoch ge_loss: 4.163 d_loss: 0.070 anomaly_score: 8189.657
# 943/1000 epoch ge_loss: 3.896 d_loss: 0.054 anomaly_score: 8084.103
# 944/1000 epoch ge_loss: 3.606 d_loss: 0.107 anomaly_score: 8620.318
# 945/1000 epoch ge_loss: 3.871 d_loss: 0.080 anomaly_score: 7167.879
# 946/1000 epoch ge_loss: 4.098 d_loss: 0.073 anomaly_score: 7169.191
# 947/1000 epoch ge_loss: 4.411 d_loss: 0.063 anomaly_score: 7300.562
# 948/1000 epoch ge_loss: 4.102 d_loss: 0.077 anomaly_score: 8114.130
# 949/1000 epoch ge_loss: 4.170 d_loss: 0.049 anomaly_score: 8143.627
# 950/1000 epoch ge_loss: 4.249 d_loss: 0.066 anomaly_score: 6927.026
# 951/1000 epoch ge_loss: 4.429 d_loss: 0.063 anomaly_score: 5814.857
# 952/1000 epoch ge_loss: 4.119 d_loss: 0.057 anomaly_score: 5958.869
# 953/1000 epoch ge_loss: 3.829 d_loss: 0.082 anomaly_score: 6070.635
# 954/1000 epoch ge_loss: 3.950 d_loss: 0.105 anomaly_score: 7361.958
# 955/1000 epoch ge_loss: 3.984 d_loss: 0.056 anomaly_score: 7413.796
# 956/1000 epoch ge_loss: 4.129 d_loss: 0.060 anomaly_score: 7294.738
# 957/1000 epoch ge_loss: 4.015 d_loss: 0.066 anomaly_score: 7902.374
# 958/1000 epoch ge_loss: 3.738 d_loss: 0.066 anomaly_score: 9462.886
# 959/1000 epoch ge_loss: 4.086 d_loss: 0.058 anomaly_score: 8629.359
# 960/1000 epoch ge_loss: 3.970 d_loss: 0.066 anomaly_score: 7381.696
# 961/1000 epoch ge_loss: 4.462 d_loss: 0.039 anomaly_score: 7815.337
# 962/1000 epoch ge_loss: 4.115 d_loss: 0.106 anomaly_score: 7052.081
# 963/1000 epoch ge_loss: 4.029 d_loss: 0.101 anomaly_score: 7219.884
# 964/1000 epoch ge_loss: 4.050 d_loss: 0.092 anomaly_score: 8044.095
# 965/1000 epoch ge_loss: 4.107 d_loss: 0.096 anomaly_score: 8299.193
# 966/1000 epoch ge_loss: 4.035 d_loss: 0.122 anomaly_score: 7719.184
# 967/1000 epoch ge_loss: 3.813 d_loss: 0.097 anomaly_score: 7839.108
# 968/1000 epoch ge_loss: 4.039 d_loss: 0.061 anomaly_score: 7967.616
# 969/1000 epoch ge_loss: 4.226 d_loss: 0.108 anomaly_score: 7642.608
# 970/1000 epoch ge_loss: 4.578 d_loss: 0.079 anomaly_score: 7230.207
# 971/1000 epoch ge_loss: 4.119 d_loss: 0.080 anomaly_score: 7554.299
# 972/1000 epoch ge_loss: 4.630 d_loss: 0.083 anomaly_score: 7874.187
# 973/1000 epoch ge_loss: 3.951 d_loss: 0.083 anomaly_score: 7605.265
# 974/1000 epoch ge_loss: 4.051 d_loss: 0.068 anomaly_score: 6886.074
# 975/1000 epoch ge_loss: 4.290 d_loss: 0.045 anomaly_score: 6879.596
# 976/1000 epoch ge_loss: 3.776 d_loss: 0.048 anomaly_score: 7672.696
# 977/1000 epoch ge_loss: 3.995 d_loss: 0.068 anomaly_score: 7990.162
# 978/1000 epoch ge_loss: 4.357 d_loss: 0.045 anomaly_score: 8168.528
# 979/1000 epoch ge_loss: 4.386 d_loss: 0.073 anomaly_score: 8353.466
# 980/1000 epoch ge_loss: 4.978 d_loss: 0.044 anomaly_score: 9268.073
# 981/1000 epoch ge_loss: 4.277 d_loss: 0.086 anomaly_score: 9574.708
# 982/1000 epoch ge_loss: 4.173 d_loss: 0.064 anomaly_score: 8465.037
# 983/1000 epoch ge_loss: 4.240 d_loss: 0.052 anomaly_score: 8808.240
# 984/1000 epoch ge_loss: 4.487 d_loss: 0.053 anomaly_score: 9209.016
# 985/1000 epoch ge_loss: 4.220 d_loss: 0.093 anomaly_score: 9375.378
# 986/1000 epoch ge_loss: 4.209 d_loss: 0.066 anomaly_score: 7784.520
# 987/1000 epoch ge_loss: 4.621 d_loss: 0.052 anomaly_score: 8647.603
# 988/1000 epoch ge_loss: 4.177 d_loss: 0.070 anomaly_score: 8250.478
# 989/1000 epoch ge_loss: 4.094 d_loss: 0.055 anomaly_score: 7648.177
# 990/1000 epoch ge_loss: 4.174 d_loss: 0.073 anomaly_score: 8650.723
# 991/1000 epoch ge_loss: 4.335 d_loss: 0.071 anomaly_score: 9635.248
# 992/1000 epoch ge_loss: 4.233 d_loss: 0.061 anomaly_score: 10157.508
# 993/1000 epoch ge_loss: 3.985 d_loss: 0.067 anomaly_score: 9108.373
# 994/1000 epoch ge_loss: 4.208 d_loss: 0.051 anomaly_score: 8621.214
# 995/1000 epoch ge_loss: 4.181 d_loss: 0.069 anomaly_score: 8779.844
# 996/1000 epoch ge_loss: 4.212 d_loss: 0.062 anomaly_score: 8888.010
# 997/1000 epoch ge_loss: 4.162 d_loss: 0.057 anomaly_score: 8683.263
# 998/1000 epoch ge_loss: 4.111 d_loss: 0.059 anomaly_score: 9041.505
# 999/1000 epoch ge_loss: 4.101 d_loss: 0.071 anomaly_score: 7966.854

# %%
# Generator+EncoderとDiscriminatorのLossの推移と、anomaly scoreの推移
plt.figure(figsize=(12, 8*2))

plt.subplot(211)
plt.plot(range(len(Losses_GE)), Losses_GE, label="ge loss",color="blue")
plt.legend()

plt.plot(range(len(Losses_D)), Losses_D, label="d loss",color="orange")
plt.legend()
plt.subplot(212)
plt.plot(range(len(anomaly_scores)), anomaly_scores, label="anomaly score",color="green")
plt.legend()

plt.show()

# %% [markdown]
# # 潜在変数Zの最適化とテスト画像での異常検知

# %%
# 学習したモデルの読み込み

LOAD_EPOCH = 1000

G = Generator().to(device)
G.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Generator_{LOAD_EPOCH}.pkl"))
G.eval()


E = Encoder().to(device)
E.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Encoder_{LOAD_EPOCH}.pkl"))
E.eval()

D = Discriminator().to(device)
D.load_state_dict(torch.load(f"{SAVE_MODEL_PATH}/Discriminator_{LOAD_EPOCH}.pkl"))
D.eval()
print("load model")
# Out:
# load model

# %%
# 正常な画像で実行

random_image_size = 20

test_root_normal = './data/fruits-360/Test/Physalis/'
test_dataset_normal = LoadFromFolder(test_root_normal, transform=transform_dict["test"])

test_images_normal = random.sample(list(test_dataset_normal), random_image_size)

# うまく再現され、異常スコアが低くなっていれば成功
for idx in range(len(test_images_normal)):

    x = test_images_normal[idx].view(1, 3, 96, 96).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()

# %%
# 画像に傷を模した記号を付与する関数

def add_damage(image_path):
    
    folder = os.path.dirname(image_path)
    save_folder = folder + "_damaged"
    save_base_path = os.path.basename(image_path).replace(".jpg", "_damaged.jpg")
    save_path = os.path.join(save_folder, save_base_path)
    
    os.makedirs(save_folder, exist_ok=True)
    
    image = cv2.imread(image_path)
    center_x = random.randint(20, 76)
    center_y = random.randint(20, 76)
    color_r = random.randint(0, 255)
    color_g = random.randint(0, 255)
    color_b = random.randint(0, 255)
    
    center = (center_x, center_y)
    color = (color_r, color_g, color_b)
    
    cv2.circle(image, center = center, radius = 10, color = color,thickness=-1)
    cv2.imwrite(save_path, image)
    
images_path = glob('./data/fruits-360/Test/Physalis/*.jpg')
[add_damage(image_path) for image_path in images_path]
print("add damage")
# Out:
# add damage

# %%
# 異常な画像で実行

test_root_anomaly = './data/fruits-360/Test/Physalis_damaged/'
test_dataset_anomaly = LoadFromFolder(test_root_anomaly, transform=transform_dict["test"])

test_images_anomaly = random.sample(list(test_dataset_anomaly), random_image_size)

# うまく再現されず、異常スコアが高くなっていれば成功
for idx in range(len(test_images_anomaly)):

    x = test_images_anomaly[idx].view(1, 3, 96, 96).to(device)
    E_x = E(x)
    G_E_x = G(E_x)
    
    loss = Anomaly_score(x, E_x, G_E_x)
    diff_img = torch.abs(x - G_E_x)
    print(f"Anomaly_score: {loss:.3f}")
    comparison = torch.cat([x.to("cpu"), G_E_x.to("cpu"), diff_img.to("cpu")])
    joined_image = make_grid(comparison, nrow=3).detach().numpy()
    joined_image = np.transpose(joined_image, [1, 2, 0])
    
    plt.figure(figsize=(12, 4))
    plt.imshow((joined_image * 255).astype(np.uint8))
    plt.show()
